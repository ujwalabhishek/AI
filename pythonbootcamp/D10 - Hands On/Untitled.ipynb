# %%
# for data analysis
import numpy as np
import pandas as pd

# for data viz.
import matplotlib.pyplot as plt
import seaborn as sns

# %%
amzn = pd.read_csv("AMZN_stocks_data.csv")
amzn.head()
# Out:
#          Date   Open   High    Low  Close   Volume  Name
# 0  2006-01-03  47.47  47.85  46.25  47.58  7582127  AMZN
# 1  2006-01-04  47.48  47.73  46.69  47.25  7440914  AMZN
# 2  2006-01-05  47.16  48.20  47.11  47.65  5417258  AMZN
# 3  2006-01-06  47.97  48.58  47.32  47.87  6154285  AMZN
# 4  2006-01-09  46.55  47.10  46.40  47.08  8945056  AMZN

# %%
# Quiz 
# Create a line plot of `Opening price` and `Closing price` 
# of Amazon Stock for the year 2007 using `amzn` dataframe.

# %%
#filter
amzn2007 = amzn[amzn['Date'].str.contains('2007') ]
amzn2007
# Out:
#            Date   Open   High    Low  Close    Volume  Name
# 251  2007-01-03  38.68  39.06  38.05  38.70  12441282  AMZN
# 252  2007-01-04  38.59  39.14  38.26  38.90   6328615  AMZN
# 253  2007-01-05  38.72  38.79  37.60  38.37   6623820  AMZN
# 254  2007-01-08  38.22  38.31  37.17  37.50   6784631  AMZN
# 255  2007-01-09  37.60  38.06  37.34  37.78   5703051  AMZN
# ..          ...    ...    ...    ...    ...       ...   ...
# 497  2007-12-24  91.05  91.56  90.30  91.01   2017170  AMZN
# 498  2007-12-26  91.48  93.94  90.50  92.85   5444957  AMZN
# 499  2007-12-27  92.67  95.29  92.50  94.25   7115884  AMZN
# 500  2007-12-28  95.27  95.90  92.10  94.45   7587601  AMZN
# 501  2007-12-31  93.81  94.37  92.45  92.64   5756991  AMZN
#
# [251 rows x 7 columns]

# %%
#ii
sns.lineplot(x = amzn2007['Date'],y = amzn2007['Open'])
sns.lineplot(x = amzn2007['Date'],y = amzn2007['Close'])
# Out:
# <Axes: xlabel='Date', ylabel='Open'>

# %%
# Quiz 
#i. Create a barplot of the average closing price (Close) for each year. 
# ii. Create a barplot of the average closing price (Close) for each year, 
# split by whether the high price of the day exceeded $1000$ dollars or not. 
# Hint: Use the hue and estimator parameters of the sns.barplot method.

# %%
#i. gurupby year does not have a clear column as date time is a string so lets create a year colm

#amzn['Year'] = amzn['Date'].str[0:4]

# Convert 'Date' to datetime
amzn['Date'] = pd.to_datetime(amzn['Date'])

# Extract year into a new column (optional but useful)
amzn['Year'] = amzn['Date'].dt.year
amzn
# Out:
#            Date     Open     High      Low    Close   Volume  Name  Year  year
# 0    2006-01-03    47.47    47.85    46.25    47.58  7582127  AMZN  2006  2006
# 1    2006-01-04    47.48    47.73    46.69    47.25  7440914  AMZN  2006  2006
# 2    2006-01-05    47.16    48.20    47.11    47.65  5417258  AMZN  2006  2006
# 3    2006-01-06    47.97    48.58    47.32    47.87  6154285  AMZN  2006  2006
# 4    2006-01-09    46.55    47.10    46.40    47.08  8945056  AMZN  2006  2006
# ...         ...      ...      ...      ...      ...      ...   ...   ...   ...
# 3014 2017-12-22  1172.08  1174.62  1167.83  1168.36  1585054  AMZN  2017  2017
# 3015 2017-12-26  1168.36  1178.32  1160.55  1176.76  2005187  AMZN  2017  2017
# 3016 2017-12-27  1179.91  1187.29  1175.61  1182.26  1867208  AMZN  2017  2017
# 3017 2017-12-28  1189.00  1190.10  1184.38  1186.10  1841676  AMZN  2017  2017
# 3018 2017-12-29  1182.35  1184.00  1167.50  1169.47  2688391  AMZN  2017  2017
#
# [3019 rows x 9 columns]

# %%
amzn.groupby('Year')['Close'].mean()
# Out:
# Year
# 2006     35.909323
# 2007     67.229482
# 2008     69.880040
# 2009     87.281825
# 2010    139.169602
# 2011    196.663849
# 2012    220.303680
# 2013    298.032222
# 2014    332.550913
# 2015    478.138294
# 2016    699.523135
# 2017    968.167012
# Name: Close, dtype: float64

# %%
sns.barplot(amzn,x='Year',y='Close',estimator='mean')
plt.title('average closing price (Close) for each year')
# Out:
# Text(0.5, 1.0, 'average closing price (Close) for each year')

# %%
# ii. Create a barplot of the average closing price (Close) for each year,
# split by whether the high price of the day exceeded  $1000$ dollars or not.
# Hint: Use the hue and estimator parameters of the sns.barplot method.

# %%
amzn.head()
# Out:
#         Date   Open   High    Low  Close   Volume  Name  Year  year  \
# 0 2006-01-03  47.47  47.85  46.25  47.58  7582127  AMZN  2006  2006
# 1 2006-01-04  47.48  47.73  46.69  47.25  7440914  AMZN  2006  2006
# 2 2006-01-05  47.16  48.20  47.11  47.65  5417258  AMZN  2006  2006
# 3 2006-01-06  47.97  48.58  47.32  47.87  6154285  AMZN  2006  2006
# 4 2006-01-09  46.55  47.10  46.40  47.08  8945056  AMZN  2006  2006
#
#    High > 1000
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
amzn['High>1000']= amzn['High'] > 1000
amzn.head()
# Out:
#         Date   Open   High    Low  Close   Volume  Name  Year  year  \
# 0 2006-01-03  47.47  47.85  46.25  47.58  7582127  AMZN  2006  2006
# 1 2006-01-04  47.48  47.73  46.69  47.25  7440914  AMZN  2006  2006
# 2 2006-01-05  47.16  48.20  47.11  47.65  5417258  AMZN  2006  2006
# 3 2006-01-06  47.97  48.58  47.32  47.87  6154285  AMZN  2006  2006
# 4 2006-01-09  46.55  47.10  46.40  47.08  8945056  AMZN  2006  2006
#
#    High > 1000  High>1000
# 0        False      False
# 1        False      False
# 2        False      False
# 3        False      False
# 4        False      False

# %%
avg_close_split = amzn.groupby(['Year','High>1000'])['Close'].mean().reset_index()
avg_close_split
# Out:
#     Year  High>1000        Close
# 0   2006      False    35.909323
# 1   2007      False    67.229482
# 2   2008      False    69.880040
# 3   2009      False    87.281825
# 4   2010      False   139.169602
# 5   2011      False   196.663849
# 6   2012      False   220.303680
# 7   2013      False   298.032222
# 8   2014      False   332.550913
# 9   2015      False   478.138294
# 10  2016      False   699.523135
# 11  2017      False   913.147965
# 12  2017       True  1087.955316

# %%
sns.barplot(data = avg_close_split, x = 'Year', y = 'Close', estimator = 'mean', hue = 'High>1000')
# Out:
# <Axes: xlabel='Year', ylabel='Close'>

# %%
# What is the distribution of the `Closing price` (Close) split by 
# whether the volume of stocks traded exceeded the median volume?

# %%
# Tell me the distribution of CLOSE price with bins = 30 
# 2 graphs - matplotlib and seaborn!
