# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('churn_data.csv')
df['PaymentMethod'].replace(to_replace='Bank transfer (automatic)',value='Bank transfer',inplace=True)
df['PaymentMethod'].replace(to_replace='Credit card (automatic)',value='Credit card',inplace=True)
df.dropna(axis=0,inplace=True)
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"])
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv('churn_data.csv')
#       2 df['PaymentMethod'].replace(to_replace='Bank transfer (automatic)',value='Bank transfer',inplace=True)
#       3 df['PaymentMethod'].replace(to_replace='Credit card (automatic)',value='Credit card',inplace=True)
#
# NameError: name 'pd' is not defined

# %%
amzn = pd.read_csv('AMZN_stocks_data.csv')
amzn.head()
# Out:
#          Date   Open   High    Low  Close   Volume  Name
# 0  2006-01-03  47.47  47.85  46.25  47.58  7582127  AMZN
# 1  2006-01-04  47.48  47.73  46.69  47.25  7440914  AMZN
# 2  2006-01-05  47.16  48.20  47.11  47.65  5417258  AMZN
# 3  2006-01-06  47.97  48.58  47.32  47.87  6154285  AMZN
# 4  2006-01-09  46.55  47.10  46.40  47.08  8945056  AMZN

# %%
df_ap = df_ap = pd.read_csv('AirPassengers.csv')  # sequential data

# %%
df_hearts = pd.read_csv('heart.csv')

# %%
# sns.scatterplot(data=amzn,x='Open',y='Close')

# %%
# using matplotlib :
plt.scatter(x= amzn['Open'] ,y=amzn['Close'])
plt.title('Relationship between Open and Close')
plt.xlabel("Open")
plt.ylabel("Close")
# Out:
# Text(0, 0.5, 'Close')

# %%
plt.scatter(x= amzn['Open'] ,y=amzn['Close'],s = 10)
plt.title('Relationship between Open and Close')
plt.xlabel("Open")
plt.ylabel("Close")
# Out:
# Text(0, 0.5, 'Close')

# %%
# Line Plots :

# %%
df_ap.head()
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %%
df_ap.tail()
# Out:
#        Month  Passengers
# 139  1960-08         606
# 140  1960-09         508
# 141  1960-10         461
# 142  1960-11         390
# 143  1960-12         432

# %%
plt.plot(df_ap['Month'],df_ap['Passengers'])
# plt.xticks()

# %%
df_hearts.head()
# Out:
#    age  sex     BP  cholestrol  heart disease
# 0   70    1  130.0       322.0            1.0
# 1   67    0  115.0       564.0            0.0
# 2   57    1  124.0       261.0            1.0
# 3   64    1  128.0       263.0            0.0
# 4   74    0  120.0       269.0            0.0

# %%
df_hearts['age'].min()
# Out:
# 29

# %%
df_hearts['age'].max()
# Out:
# 77

# %%
df_hearts['age'].median()
# Out:
# 55.0

# %%
plt.hist(df_hearts['age'])
# Out:
# (array([ 1.,  8., 30., 35., 35., 50., 57., 38., 13.,  3.]),
#  array([29. , 33.8, 38.6, 43.4, 48.2, 53. , 57.8, 62.6, 67.4, 72.2, 77. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df_hearts['age'],bins = 4)
# Out:
# (array([ 15.,  94., 123.,  38.]),
#  array([29., 41., 53., 65., 77.]),
#  <BarContainer object of 4 artists>)

# %%
plt.hist(df_hearts['age'],bins = 2)
# Out:
# (array([109., 161.]),
#  array([29., 53., 77.]),
#  <BarContainer object of 2 artists>)

# %%
df_hearts.head()
# 2 histograms for both sex - Male and Female!
# Out:
#    age  sex     BP  cholestrol  heart disease
# 0   70    1  130.0       322.0            1.0
# 1   67    0  115.0       564.0            0.0
# 2   57    1  124.0       261.0            1.0
# 3   64    1  128.0       263.0            0.0
# 4   74    0  120.0       269.0            0.0

# %%
male   = df_hearts[df_hearts['sex']==1]
female = df_hearts[df_hearts['sex']==0]

# %%
plt.hist(male['age'],label = 'male')
plt.hist(female['age'],label = 'female')
plt.legend();

# %%
plt.hist(male['age'],label = 'male')
# Out:
# (array([ 1.,  5., 21., 26., 25., 36., 38., 22.,  8.,  1.]),
#  array([29. , 33.8, 38.6, 43.4, 48.2, 53. , 57.8, 62.6, 67.4, 72.2, 77. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(female['age'],label = 'female')
# Out:
# (array([ 3.,  7., 10.,  6., 12., 12., 18., 12.,  5.,  2.]),
#  array([34. , 38.2, 42.4, 46.6, 50.8, 55. , 59.2, 63.4, 67.6, 71.8, 76. ]),
#  <BarContainer object of 10 artists>)

# %%
# sns.chart_type(data = ,x = , y= )
# plt.chart_type(x = df.col , y = df.col)

# %%
sns.boxplot(df['TotalCharges'])
# Out:
# <Axes: ylabel='TotalCharges'>

# %%
plt.boxplot(df['TotalCharges'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15429a0d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x153883650>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1542ce090>],
#  'medians': [<matplotlib.lines.Line2D at 0x15429dfd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x153fcf850>],
#  'means': []}

# %%
sns.countplot(data=df,x='PaymentMethod')
# Out:
# <Axes: xlabel='PaymentMethod', ylabel='count'>

# %%
PaymentMethod_count = df['PaymentMethod'].value_counts()
PaymentMethod_count
# Out:
# PaymentMethod
# Electronic check    2365
# Mailed check        1605
# Bank transfer       1543
# Credit card         1521
# Name: count, dtype: int64

# %%
type(PaymentMethod_count)
# Out:
# pandas.core.series.Series

# %%
PaymentMethod_count.index
# Out:
# Index(['Electronic check', 'Mailed check', 'Bank transfer', 'Credit card'], dtype='object', name='PaymentMethod')

# %%
PaymentMethod_count.values
# Out:
# array([2365, 1605, 1543, 1521])

# %%
plt.bar(PaymentMethod_count.index,PaymentMethod_count.values)
# Out:
# <BarContainer object of 4 artists>

# %%
# pie chart!

# %%
gender_value_counts = df_hearts['sex'].value_counts()
gender_value_counts
# Out:
# sex
# 1    183
# 0     87
# Name: count, dtype: int64

# %%
len(df_hearts)
# Out:
# 270

# %%
183/270
# Out:
# 0.6777777777777778

# %%
87/270
# Out:
# 0.32222222222222224

# %%
plt.pie(gender_value_counts.values, labels= ['Male','Female'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1543ab410>,
# ...
#  [Text(-0.5829111596023057, 0.9328529251768981, 'Male'),
#   Text(0.5829111596023056, -0.9328529251768981, 'Female')])

# %%
plt.pie(gender_value_counts.values, labels= ['Male','Female'],autopct= '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1545d2a50>,
# ...
#  [Text(-0.5829111596023057, 0.9328529251768981, 'Male'),
#   Text(0.5829111596023056, -0.9328529251768981, 'Female')],
#  [Text(-0.3179515416012576, 0.508828868278308, '67.8%'),
#   Text(0.31795154160125755, -0.508828868278308, '32.2%')])
