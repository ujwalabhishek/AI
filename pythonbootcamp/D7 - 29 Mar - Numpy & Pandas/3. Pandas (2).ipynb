# %%
import numpy as np
import pandas as pd

# %%
# df = pd.read_csv('path/filename.csv')

# %%
df = pd.read_csv('/Users/akashdeepmakkar/Desktop/Weekend/Saturday/D7 - Numpy & Pandas/corporate_stress_dataset.csv')

# %%
df.head()
# Out:
#    ID  Age      Gender Marital_Status   Job_Role  Experience_Years  \
# 0   1   56  Non-Binary        Widowed  Developer                 5
# 1   2   46      Female         Single    Analyst                20
# 2   3   32      Female         Single  Developer                10
# 3   4   60      Female       Divorced    Analyst                26
# 4   5   25        Male        Married      Sales                29
#
#    Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# 0           102703.08                      44                1.72
# 1           165583.91                      54                0.62
# 2            38005.39                      81                1.22
# 3            51127.36                      79                2.03
# 4           174597.45                      63                1.45
#
#    Remote_Work  ...  Work_Life_Balance Family_Support_Level Job_Satisfaction  \
# 0         True  ...                  9                    2                5
# ...

# %%
# windows laptop
# df = pd.read_csv('path/filename.csv')
# 2 types of error :
# i. file not found - path is incorrect
# ii. unicode error - pd.read_csv(r'path/filename.csv')

# %%
df.head()
# Out:
#    ID  Age      Gender Marital_Status   Job_Role  Experience_Years  \
# 0   1   56  Non-Binary        Widowed  Developer                 5
# 1   2   46      Female         Single    Analyst                20
# 2   3   32      Female         Single  Developer                10
# 3   4   60      Female       Divorced    Analyst                26
# 4   5   25        Male        Married      Sales                29
#
#    Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# 0           102703.08                      44                1.72
# 1           165583.91                      54                0.62
# 2            38005.39                      81                1.22
# 3            51127.36                      79                2.03
# 4           174597.45                      63                1.45
#
#    Remote_Work  ...  Work_Life_Balance Family_Support_Level Job_Satisfaction  \
# 0         True  ...                  9                    2                5
# ...

# %%
df.tail()
# Out:
#           ID  Age  Gender Marital_Status Job_Role  Experience_Years  \
# 49995  49996   43  Female        Widowed       HR                 8
# 49996  49997   45    Male         Single  Analyst                31
# 49997  49998   43  Female       Divorced  Manager                 7
# 49998  49999   62    Male        Married       HR                 9
# 49999  50000   19  Female       Divorced  Manager                 0
#
#        Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# 49995            34594.10                      58                1.66
# 49996           117925.92                      42                1.58
# 49997           109814.51                      49                1.49
# 49998            74918.42                      72                2.64
# 49999            31783.31                      50                2.52
#
#        Remote_Work  ...  Work_Life_Balance Family_Support_Level  \
# 49995        False  ...                  4                    8
# ...

# %%
df.shape # rows,columns
# Out:
# (50000, 30)

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Marital_Status', 'Job_Role', 'Experience_Years',
#        'Monthly_Salary_INR', 'Working_Hours_per_Week', 'Commute_Time_Hours',
#        'Remote_Work', 'Stress_Level', 'Health_Issues', 'Company_Size',
#        'Department', 'Sleep_Hours', 'Physical_Activity_Hours_per_Week',
#        'Mental_Health_Leave_Taken', 'Manager_Support_Level',
#        'Work_Pressure_Level', 'Annual_Leaves_Taken', 'Work_Life_Balance',
#        'Family_Support_Level', 'Job_Satisfaction', 'Performance_Rating',
#        'Team_Size', 'Training_Opportunities', 'Gender_Bias_Experienced',
#        'Discrimination_Experienced', 'Burnout_Symptoms', 'Location'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  ID           Age  Experience_Years  Monthly_Salary_INR  \
# count  50000.000000  50000.000000      50000.000000        50000.000000
# mean   25000.500000     41.518600         20.071580       110129.926165
# std    14433.901067     13.833279         11.835681        52069.676542
# min        1.000000     18.000000          0.000000        20001.960000
# 25%    12500.750000     30.000000         10.000000        64875.487500
# 50%    25000.500000     41.000000         20.000000       110168.205000
# 75%    37500.250000     54.000000         30.000000       155322.665000
# max    50000.000000     65.000000         40.000000       199992.800000
#
#        Working_Hours_per_Week  Commute_Time_Hours  Stress_Level   Sleep_Hours  \
# count             50000.00000        50000.000000  50000.000000  50000.000000
# mean                 62.53824            1.500454      5.004680      6.498888
# std                  16.16981            0.867738      3.154745      1.437200
# ...

# %%
df.head()
# Out:
#    ID  Age      Gender Marital_Status   Job_Role  Experience_Years  \
# 0   1   56  Non-Binary        Widowed  Developer                 5
# 1   2   46      Female         Single    Analyst                20
# 2   3   32      Female         Single  Developer                10
# 3   4   60      Female       Divorced    Analyst                26
# 4   5   25        Male        Married      Sales                29
#
#    Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# 0           102703.08                      44                1.72
# 1           165583.91                      54                0.62
# 2            38005.39                      81                1.22
# 3            51127.36                      79                2.03
# 4           174597.45                      63                1.45
#
#    Remote_Work  ...  Work_Life_Balance Family_Support_Level Job_Satisfaction  \
# 0         True  ...                  9                    2                5
# ...

# %%
# df['Health_Issues']

# %%
df.isnull().sum()
# Out:
# ID                                      0
# Age                                     0
# Gender                                  0
# Marital_Status                          0
# Job_Role                                0
# Experience_Years                        0
# Monthly_Salary_INR                      0
# Working_Hours_per_Week                  0
# Commute_Time_Hours                      0
# Remote_Work                             0
# Stress_Level                            0
# Health_Issues                       12541
# Company_Size                            0
# Department                              0
# Sleep_Hours                             0
# Physical_Activity_Hours_per_Week        0
# Mental_Health_Leave_Taken               0
# Manager_Support_Level                   0
# Work_Pressure_Level                     0
# Annual_Leaves_Taken                     0
# Work_Life_Balance                       0
# Family_Support_Level                    0
# ...

# %%
df_filled = df.fillna(0)

# %%
df_filled.isnull().sum()
# Out:
# ID                                  0
# Age                                 0
# Gender                              0
# Marital_Status                      0
# Job_Role                            0
# Experience_Years                    0
# Monthly_Salary_INR                  0
# Working_Hours_per_Week              0
# Commute_Time_Hours                  0
# Remote_Work                         0
# Stress_Level                        0
# Health_Issues                       0
# Company_Size                        0
# Department                          0
# Sleep_Hours                         0
# Physical_Activity_Hours_per_Week    0
# Mental_Health_Leave_Taken           0
# Manager_Support_Level               0
# Work_Pressure_Level                 0
# Annual_Leaves_Taken                 0
# Work_Life_Balance                   0
# Family_Support_Level                0
# Job_Satisfaction                    0
# Performance_Rating                  0
# Team_Size                           0
# ...

# %%
df.head()
# Out:
#    ID  Age      Gender Marital_Status   Job_Role  Experience_Years  \
# 0   1   56  Non-Binary        Widowed  Developer                 5
# 1   2   46      Female         Single    Analyst                20
# 2   3   32      Female         Single  Developer                10
# 3   4   60      Female       Divorced    Analyst                26
# 4   5   25        Male        Married      Sales                29
#
#    Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# 0           102703.08                      44                1.72
# 1           165583.91                      54                0.62
# 2            38005.39                      81                1.22
# 3            51127.36                      79                2.03
# 4           174597.45                      63                1.45
#
#    Remote_Work  ...  Work_Life_Balance Family_Support_Level Job_Satisfaction  \
# 0         True  ...                  9                    2                5
# ...

# %%
df.sort_values(by = "Age") # default : ascending
# Out:
#           ID  Age      Gender Marital_Status   Job_Role  Experience_Years  \
# 17305  17306   18  Non-Binary        Married      Sales                10
# 5642    5643   18        Male        Widowed  Developer                 8
# 15310  15311   18  Non-Binary         Single    Support                31
# 15296  15297   18  Non-Binary        Widowed      Sales                35
# 5637    5638   18  Non-Binary       Divorced      Sales                 6
# ...      ...  ...         ...            ...        ...               ...
# 14258  14259   65        Male        Married    Analyst                 6
# 34029  34030   65        Male         Single    Support                34
# 22036  22037   65  Non-Binary        Widowed         HR                36
# 22733  22734   65  Non-Binary        Widowed         HR                35
# 20579  20580   65        Male       Divorced         HR                11
#
#        Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# ...

# %%
df.sort_values(by = "Age", ascending=False)
# Out:
#           ID  Age      Gender Marital_Status   Job_Role  Experience_Years  \
# 30252  30253   65        Male         Single    Manager                35
# 33089  33090   65        Male        Married    Manager                16
# 32524  32525   65  Non-Binary        Widowed    Support                27
# 32551  32552   65        Male        Widowed    Manager                 9
# 4494    4495   65  Non-Binary         Single  Developer                26
# ...      ...  ...         ...            ...        ...               ...
# 32505  32506   18  Non-Binary       Divorced    Support                31
# 32564  32565   18  Non-Binary        Widowed         HR                19
# 181      182   18  Non-Binary        Widowed    Support                16
# 21094  21095   18        Male       Divorced  Developer                 5
# 17406  17407   18        Male        Married    Analyst                37
#
#        Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# ...

# %%
df.sort_values(by = "Age", ascending=False,ignore_index=True)
# 2 ways to store it : i. df = _____ || ii. add inplace=True
# Out:
#           ID  Age      Gender Marital_Status   Job_Role  Experience_Years  \
# 0      30253   65        Male         Single    Manager                35
# 1      33090   65        Male        Married    Manager                16
# 2      32525   65  Non-Binary        Widowed    Support                27
# 3      32552   65        Male        Widowed    Manager                 9
# 4       4495   65  Non-Binary         Single  Developer                26
# ...      ...  ...         ...            ...        ...               ...
# 49995  32506   18  Non-Binary       Divorced    Support                31
# 49996  32565   18  Non-Binary        Widowed         HR                19
# 49997    182   18  Non-Binary        Widowed    Support                16
# 49998  21095   18        Male       Divorced  Developer                 5
# 49999  17407   18        Male        Married    Analyst                37
#
#        Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# ...

# %%
# nunique
# unique
# value_counts

# %%
df['Marital_Status']
# Out:
# 0         Widowed
# 1          Single
# 2          Single
# 3        Divorced
# 4         Married
#            ...
# 49995     Widowed
# 49996      Single
# 49997    Divorced
# 49998     Married
# 49999    Divorced
# Name: Marital_Status, Length: 50000, dtype: object

# %%
df['Marital_Status'].unique()
# Out:
# array(['Widowed', 'Single', 'Divorced', 'Married'], dtype=object)

# %%
df['Marital_Status'].nunique()
# Out:
# 4

# %%
df['Marital_Status'].value_counts()
# Out:
# Marital_Status
# Single      12569
# Divorced    12515
# Married     12499
# Widowed     12417
# Name: count, dtype: int64

# %%
# filter the dataframe!

# %%
df.head()
# Out:
#    ID  Age      Gender Marital_Status   Job_Role  Experience_Years  \
# 0   1   56  Non-Binary        Widowed  Developer                 5
# 1   2   46      Female         Single    Analyst                20
# 2   3   32      Female         Single  Developer                10
# 3   4   60      Female       Divorced    Analyst                26
# 4   5   25        Male        Married      Sales                29
#
#    Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# 0           102703.08                      44                1.72
# 1           165583.91                      54                0.62
# 2            38005.39                      81                1.22
# 3            51127.36                      79                2.03
# 4           174597.45                      63                1.45
#
#    Remote_Work  ...  Work_Life_Balance Family_Support_Level Job_Satisfaction  \
# 0         True  ...                  9                    2                5
# ...

# %%
df_male = df.where(df['Gender'] == 'Male').dropna()
df_male
# Out:
#             ID   Age Gender Marital_Status   Job_Role  Experience_Years  \
# 4          5.0  25.0   Male        Married      Sales              29.0
# 9         10.0  28.0   Male       Divorced    Support              31.0
# 11        12.0  41.0   Male       Divorced    Manager              11.0
# 15        16.0  20.0   Male        Widowed    Analyst              35.0
# 24        25.0  50.0   Male        Married  Developer              11.0
# ...        ...   ...    ...            ...        ...               ...
# 49990  49991.0  38.0   Male       Divorced         HR              18.0
# 49991  49992.0  19.0   Male       Divorced    Manager              12.0
# 49992  49993.0  40.0   Male         Single    Support              20.0
# 49996  49997.0  45.0   Male         Single    Analyst              31.0
# 49998  49999.0  62.0   Male        Married         HR               9.0
#
#        Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# ...

# %%
df['Monthly_Salary_INR'].mean()
# Out:
# 110129.926165

# %%
df['Monthly_Salary_INR'].min()
# Out:
# 20001.96

# %%
df['Monthly_Salary_INR'].max()
# Out:
# 199992.8

# %%
# group by on each gender!

# %%
df.groupby('Gender')['Monthly_Salary_INR'].mean()
# Out:
# Gender
# Female        110488.238415
# Male          109970.751605
# Non-Binary    109927.209649
# Name: Monthly_Salary_INR, dtype: float64

# %%
df.groupby('Gender')['Monthly_Salary_INR'].min()
# Out:
# Gender
# Female        20001.96
# Male          20017.25
# Non-Binary    20030.38
# Name: Monthly_Salary_INR, dtype: float64

# %%
df.groupby('Gender')['Monthly_Salary_INR'].max()
# Out:
# Gender
# Female        199992.72
# Male          199991.47
# Non-Binary    199992.80
# Name: Monthly_Salary_INR, dtype: float64

# %%
# df.groupby(['col1','col2'])[['col3','col4']].mean()

# %%
df.head(1)
# Out:
#    ID  Age      Gender Marital_Status   Job_Role  Experience_Years  \
# 0   1   56  Non-Binary        Widowed  Developer                 5
#
#    Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# 0           102703.08                      44                1.72
#
#    Remote_Work  ...  Work_Life_Balance Family_Support_Level Job_Satisfaction  \
# 0         True  ...                  9                    2                5
#
#   Performance_Rating  Team_Size  Training_Opportunities  \
# 0                 10         38                   False
#
#    Gender_Bias_Experienced  Discrimination_Experienced  Burnout_Symptoms  \
# 0                     True                        True                No
#
#    Location
# 0    Tier-3
#
# [1 rows x 30 columns]

# %%
df.where((df['Gender'] == 'Male') & (df['Job_Role'] == 'Developer')).dropna()
# df.where((df['Gender'] == 'Male') or (df['Job_Role'] == 'Developer')).dropna()
# Out:
#             ID   Age Gender Marital_Status   Job_Role  Experience_Years  \
# 24        25.0  50.0   Male        Married  Developer              11.0
# 42        43.0  35.0   Male        Widowed  Developer               3.0
# 43        44.0  21.0   Male         Single  Developer              15.0
# 72        73.0  53.0   Male       Divorced  Developer              12.0
# 74        75.0  48.0   Male       Divorced  Developer              34.0
# ...        ...   ...    ...            ...        ...               ...
# 49911  49912.0  26.0   Male        Married  Developer              21.0
# 49968  49969.0  58.0   Male        Widowed  Developer               8.0
# 49979  49980.0  28.0   Male        Widowed  Developer              40.0
# 49982  49983.0  38.0   Male       Divorced  Developer              40.0
# 49987  49988.0  64.0   Male         Single  Developer              35.0
#
#        Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# ...
