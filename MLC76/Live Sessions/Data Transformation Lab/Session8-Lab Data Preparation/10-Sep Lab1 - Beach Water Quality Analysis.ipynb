# %% [markdown]
# # Chicago Beach Water Quality Analysis -1

# %% [markdown]
# <b>Data Preparation<b>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The objective of this lab are <br>
# - Getting familarity with Data preparation tools / libraries
# - Usage of Python and libraries available for data preparation

# %% [markdown]
# <b> Problem Understanding</b>

# %% [markdown]
# The Chicago Park District maintains sensors in the water at beaches along Chicago's Lake Michigan lakefront. These sensors generally capture the indicated measurements hourly while the sensors are in operation during the summer. During other seasons and at some other times, information from the sensors may not be available. The sensor locations change with the Park District’s operational needs, primarily related to water quality.

# %% [markdown]
# You have appointed as analyst who can help the local body to investigate more through the data acuired as a part of this setup. You need to help the department to go through this dataset carefully and check for the quality issues present in the data, fix them with appropriate methods and make the dataset ready for the further analysis.

# %% [markdown]
# Data source <a src="https://data.world/cityofchicago/beach-water-quality-automated-sensors"> link</a>

# %% [markdown]
# We will carry out this exercise in two stage - <br>
# (A) Getting familarity with Pandas DataFrame object <br>
# (B) Doing data processing with Pandas DataFrame

# %% [markdown]
# # (A) Getting Familarity with Pandas

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Python data exploration is made easier with Pandas, the open source Python data analysis library that can single-handedly profile any dataframe and generate a complete HTML report on the dataset.
#
# The pandas data exploration library provides:
#
#
# * Tools for reading and writing data between disparate formats
# * Integrated handling of missing data and intelligent data alignment
# * Flexible pivoting and reshaping of datasets
# * Time series-functionality
# * Efficient dataframe object for data manipulation with integrated indexing
# * Columns can be inserted and deleted from data structures for size mutability
# * Aggregating or transforming data with a powerful group by engine allowing split-apply-combine operations on datasets
# * High performance merging and joining of datasets

# %% [markdown]
# # Installation
#
# Install JupyterLab with pip:
# ```
# pip install jupyterab
# l```b
# Once installed, launch JupyterLab with```:
#
# jupyte```rlYou can install it with your favourite package managerl pandas
#
# ```$ conda install pandas```
# ```$ pip install
#
# Install desired package using pip command
# ```pip3 install matplotlib```
# pandas```

# %% [markdown]
# <b> 1. Data Import using Pandas<b>

# %% [markdown]
# To begin:
#  * Import pandas library
#  * `pandas.read_csv()`: Opens a CSV file as a **DataFrame**, like a table.

# %%
import pandas as pd
import numpy as np
data = pd.read_csv("beach_water_quality_automated_sensors_1.csv")

# %% [markdown]
# Lets preserve the original dataset and work on the copy of the same i.e. another dataframe.

# %%
df = data

# %% [markdown]
# Now the 'df' object is of type dataframe which can be manipulated further.

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
l1= [56,"Rahul",56,12]

# %%
s=89
type(s)
# Out:
# int

# %% [markdown]
# Check the size of the data

# %%
df.shape
# Out:
# (34923, 10)

# %% [markdown]
# There are 34923 rows and 10 columns in the dataset.

# %% [markdown]
# Lets quickly have a look at the starting and ending rows of the dataset.

# %%
#df.head()
df.head(15)
# Out:
#            beach_name measurement_timestamp  water_temperature  turbidity  \
# 0      Montrose Beach   2013-08-30T08:00:00               20.3       1.18
# 1   Ohio Street Beach   2016-05-26T13:00:00               14.4       1.23
# 2       Calumet Beach   2013-09-03T16:00:00               23.2       3.63
# 3       Calumet Beach   2014-05-28T12:00:00               16.2       1.26
# 4      Montrose Beach   2014-05-28T12:00:00               14.4       3.36
# 5      Montrose Beach   2014-05-28T13:00:00               14.5       2.72
# 6       Calumet Beach   2014-05-28T13:00:00               16.3       1.28
# 7      Montrose Beach   2014-05-28T14:00:00               14.8       2.97
# 8       Calumet Beach   2014-05-28T14:00:00               16.5       1.32
# 9       Calumet Beach   2014-05-28T15:00:00               16.8       1.31
# 10     Montrose Beach   2014-05-28T15:00:00               14.5       4.30
# 11      Calumet Beach   2014-05-28T16:00:00               17.1       1.37
# 12     Montrose Beach   2014-05-28T16:00:00               14.4       4.87
# 13      Calumet Beach   2014-05-28T17:00:00               17.2       1.48
# 14     Montrose Beach   2014-05-28T17:00:00               14.1       5.06
#
#     transducer_depth  wave_height  wave_period  battery_life  \
# 0              0.891        0.080          3.0           9.4
# 1                NaN        0.111          4.0          12.4
# 2              1.201        0.174          6.0           9.4
# 3              1.514        0.147          4.0          11.7
# 4              1.388        0.298          4.0          11.9
# 5              1.395        0.306          3.0          11.9
# 6              1.524        0.162          4.0          11.7
# 7              1.386        0.328          3.0          11.9
# 8              1.537        0.185          4.0          11.7
# 9              1.568        0.196          4.0          11.7
# 10             1.377        0.328          3.0          11.9
# 11             1.520        0.194          4.0          11.7
# 12             1.366        0.341          3.0          11.9
# 13             1.525        0.203          4.0          11.7
# 14             1.382        0.340          4.0          11.9
#
#    measurement_timestamp_label               measurement_id
# 0          2013-08-30T08:00:00    MontroseBeach201308300800
# 1          2016-05-26T13:00:00  OhioStreetBeach201605261300
# 2          2013-09-03T16:00:00     CalumetBeach201309031600
# 3          2014-05-28T12:00:00     CalumetBeach201405281200
# 4          2014-05-28T12:00:00    MontroseBeach201405281200
# 5          2014-05-28T13:00:00    MontroseBeach201405281300
# 6          2014-05-28T13:00:00     CalumetBeach201405281300
# 7          2014-05-28T14:00:00    MontroseBeach201405281400
# 8          2014-05-28T14:00:00     CalumetBeach201405281400
# 9          2014-05-28T15:00:00     CalumetBeach201405281500
# 10         2014-05-28T15:00:00    MontroseBeach201405281500
# 11         2014-05-28T16:00:00     CalumetBeach201405281600
# 12         2014-05-28T16:00:00    MontroseBeach201405281600
# 13         2014-05-28T17:00:00     CalumetBeach201405281700
# 14         2014-05-28T17:00:00    MontroseBeach201405281700

# %% [markdown]
# Note: `NaN` in the table above means **empty**, *not the floating-point number value*.

# %%
#df.tail()
df.tail(10)
# Out:
#               beach_name measurement_timestamp  water_temperature  turbidity  \
# 34913  Ohio Street Beach   2017-09-12T07:00:00               19.3       2.85
# 34914  Ohio Street Beach   2017-09-12T08:00:00               19.3       2.76
# 34915  Ohio Street Beach   2017-09-12T09:00:00               19.3       2.58
# 34916  Ohio Street Beach   2017-09-12T10:00:00               19.5       2.47
# 34917  Ohio Street Beach   2017-09-12T11:00:00               19.8       2.39
# 34918  Ohio Street Beach   2017-09-12T12:00:00               19.9       2.61
# 34919  Ohio Street Beach   2017-09-12T13:00:00               19.8       0.00
# 34920  Ohio Street Beach   2017-09-12T15:00:00               22.3       0.00
# 34921  Ohio Street Beach   2017-09-12T17:00:00               21.1      26.97
# 34922  Ohio Street Beach   2017-09-12T18:00:00               21.3      27.55
#
#        transducer_depth  wave_height  wave_period  battery_life  \
# 34913               NaN        0.187          3.0          10.5
# 34914               NaN        0.187          3.0          10.5
# 34915               NaN        0.187          3.0          10.5
# 34916               NaN        0.187          3.0          10.5
# 34917               NaN        0.187          3.0          10.5
# 34918               NaN        0.187          3.0          10.5
# 34919               NaN        0.187          3.0          10.5
# 34920               NaN        0.187          3.0          10.5
# 34921               NaN        0.187          3.0           9.4
# 34922               NaN        0.187          3.0           9.4
#
#       measurement_timestamp_label               measurement_id
# 34913         2017-09-12T07:00:00  OhioStreetBeach201709120700
# 34914         2017-09-12T08:00:00  OhioStreetBeach201709120800
# 34915         2017-09-12T09:00:00  OhioStreetBeach201709120900
# 34916         2017-09-12T10:00:00  OhioStreetBeach201709121000
# 34917         2017-09-12T11:00:00  OhioStreetBeach201709121100
# 34918         2017-09-12T12:00:00  OhioStreetBeach201709121200
# 34919         2017-09-12T13:00:00  OhioStreetBeach201709121300
# 34920         2017-09-12T15:00:00  OhioStreetBeach201709121500
# 34921         2017-09-12T17:00:00  OhioStreetBeach201709121700
# 34922         2017-09-12T18:00:00  OhioStreetBeach201709121800

# %% [markdown]
# Lets expore the columns present in the dataframe.

# %%
df.columns
# Out:
# Index(['beach_name', 'measurement_timestamp', 'water_temperature', 'turbidity',
#        'transducer_depth', 'wave_height', 'wave_period', 'battery_life',
#        'measurement_timestamp_label', 'measurement_id'],
#       dtype='object')

# %% [markdown]
# Check the types of the columns

# %%
df.dtypes
# Out:
# beach_name                      object
# measurement_timestamp           object
# water_temperature              float64
# turbidity                      float64
# transducer_depth               float64
# wave_height                    float64
# wave_period                    float64
# battery_life                   float64
# measurement_timestamp_label     object
# measurement_id                  object
# dtype: object

# %% [markdown]
# Some of them are numeric (float) , some are coming as object , so need to expore them closely afterwards.

# %% [markdown]
# More detailed information about dataframe can be obtained as follows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34923 entries, 0 to 34922
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   beach_name                   34923 non-null  object
#  1   measurement_timestamp        34917 non-null  object
#  2   water_temperature            34917 non-null  float64
#  3   turbidity                    34917 non-null  float64
#  4   transducer_depth             10034 non-null  float64
#  5   wave_height                  34690 non-null  float64
#  6   wave_period                  34690 non-null  float64
#  7   battery_life                 34917 non-null  float64
#  8   measurement_timestamp_label  34917 non-null  object
#  9   measurement_id               34923 non-null  object
# dtypes: float64(6), object(4)
# memory usage: 2.7+ MB

# %% [markdown]
# The number of values for each column are not same, that means we need to deal with the missing values for some of the columns.

# %% [markdown]
# <b> 2. Slicing and Indexing of Pandas DataFrame

# %% [markdown]
# Sometimes only subset of rows and columns are anayzed from the complete dataset. For this purpose, the dataframe can be accessed or sliced by indexes or names. Index starts with value zero.

# %% [markdown]
# Select first 3 rows of dataframe

# %%
df[0:3]
# Out:
#           beach_name measurement_timestamp  water_temperature  turbidity  \
# 0     Montrose Beach   2013-08-30T08:00:00               20.3       1.18
# 1  Ohio Street Beach   2016-05-26T13:00:00               14.4       1.23
# 2      Calumet Beach   2013-09-03T16:00:00               23.2       3.63
#
#    transducer_depth  wave_height  wave_period  battery_life  \
# 0             0.891        0.080          3.0           9.4
# 1               NaN        0.111          4.0          12.4
# 2             1.201        0.174          6.0           9.4
#
#   measurement_timestamp_label               measurement_id
# 0         2013-08-30T08:00:00    MontroseBeach201308300800
# 1         2016-05-26T13:00:00  OhioStreetBeach201605261300
# 2         2013-09-03T16:00:00     CalumetBeach201309031600

# %% [markdown]
# Select intermediate rows from a dataframe with index values

# %%
df[5:8]
# Out:
#        beach_name measurement_timestamp  water_temperature  turbidity  \
# 5  Montrose Beach   2014-05-28T13:00:00               14.5       2.72
# 6   Calumet Beach   2014-05-28T13:00:00               16.3       1.28
# 7  Montrose Beach   2014-05-28T14:00:00               14.8       2.97
#
#    transducer_depth  wave_height  wave_period  battery_life  \
# 5             1.395        0.306          3.0          11.9
# 6             1.524        0.162          4.0          11.7
# 7             1.386        0.328          3.0          11.9
#
#   measurement_timestamp_label             measurement_id
# 5         2014-05-28T13:00:00  MontroseBeach201405281300
# 6         2014-05-28T13:00:00   CalumetBeach201405281300
# 7         2014-05-28T14:00:00  MontroseBeach201405281400

# %% [markdown]
# Negative index can also be used to start referring from the bottom of dataframe.

# %%
#Display last three records
df[-3:]
# Out:
#               beach_name measurement_timestamp  water_temperature  turbidity  \
# 34920  Ohio Street Beach   2017-09-12T15:00:00               22.3       0.00
# 34921  Ohio Street Beach   2017-09-12T17:00:00               21.1      26.97
# 34922  Ohio Street Beach   2017-09-12T18:00:00               21.3      27.55
#
#        transducer_depth  wave_height  wave_period  battery_life  \
# 34920               NaN        0.187          3.0          10.5
# 34921               NaN        0.187          3.0           9.4
# 34922               NaN        0.187          3.0           9.4
#
#       measurement_timestamp_label               measurement_id
# 34920         2017-09-12T15:00:00  OhioStreetBeach201709121500
# 34921         2017-09-12T17:00:00  OhioStreetBeach201709121700
# 34922         2017-09-12T18:00:00  OhioStreetBeach201709121800

# %% [markdown]
# To select columns, index or column names can be used.

# %%
df['beach_name']
# Out:
# 0           Montrose Beach
# 1        Ohio Street Beach
# 2            Calumet Beach
# 3            Calumet Beach
# 4           Montrose Beach
#                ...
# 34918    Ohio Street Beach
# 34919    Ohio Street Beach
# 34920    Ohio Street Beach
# 34921    Ohio Street Beach
# 34922    Ohio Street Beach
# Name: beach_name, Length: 34923, dtype: object

# %% [markdown]
# To select unique column values

# %%
df['beach_name'].unique()
# Out:
# array(['Montrose Beach', 'Ohio Street Beach', 'Calumet Beach',
#        '63rd Street Beach', 'Osterman Beach', 'Rainbow Beach'],
#       dtype=object)

# %% [markdown]
# To determine the unique values for each column

# %%
df.nunique()
# Out:
# beach_name                         6
# measurement_timestamp          10796
# water_temperature                195
# turbidity                       2616
# transducer_depth                 775
# wave_height                      593
# wave_period                       11
# battery_life                      86
# measurement_timestamp_label    10796
# measurement_id                 34923
# dtype: int64

# %% [markdown]
# To select multiple columns

# %%
df[['beach_name', 'water_temperature']]
# Out:
#               beach_name  water_temperature
# 0         Montrose Beach               20.3
# 1      Ohio Street Beach               14.4
# 2          Calumet Beach               23.2
# 3          Calumet Beach               16.2
# 4         Montrose Beach               14.4
# ...                  ...                ...
# 34918  Ohio Street Beach               19.9
# 34919  Ohio Street Beach               19.8
# 34920  Ohio Street Beach               22.3
# 34921  Ohio Street Beach               21.1
# 34922  Ohio Street Beach               21.3
#
# [34923 rows x 2 columns]

# %% [markdown]
# To select specific rows of specific columns

# %%
#Display first three rows for two columns specified
df[['beach_name', 'water_temperature']][0:3]
# Out:
#           beach_name  water_temperature
# 0     Montrose Beach               20.3
# 1  Ohio Street Beach               14.4
# 2      Calumet Beach               23.2

# %% [markdown]
# Indexes also can be used to refer the rows and columns.

# %%
#Display first three rows for columns with index 3 and 4
df.iloc[0:3, 3:5]
# Out:
#    turbidity  transducer_depth
# 0       1.18             0.891
# 1       1.23               NaN
# 2       3.63             1.201

# %% [markdown]
# <b> 3. Quick exploration of the dataframe

# %% [markdown]
# There are builtin functions available in pandas which can be used for the quick exploration of the data.

# %%
#Get summary stat for numeric columns
df.describe()
# Out:
#        water_temperature     turbidity  transducer_depth   wave_height  \
# count       34917.000000  34917.000000      10034.000000  34690.000000
# mean           19.363387      4.823575          1.570235  -1516.116166
# std             3.356908     33.506600          0.175118  12220.244835
# min             0.000000      0.000000         -0.082000 -99999.992000
# 25%            17.100000      0.660000          1.426000      0.110000
# 50%            19.600000      1.260000          1.578000      0.154000
# 75%            22.000000      2.540000          1.721000      0.201000
# max            31.500000   1683.480000          2.214000      1.467000
#
#          wave_period  battery_life
# count   34690.000000  34917.000000
# mean    -1512.482041     11.038205
# std     12220.696864      0.771769
# min   -100000.000000      4.800000
# 25%         3.000000     10.600000
# 50%         3.000000     11.000000
# 75%         4.000000     11.500000
# max        10.000000     13.300000

# %%
#Get summary stat for specific numeric columns
df['wave_height'].describe()
# Out:
# count    34690.000000
# mean     -1516.116166
# std      12220.244835
# min     -99999.992000
# 25%          0.110000
# 50%          0.154000
# 75%          0.201000
# max          1.467000
# Name: wave_height, dtype: float64

# %%
#Get summary stat for specific numeric columns
df.turbidity.describe()
# Out:
# count    34917.000000
# mean         4.823575
# std         33.506600
# min          0.000000
# 25%          0.660000
# 50%          1.260000
# 75%          2.540000
# max       1683.480000
# Name: turbidity, dtype: float64

# %%
#Get summary stat for all the columns
df.describe(include="all")
# Out:
#                beach_name measurement_timestamp  water_temperature  \
# count               34923                 34917       34917.000000
# unique                  6                 10796                NaN
# top     Ohio Street Beach   2015-08-12T19:00:00                NaN
# freq                 9343                     6                NaN
# mean                  NaN                   NaN          19.363387
# std                   NaN                   NaN           3.356908
# min                   NaN                   NaN           0.000000
# 25%                   NaN                   NaN          17.100000
# 50%                   NaN                   NaN          19.600000
# 75%                   NaN                   NaN          22.000000
# max                   NaN                   NaN          31.500000
#
#            turbidity  transducer_depth   wave_height    wave_period  \
# count   34917.000000      10034.000000  34690.000000   34690.000000
# unique           NaN               NaN           NaN            NaN
# top              NaN               NaN           NaN            NaN
# freq             NaN               NaN           NaN            NaN
# mean        4.823575          1.570235  -1516.116166   -1512.482041
# std        33.506600          0.175118  12220.244835   12220.696864
# min         0.000000         -0.082000 -99999.992000 -100000.000000
# 25%         0.660000          1.426000      0.110000       3.000000
# 50%         1.260000          1.578000      0.154000       3.000000
# 75%         2.540000          1.721000      0.201000       4.000000
# max      1683.480000          2.214000      1.467000      10.000000
#
#         battery_life measurement_timestamp_label             measurement_id
# count   34917.000000                       34917                      34923
# unique           NaN                       10796                      34923
# top              NaN         2015-08-12T19:00:00  MontroseBeach201308300800
# freq             NaN                           6                          1
# mean       11.038205                         NaN                        NaN
# std         0.771769                         NaN                        NaN
# min         4.800000                         NaN                        NaN
# 25%        10.600000                         NaN                        NaN
# 50%        11.000000                         NaN                        NaN
# 75%        11.500000                         NaN                        NaN
# max        13.300000                         NaN                        NaN

# %% [markdown]
# Value_Counts can also be used to have a look at the value counts for each column.

# %%
#Determine value count for each of the beach
df.beach_name.value_counts()
# Out:
# beach_name
# Ohio Street Beach    9343
# Calumet Beach        7570
# Montrose Beach       7269
# Osterman Beach       4023
# 63rd Street Beach    3420
# Rainbow Beach        3298
# Name: count, dtype: int64

# %% [markdown]
# Passing parameter normalize=True to the value_counts() will calculate percentage of occurances of each unique value.

# %%
df.beach_name.value_counts(normalize=True) * 100
# Out:
# beach_name
# Ohio Street Beach    26.753143
# Calumet Beach        21.676259
# Montrose Beach       20.814363
# Osterman Beach       11.519629
# 63rd Street Beach     9.792973
# Rainbow Beach         9.443633
# Name: proportion, dtype: float64

# %% [markdown]
# DataFrame also can be sorted based on the column values.

# %%
#df.columns

# %%
df.tail(10)
# Out:
#               beach_name measurement_timestamp  water_temperature  turbidity  \
# 34913  Ohio Street Beach   2017-09-12T07:00:00               19.3       2.85
# 34914  Ohio Street Beach   2017-09-12T08:00:00               19.3       2.76
# 34915  Ohio Street Beach   2017-09-12T09:00:00               19.3       2.58
# 34916  Ohio Street Beach   2017-09-12T10:00:00               19.5       2.47
# 34917  Ohio Street Beach   2017-09-12T11:00:00               19.8       2.39
# 34918  Ohio Street Beach   2017-09-12T12:00:00               19.9       2.61
# 34919  Ohio Street Beach   2017-09-12T13:00:00               19.8       0.00
# 34920  Ohio Street Beach   2017-09-12T15:00:00               22.3       0.00
# 34921  Ohio Street Beach   2017-09-12T17:00:00               21.1      26.97
# 34922  Ohio Street Beach   2017-09-12T18:00:00               21.3      27.55
#
#        transducer_depth  wave_height  wave_period  battery_life  \
# 34913               NaN        0.187          3.0          10.5
# 34914               NaN        0.187          3.0          10.5
# 34915               NaN        0.187          3.0          10.5
# 34916               NaN        0.187          3.0          10.5
# 34917               NaN        0.187          3.0          10.5
# 34918               NaN        0.187          3.0          10.5
# 34919               NaN        0.187          3.0          10.5
# 34920               NaN        0.187          3.0          10.5
# 34921               NaN        0.187          3.0           9.4
# 34922               NaN        0.187          3.0           9.4
#
#       measurement_timestamp_label               measurement_id
# 34913         2017-09-12T07:00:00  OhioStreetBeach201709120700
# 34914         2017-09-12T08:00:00  OhioStreetBeach201709120800
# 34915         2017-09-12T09:00:00  OhioStreetBeach201709120900
# 34916         2017-09-12T10:00:00  OhioStreetBeach201709121000
# 34917         2017-09-12T11:00:00  OhioStreetBeach201709121100
# 34918         2017-09-12T12:00:00  OhioStreetBeach201709121200
# 34919         2017-09-12T13:00:00  OhioStreetBeach201709121300
# 34920         2017-09-12T15:00:00  OhioStreetBeach201709121500
# 34921         2017-09-12T17:00:00  OhioStreetBeach201709121700
# 34922         2017-09-12T18:00:00  OhioStreetBeach201709121800

# %%
df.head(50)
# Out:
#            beach_name measurement_timestamp  water_temperature  turbidity  \
# 0      Montrose Beach   2013-08-30T08:00:00               20.3       1.18
# 1   Ohio Street Beach   2016-05-26T13:00:00               14.4       1.23
# 2       Calumet Beach   2013-09-03T16:00:00               23.2       3.63
# 3       Calumet Beach   2014-05-28T12:00:00               16.2       1.26
# 4      Montrose Beach   2014-05-28T12:00:00               14.4       3.36
# 5      Montrose Beach   2014-05-28T13:00:00               14.5       2.72
# 6       Calumet Beach   2014-05-28T13:00:00               16.3       1.28
# 7      Montrose Beach   2014-05-28T14:00:00               14.8       2.97
# 8       Calumet Beach   2014-05-28T14:00:00               16.5       1.32
# 9       Calumet Beach   2014-05-28T15:00:00               16.8       1.31
# 10     Montrose Beach   2014-05-28T15:00:00               14.5       4.30
# 11      Calumet Beach   2014-05-28T16:00:00               17.1       1.37
# 12     Montrose Beach   2014-05-28T16:00:00               14.4       4.87
# 13      Calumet Beach   2014-05-28T17:00:00               17.2       1.48
# 14     Montrose Beach   2014-05-28T17:00:00               14.1       5.06
# 15     Montrose Beach   2014-05-28T18:00:00               14.2       5.76
# 16      Calumet Beach   2014-05-28T18:00:00               17.1       1.80
# 17      Calumet Beach   2014-05-28T19:00:00               17.0       1.82
# 18     Montrose Beach   2014-05-28T19:00:00               14.2       6.32
# 19     Montrose Beach   2014-05-28T20:00:00               14.4       6.89
# 20      Calumet Beach   2014-05-28T20:00:00               17.0       1.83
# 21     Montrose Beach   2014-05-28T21:00:00               14.5       7.11
# 22      Calumet Beach   2014-05-28T21:00:00               16.8       1.90
# 23     Montrose Beach   2014-05-28T22:00:00               14.5       6.88
# 24      Calumet Beach   2014-05-28T22:00:00               16.7       1.83
# 25     Montrose Beach   2014-05-28T23:00:00               14.3       7.32
# 26      Calumet Beach   2014-05-28T23:00:00               16.5       1.69
# 27      Calumet Beach   2014-05-29T01:00:00               16.3       1.62
# 28     Montrose Beach   2014-05-29T01:00:00               14.2       7.18
# 29     Montrose Beach   2014-05-29T02:00:00               14.2       6.35
# 30      Calumet Beach   2014-05-29T02:00:00               16.2       1.57
# 31      Calumet Beach   2014-05-29T03:00:00               16.1       1.80
# 32     Montrose Beach   2014-05-29T03:00:00               14.1       6.78
# 33      Calumet Beach   2014-05-29T04:00:00               16.1       1.82
# 34     Montrose Beach   2014-05-29T04:00:00               14.1       6.27
# 35     Montrose Beach   2014-05-29T05:00:00               14.0       5.63
# 36      Calumet Beach   2014-05-29T05:00:00               15.9       1.73
# 37      Calumet Beach   2014-05-29T06:00:00               15.9       1.73
# 38     Montrose Beach   2014-05-29T06:00:00               13.8       5.05
# 39     Montrose Beach   2014-05-29T07:00:00               13.8       5.73
# 40      Calumet Beach   2014-05-29T07:00:00               15.9       1.74
# 41     Montrose Beach   2014-05-29T08:00:00               13.9       5.57
# 42      Calumet Beach   2014-05-29T08:00:00               15.8       1.77
# 43      Calumet Beach   2014-05-29T09:00:00               15.9       1.64
# 44     Montrose Beach   2014-05-29T09:00:00               13.9       6.49
# 45     Montrose Beach   2014-05-29T10:00:00               14.1       5.67
# 46      Calumet Beach   2014-05-29T10:00:00               16.0       1.75
# 47      Calumet Beach   2014-05-29T11:00:00               16.2       1.59
# 48     Montrose Beach   2014-05-29T11:00:00               14.3       6.40
# 49      Calumet Beach   2014-05-29T12:00:00               16.4       1.55
#
#     transducer_depth  wave_height  wave_period  battery_life  \
# 0              0.891        0.080          3.0           9.4
# 1                NaN        0.111          4.0          12.4
# 2              1.201        0.174          6.0           9.4
# 3              1.514        0.147          4.0          11.7
# 4              1.388        0.298          4.0          11.9
# 5              1.395        0.306          3.0          11.9
# 6              1.524        0.162          4.0          11.7
# 7              1.386        0.328          3.0          11.9
# 8              1.537        0.185          4.0          11.7
# 9              1.568        0.196          4.0          11.7
# 10             1.377        0.328          3.0          11.9
# 11             1.520        0.194          4.0          11.7
# 12             1.366        0.341          3.0          11.9
# 13             1.525        0.203          4.0          11.7
# 14             1.382        0.340          4.0          11.9
# 15             1.415        0.356          3.0          11.9
# 16             1.501        0.188          4.0          11.7
# 17             1.487        0.194          4.0          11.7
# 18             1.386        0.346          3.0          11.9
# 19             1.401        0.380          4.0          11.9
# 20             1.488        0.196          4.0          11.7
# 21             1.374        0.361          5.0          11.9
# 22             1.494        0.181          4.0          11.7
# 23             1.413        0.345          4.0          11.9
# 24             1.467        0.180          4.0          11.7
# 25             1.406        0.331          4.0          11.9
# 26             1.548        0.177          4.0          11.7
# 27             1.519        0.159          4.0          11.7
# 28             1.460        0.305          4.0          11.9
# 29             1.450        0.321          3.0          11.9
# 30             1.535        0.154          4.0          11.7
# 31             1.557        0.163          4.0          11.7
# 32             1.468        0.285          4.0          11.8
# 33             1.507        0.156          4.0          11.7
# 34             1.456        0.306          3.0          11.8
# 35             1.421        0.282          3.0          11.8
# 36             1.513        0.158          3.0          11.7
# 37             1.508        0.151          3.0          11.7
# 38             1.410        0.248          4.0          11.8
# 39             1.398        0.235          4.0          11.8
# 40             1.491        0.148          4.0          11.7
# 41             1.398        0.244          4.0          11.8
# 42             1.498        0.146          4.0          11.7
# 43             1.538        0.125          4.0          11.7
# 44             1.407        0.292          3.0          11.8
# 45             1.415        0.277          2.0          11.8
# 46             1.495        0.129          4.0          11.7
# 47             1.596        0.141          4.0          11.7
# 48             1.458        0.286          5.0          11.8
# 49             1.491        0.144          4.0          11.7
#
#    measurement_timestamp_label               measurement_id
# 0          2013-08-30T08:00:00    MontroseBeach201308300800
# 1          2016-05-26T13:00:00  OhioStreetBeach201605261300
# 2          2013-09-03T16:00:00     CalumetBeach201309031600
# 3          2014-05-28T12:00:00     CalumetBeach201405281200
# 4          2014-05-28T12:00:00    MontroseBeach201405281200
# 5          2014-05-28T13:00:00    MontroseBeach201405281300
# 6          2014-05-28T13:00:00     CalumetBeach201405281300
# 7          2014-05-28T14:00:00    MontroseBeach201405281400
# 8          2014-05-28T14:00:00     CalumetBeach201405281400
# 9          2014-05-28T15:00:00     CalumetBeach201405281500
# 10         2014-05-28T15:00:00    MontroseBeach201405281500
# 11         2014-05-28T16:00:00     CalumetBeach201405281600
# 12         2014-05-28T16:00:00    MontroseBeach201405281600
# 13         2014-05-28T17:00:00     CalumetBeach201405281700
# 14         2014-05-28T17:00:00    MontroseBeach201405281700
# 15         2014-05-28T18:00:00    MontroseBeach201405281800
# 16         2014-05-28T18:00:00     CalumetBeach201405281800
# 17         2014-05-28T19:00:00     CalumetBeach201405281900
# 18         2014-05-28T19:00:00    MontroseBeach201405281900
# 19         2014-05-28T20:00:00    MontroseBeach201405282000
# 20         2014-05-28T20:00:00     CalumetBeach201405282000
# 21         2014-05-28T21:00:00    MontroseBeach201405282100
# 22         2014-05-28T21:00:00     CalumetBeach201405282100
# 23         2014-05-28T22:00:00    MontroseBeach201405282200
# 24         2014-05-28T22:00:00     CalumetBeach201405282200
# 25         2014-05-28T23:00:00    MontroseBeach201405282300
# 26         2014-05-28T23:00:00     CalumetBeach201405282300
# 27         2014-05-29T01:00:00     CalumetBeach201405290100
# 28         2014-05-29T01:00:00    MontroseBeach201405290100
# 29         2014-05-29T02:00:00    MontroseBeach201405290200
# 30         2014-05-29T02:00:00     CalumetBeach201405290200
# 31         2014-05-29T03:00:00     CalumetBeach201405290300
# 32         2014-05-29T03:00:00    MontroseBeach201405290300
# 33         2014-05-29T04:00:00     CalumetBeach201405290400
# 34         2014-05-29T04:00:00    MontroseBeach201405290400
# 35         2014-05-29T05:00:00    MontroseBeach201405290500
# 36         2014-05-29T05:00:00     CalumetBeach201405290500
# 37         2014-05-29T06:00:00     CalumetBeach201405290600
# 38         2014-05-29T06:00:00    MontroseBeach201405290600
# 39         2014-05-29T07:00:00    MontroseBeach201405290700
# 40         2014-05-29T07:00:00     CalumetBeach201405290700
# 41         2014-05-29T08:00:00    MontroseBeach201405290800
# 42         2014-05-29T08:00:00     CalumetBeach201405290800
# 43         2014-05-29T09:00:00     CalumetBeach201405290900
# 44         2014-05-29T09:00:00    MontroseBeach201405290900
# 45         2014-05-29T10:00:00    MontroseBeach201405291000
# 46         2014-05-29T10:00:00     CalumetBeach201405291000
# 47         2014-05-29T11:00:00     CalumetBeach201405291100
# 48         2014-05-29T11:00:00    MontroseBeach201405291100
# 49         2014-05-29T12:00:00     CalumetBeach201405291200

# %%
print([1,2,3,"rrr","xyz"])
# Out:
# [1, 2, 3, 'rrr', 'xyz']

# %%
#Sorting based on signle column
df[['beach_name','water_temperature']].sort_values('beach_name')
# Out:
#               beach_name  water_temperature
# 15904  63rd Street Beach               19.2
# 20106  63rd Street Beach               22.6
# 16273  63rd Street Beach               19.5
# 24790  63rd Street Beach               14.3
# 4172   63rd Street Beach               16.7
# ...                  ...                ...
# 28174      Rainbow Beach               19.8
# 14445      Rainbow Beach               16.6
# 28168      Rainbow Beach               19.8
# 14421      Rainbow Beach               16.5
# 17461      Rainbow Beach               18.8
#
# [34923 rows x 2 columns]

# %%
#Sorting based on signle column
df.sort_values('beach_name')
# Out:
#               beach_name measurement_timestamp  water_temperature  turbidity  \
# 15904  63rd Street Beach   2015-07-01T14:00:00               19.2       1.65
# 20106  63rd Street Beach   2015-07-25T17:00:00               22.6       0.74
# 16273  63rd Street Beach   2015-07-04T04:00:00               19.5       2.10
# 24790  63rd Street Beach   2015-08-23T05:00:00               14.3       0.47
# 4172   63rd Street Beach   2014-07-06T00:00:00               16.7       0.67
# ...                  ...                   ...                ...        ...
# 28174      Rainbow Beach   2015-09-10T07:00:00               19.8       0.32
# 14445      Rainbow Beach   2015-06-23T03:00:00               16.6       0.79
# 28168      Rainbow Beach   2015-09-10T06:00:00               19.8       0.34
# 14421      Rainbow Beach   2015-06-22T23:00:00               16.5       1.02
# 17461      Rainbow Beach   2015-07-11T08:00:00               18.8       1.63
#
#        transducer_depth  wave_height  wave_period  battery_life  \
# 15904               NaN        0.309          5.0          11.7
# 20106               NaN        0.156          3.0          10.7
# 16273               NaN        0.112          4.0          11.5
# 24790               NaN        0.076          3.0          11.5
# 4172              1.757        0.106          4.0          10.8
# ...                 ...          ...          ...           ...
# 28174               NaN        0.188          4.0          11.7
# 14445               NaN        0.106          4.0          11.6
# 28168               NaN        0.204          4.0          11.7
# 14421               NaN        0.104          9.0          11.6
# 17461               NaN        0.095          7.0          10.7
#
#       measurement_timestamp_label               measurement_id
# 15904         2015-07-01T14:00:00  63rdStreetBeach201507011400
# 20106         2015-07-25T17:00:00  63rdStreetBeach201507251700
# 16273         2015-07-04T04:00:00  63rdStreetBeach201507040400
# 24790         2015-08-23T05:00:00  63rdStreetBeach201508230500
# 4172          2014-07-06T00:00:00  63rdStreetBeach201407062400
# ...                           ...                          ...
# 28174         2015-09-10T07:00:00     RainbowBeach201509100700
# 14445         2015-06-23T03:00:00     RainbowBeach201506230300
# 28168         2015-09-10T06:00:00     RainbowBeach201509100600
# 14421         2015-06-22T23:00:00     RainbowBeach201506222300
# 17461         2015-07-11T08:00:00     RainbowBeach201507110800
#
# [34923 rows x 10 columns]

# %%
#Sorting based on multiple column
df[['beach_name','water_temperature']].sort_values(['beach_name', 'water_temperature'])
# Out:
#               beach_name  water_temperature
# 5172   63rd Street Beach               10.1
# 5217   63rd Street Beach               10.1
# 5229   63rd Street Beach               10.1
# 5213   63rd Street Beach               10.2
# 5176   63rd Street Beach               10.3
# ...                  ...                ...
# 20458      Rainbow Beach               25.8
# 20526      Rainbow Beach               25.8
# 20912      Rainbow Beach               26.7
# 824        Rainbow Beach               27.1
# 32352      Rainbow Beach                NaN
#
# [34923 rows x 2 columns]

# %%
#Sorting based on multiple column - descending order
df[['beach_name','water_temperature']].sort_values('water_temperature', ascending=False)
# Out:
#               beach_name  water_temperature
# 16945  Ohio Street Beach               31.5
# 19330  Ohio Street Beach               31.4
# 19327  Ohio Street Beach               31.2
# 19333  Ohio Street Beach               30.4
# 19324  Ohio Street Beach               30.0
# ...                  ...                ...
# 30542     Osterman Beach                NaN
# 31199  Ohio Street Beach                NaN
# 31309      Calumet Beach                NaN
# 31310  63rd Street Beach                NaN
# 32352      Rainbow Beach                NaN
#
# [34923 rows x 2 columns]

# %% [markdown]
# <b>4. Filtering the records

# %% [markdown]
# We can also write where conditions to filter out the records from the dataframe.

# %%
#Get column names
df.columns
# Out:
# Index(['beach_name', 'measurement_timestamp', 'water_temperature', 'turbidity',
#        'transducer_depth', 'wave_height', 'wave_period', 'battery_life',
#        'measurement_timestamp_label', 'measurement_id'],
#       dtype='object')

# %%
#Get unique beach names
df.beach_name.value_counts()
#df.beach_name.value_counts()
# Out:
# beach_name
# Ohio Street Beach    9343
# Calumet Beach        7570
# Montrose Beach       7269
# Osterman Beach       4023
# 63rd Street Beach    3420
# Rainbow Beach        3298
# Name: count, dtype: int64

# %%
#Extract records for a particular beach
#df[df.beach_name=='Rainbow Beach']
df[df.beach_name=='Ohio Street Beach'].head()
# Out:
#             beach_name measurement_timestamp  water_temperature  turbidity  \
# 1    Ohio Street Beach   2016-05-26T13:00:00               14.4       1.23
# 278  Ohio Street Beach   2013-09-03T03:00:00               21.9       4.97
# 388  Ohio Street Beach   2014-06-05T12:00:00               16.9       1.60
# 441  Ohio Street Beach   2014-06-06T14:00:00               18.8       0.70
# 444  Ohio Street Beach   2014-06-06T17:00:00               19.8       0.78
#
#      transducer_depth  wave_height  wave_period  battery_life  \
# 1                 NaN        0.111          4.0          12.4
# 278             1.039        0.241          7.0           9.4
# 388             1.780        0.159          3.0          12.8
# 441             1.495        0.135          2.0          12.4
# 444             1.471        0.162          3.0          12.3
#
#     measurement_timestamp_label               measurement_id
# 1           2016-05-26T13:00:00  OhioStreetBeach201605261300
# 278         2013-09-03T03:00:00  OhioStreetBeach201309030300
# 388         2014-06-05T12:00:00  OhioStreetBeach201406051200
# 441         2014-06-06T14:00:00  OhioStreetBeach201406061400
# 444         2014-06-06T17:00:00  OhioStreetBeach201406061700

# %%
#Few columns and records of dataframe
df[df.beach_name=='Ohio Street Beach'][['beach_name', 'water_temperature']].head()
# Out:
#             beach_name  water_temperature
# 1    Ohio Street Beach               14.4
# 278  Ohio Street Beach               21.9
# 388  Ohio Street Beach               16.9
# 441  Ohio Street Beach               18.8
# 444  Ohio Street Beach               19.8

# %%
#all records of dataframe with more than one condition
filtered_df = df[(df.beach_name=='Ohio Street Beach') & (df.water_temperature > 20)].head()
filtered_df.head()
# Out:
#              beach_name measurement_timestamp  water_temperature  turbidity  \
# 278   Ohio Street Beach   2013-09-03T03:00:00               21.9       4.97
# 1555  Ohio Street Beach   2014-06-17T16:00:00               21.1       1.36
# 1594  Ohio Street Beach   2014-06-17T14:00:00               20.8       1.30
# 1600  Ohio Street Beach   2014-06-17T15:00:00               21.4       0.98
# 1606  Ohio Street Beach   2014-06-17T17:00:00               20.5       1.45
#
#       transducer_depth  wave_height  wave_period  battery_life  \
# 278              1.039        0.241          7.0           9.4
# 1555             1.717        0.159          2.0          11.3
# 1594             1.493        0.141          3.0          11.3
# 1600             1.688        0.136          2.0          11.3
# 1606             1.711        0.131          3.0          11.3
#
#      measurement_timestamp_label               measurement_id
# 278          2013-09-03T03:00:00  OhioStreetBeach201309030300
# 1555         2014-06-17T16:00:00  OhioStreetBeach201406171600
# 1594         2014-06-17T14:00:00  OhioStreetBeach201406171400
# 1600         2014-06-17T15:00:00  OhioStreetBeach201406171500
# 1606         2014-06-17T17:00:00  OhioStreetBeach201406171700

# %%
#all records of dataframe with more than one condition, restricted columns
filtered_df = df[(df.beach_name=='Ohio Street Beach') & (df.water_temperature > 20)][['beach_name', 'water_temperature']].head()
filtered_df.head()
# Out:
#              beach_name  water_temperature
# 278   Ohio Street Beach               21.9
# 1555  Ohio Street Beach               21.1
# 1594  Ohio Street Beach               20.8
# 1600  Ohio Street Beach               21.4
# 1606  Ohio Street Beach               20.5

# %%
#all records of dataframe with more than one 'or' condition, restricted columns
#filtered_df = df[(df.beach_name=='Ohio Street Beach') | (df.beach_name=='Calumet Beach')][['beach_name', 'water_temperature']].head()
filtered_df = df[(df.beach_name=='Ohio Street Beach') | (df.beach_name=='Calumet Beach')][['beach_name', 'water_temperature']]
print(filtered_df.head(5))
print(filtered_df.tail(5))
# Out:
#           beach_name  water_temperature
# 1  Ohio Street Beach               14.4
# 2      Calumet Beach               23.2
# 3      Calumet Beach               16.2
# 6      Calumet Beach               16.3
# 8      Calumet Beach               16.5
#               beach_name  water_temperature
# 34918  Ohio Street Beach               19.9
# 34919  Ohio Street Beach               19.8
# 34920  Ohio Street Beach               22.3
# 34921  Ohio Street Beach               21.1
# 34922  Ohio Street Beach               21.3

# %% [markdown]
# query method can be directly used for specifying the where clause in simple manner

# %%
df.query('wave_period > 3 and water_temperature < 10')
# Out:
#           beach_name measurement_timestamp  water_temperature  turbidity  \
# 5040   Rainbow Beach   2014-07-25T23:00:00                0.0       0.00
# 6853   Rainbow Beach   2014-07-23T03:00:00                0.0       0.00
# 6859   Rainbow Beach   2014-07-23T04:00:00                0.0       0.00
# 6865   Rainbow Beach   2014-07-23T05:00:00                0.0       0.00
# 6871   Rainbow Beach   2014-07-25T16:00:00                0.0       0.00
# ...              ...                   ...                ...        ...
# 9053  Osterman Beach   2015-06-01T06:00:00                9.1     123.39
# 9055  Montrose Beach   2015-06-01T09:00:00                9.4      87.54
# 9060  Montrose Beach   2015-06-01T10:00:00                9.6      89.38
# 9061  Osterman Beach   2015-06-01T10:00:00                9.4     119.88
# 9063  Montrose Beach   2015-06-01T12:00:00                9.8      86.18
#
#       transducer_depth  wave_height  wave_period  battery_life  \
# 5040             1.645        0.096          9.0           9.5
# 6853             1.729        0.537          5.0          11.1
# 6859             1.831        0.576          6.0          11.0
# 6865             1.778        0.535          6.0          11.0
# 6871             1.589        0.105          4.0           9.6
# ...                ...          ...          ...           ...
# 9053               NaN        0.393          4.0          10.8
# 9055               NaN        0.435          4.0          11.0
# 9060               NaN        0.404          5.0          11.0
# 9061               NaN        0.373          4.0          10.8
# 9063               NaN        0.418          4.0          10.8
#
#      measurement_timestamp_label             measurement_id
# 5040         2014-07-25T23:00:00   RainbowBeach201407252300
# 6853         2014-07-23T03:00:00   RainbowBeach201407230300
# 6859         2014-07-23T04:00:00   RainbowBeach201407230400
# 6865         2014-07-23T05:00:00   RainbowBeach201407230500
# 6871         2014-07-25T16:00:00   RainbowBeach201407251600
# ...                          ...                        ...
# 9053         2015-06-01T06:00:00  OstermanBeach201506010600
# 9055         2015-06-01T09:00:00  MontroseBeach201506010900
# 9060         2015-06-01T10:00:00  MontroseBeach201506011000
# 9061         2015-06-01T10:00:00  OstermanBeach201506011000
# 9063         2015-06-01T12:00:00  MontroseBeach201506011200
#
# [127 rows x 10 columns]

# %% [markdown]
# <b> 5. Applying groupby on the dataframe

# %%
#count(temp) group by beach_name
df.groupby('beach_name')['water_temperature'].count()
# Out:
# beach_name
# 63rd Street Beach    3419
# Calumet Beach        7569
# Montrose Beach       7268
# Ohio Street Beach    9342
# Osterman Beach       4022
# Rainbow Beach        3297
# Name: water_temperature, dtype: int64

# %%
#avg(temp) group by beach_name
df.groupby('beach_name')['water_temperature'].mean()
# Out:
# beach_name
# 63rd Street Beach    18.459901
# Calumet Beach        20.372929
# Montrose Beach       18.640534
# Ohio Street Beach    20.273603
# Osterman Beach       17.933615
# Rainbow Beach        18.741250
# Name: water_temperature, dtype: float64

# %%
#max(temp) group by beach_name
df.groupby('beach_name')['water_temperature'].max()
# Out:
# beach_name
# 63rd Street Beach    26.1
# Calumet Beach        29.2
# Montrose Beach       27.0
# Ohio Street Beach    31.5
# Osterman Beach       25.7
# Rainbow Beach        27.1
# Name: water_temperature, dtype: float64

# %%
#avg(temp) groupby beach_name and wave_period
df.groupby(['beach_name', 'wave_period'])['water_temperature'].mean()
# Out:
# beach_name         wave_period
# 63rd Street Beach  -100000.0      18.731818
#                     2.0           18.535052
#                     3.0           18.570020
#                     4.0           18.384449
#                     5.0           18.309471
#                     6.0           18.139510
#                     7.0           18.097403
#                     8.0           18.285714
#                     9.0           17.719231
#                     10.0          18.548148
# Calumet Beach       2.0           20.747992
#                     3.0           20.630416
#                     4.0           19.863279
#                     5.0           19.561029
#                     6.0           20.086461
#                     7.0           20.131628
#                     8.0           20.004598
#                     9.0           20.323596
#                     10.0          20.574194
# Montrose Beach      1.0           21.969231
#                     2.0           18.541403
#                     3.0           18.985866
#                     4.0           18.525367
#                     5.0           18.327426
#                     6.0           18.462626
#                     7.0           18.489681
#                     8.0           18.400420
#                     9.0           18.033880
#                     10.0          18.360674
# Ohio Street Beach  -100000.0      24.582500
#                     1.0           23.273913
#                     2.0           20.408019
#                     3.0           20.347669
#                     4.0           19.807295
#                     5.0           19.995872
#                     6.0           20.474113
#                     7.0           20.522165
#                     8.0           20.473333
#                     9.0           20.121277
#                     10.0          21.932353
# Osterman Beach      1.0           20.300000
#                     2.0           17.942469
#                     3.0           18.320776
#                     4.0           17.795055
#                     5.0           17.279675
#                     6.0           17.217959
#                     7.0           17.729412
#                     8.0           17.560185
#                     9.0           17.308791
#                     10.0          18.415385
# Rainbow Beach      -100000.0      21.808824
#                     2.0           19.098214
#                     3.0           18.531693
#                     4.0           18.218942
#                     5.0           18.499417
#                     6.0           17.518100
#                     7.0           17.169504
#                     8.0           17.714063
#                     9.0           17.181132
#                     10.0          18.397826
# Name: water_temperature, dtype: float64

# %% [markdown]
# # (B) Data Preparation / Preprocessing
# ![image.png](attachment:image.png)

# %% [markdown]
# The objective of this step are -
#
# - To improve data quality
# - To modify data to better fit specific data mining technique

# %% [markdown]
# <b>The major steps involved are</b>
#
#
# 1) Data cleaning
#
# - Fill in missing values
# - Smooth noisy data
# - Identify or remove outliers
# - Resolve inconsistencies
#
# 2) Data integration
#
# - Integration of multiple databases, data cubes, or files
#
# 3) Data reduction
#
# - Dimensionality reduction
# - Numerosity reduction
# - Data compression
#
# 4) Data transformation
#
# - Data discretization
# - Normalization
# - Concept hierarchy generation

# %% [markdown]
# <b> 1. Missing values

# %%
df.head()
# Out:
#           beach_name measurement_timestamp  water_temperature  turbidity  \
# 0     Montrose Beach   2013-08-30T08:00:00               20.3       1.18
# 1  Ohio Street Beach   2016-05-26T13:00:00               14.4       1.23
# 2      Calumet Beach   2013-09-03T16:00:00               23.2       3.63
# 3      Calumet Beach   2014-05-28T12:00:00               16.2       1.26
# 4     Montrose Beach   2014-05-28T12:00:00               14.4       3.36
#
#    transducer_depth  wave_height  wave_period  battery_life  \
# 0             0.891        0.080          3.0           9.4
# 1               NaN        0.111          4.0          12.4
# 2             1.201        0.174          6.0           9.4
# 3             1.514        0.147          4.0          11.7
# 4             1.388        0.298          4.0          11.9
#
#   measurement_timestamp_label               measurement_id
# 0         2013-08-30T08:00:00    MontroseBeach201308300800
# 1         2016-05-26T13:00:00  OhioStreetBeach201605261300
# 2         2013-09-03T16:00:00     CalumetBeach201309031600
# 3         2014-05-28T12:00:00     CalumetBeach201405281200
# 4         2014-05-28T12:00:00    MontroseBeach201405281200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34923 entries, 0 to 34922
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   beach_name                   34923 non-null  object
#  1   measurement_timestamp        34917 non-null  object
#  2   water_temperature            34917 non-null  float64
#  3   turbidity                    34917 non-null  float64
#  4   transducer_depth             10034 non-null  float64
#  5   wave_height                  34690 non-null  float64
#  6   wave_period                  34690 non-null  float64
#  7   battery_life                 34917 non-null  float64
#  8   measurement_timestamp_label  34917 non-null  object
#  9   measurement_id               34923 non-null  object
# dtypes: float64(6), object(4)
# memory usage: 2.7+ MB

# %% [markdown]
# Shows presense of missing values? But how many of them are there?

# %%
df.isnull()
# Out:
#        beach_name  measurement_timestamp  water_temperature  turbidity  \
# 0           False                  False              False      False
# 1           False                  False              False      False
# 2           False                  False              False      False
# 3           False                  False              False      False
# 4           False                  False              False      False
# ...           ...                    ...                ...        ...
# 34918       False                  False              False      False
# 34919       False                  False              False      False
# 34920       False                  False              False      False
# 34921       False                  False              False      False
# 34922       False                  False              False      False
#
#        transducer_depth  wave_height  wave_period  battery_life  \
# 0                 False        False        False         False
# 1                  True        False        False         False
# 2                 False        False        False         False
# 3                 False        False        False         False
# 4                 False        False        False         False
# ...                 ...          ...          ...           ...
# 34918              True        False        False         False
# 34919              True        False        False         False
# 34920              True        False        False         False
# 34921              True        False        False         False
# 34922              True        False        False         False
#
#        measurement_timestamp_label  measurement_id
# 0                            False           False
# 1                            False           False
# 2                            False           False
# 3                            False           False
# 4                            False           False
# ...                            ...             ...
# 34918                        False           False
# 34919                        False           False
# 34920                        False           False
# 34921                        False           False
# 34922                        False           False
#
# [34923 rows x 10 columns]

# %% [markdown]
# It tells me about presence / absense of value for each column,but thats not much meaningfull. I need the count for each column's missing values.

# %%
#Get missing values count per column
df.isnull().sum()
# Out:
# beach_name                         0
# measurement_timestamp              6
# water_temperature                  6
# turbidity                          6
# transducer_depth               24889
# wave_height                      233
# wave_period                      233
# battery_life                       6
# measurement_timestamp_label        6
# measurement_id                     0
# dtype: int64

# %% [markdown]
# Many columns have missing values present in them. Lets deal with them.

# %% [markdown]
# For numeric variable, simplest of imputing the missing value by average can be applied.

# %%
#Find out the average for "water_temperature"
avg_water_temperature = df["water_temperature"].astype("float").mean(axis = 0)
print("avg_water_temperature : ", avg_water_temperature)

#Use the average "water_temperature" for the inplace replacement
df["water_temperature"].replace(np.nan, avg_water_temperature, inplace = True)
# Out:
# avg_water_temperature :  19.363387461694877

# %%
+------------+---------+--------+
|            |  A      |  B     |
+------------+---------+---------
|      0     | 0.626386| 1.52325|----axis=1----->
+------------+---------+--------+
             |         |
             | axis=0  |
             ↓         ↓

#It specifies the axis along which the means are computed.

# %%
#Get missing values count per column
df.isnull().sum()
# Out:
# beach_name                         0
# measurement_timestamp              6
# water_temperature                  0
# turbidity                          6
# transducer_depth               24889
# wave_height                      233
# wave_period                      233
# battery_life                       6
# measurement_timestamp_label        6
# measurement_id                     0
# dtype: int64

# %% [markdown]
# Repeat same for other numerics like turbidity, wave_height, wave_period and battery_life.

# %%
#Use the average "turbidity" for the inplace replacement
avg_turbidity = df["turbidity"].astype("float").mean(axis = 0)
df["turbidity"].replace(np.nan, avg_turbidity, inplace = True)

#Use the average "wave_height" for the inplace replacement
avg_wave_height = df["wave_height"].astype("float").mean(axis = 0)
df["wave_height"].replace(np.nan, avg_wave_height, inplace = True)

#Use the average "wave_period" for the inplace replacement
avg_wave_period = df["wave_period"].astype("float").mean(axis = 0)
df["wave_period"].replace(np.nan, avg_wave_period, inplace = True)

#Use the average "battery_life" for the inplace replacement
avg_battery_life = df["battery_life"].astype("float").mean(axis = 0)
df["battery_life"].replace(np.nan, avg_battery_life, inplace = True)

# %%
#Get missing values count per column
df.isnull().sum()
# Out:
# beach_name                         0
# measurement_timestamp              6
# water_temperature                  0
# turbidity                          0
# transducer_depth               24889
# wave_height                        0
# wave_period                        0
# battery_life                       0
# measurement_timestamp_label        6
# measurement_id                     0
# dtype: int64

# %% [markdown]
# How to deal with measurement_timestamp, measurement_timestamp_label and transducer_depth?

# %% [markdown]
# <b> 2. Dropping duplicate columns

# %% [markdown]
# Seems columns measurement_timestamp and measurement_timestamp_label are same. Lets verify and if it so then we get rid one of them.

# %%
#Compare measurement_timestamp and measurement_timestamp_label 
df['measurement_timestamp'].equals(df['measurement_timestamp_label'])
# Out:
# True

# %%
#Remove "measurement_timestamp_label" from dataframe
df.drop('measurement_timestamp_label', inplace=True, axis=1)

# %%
df.columns
# Out:
# Index(['beach_name', 'measurement_timestamp', 'water_temperature', 'turbidity',
#        'transducer_depth', 'wave_height', 'wave_period', 'battery_life',
#        'measurement_id'],
#       dtype='object')

# %% [markdown]
# <b> 3. Converting data types of column

# %% [markdown]
# measurement_timestamp is datetime column but appearing as object in dataframe, so lets convert it to date time first.

# %%
df.dtypes
# Out:
# beach_name                object
# measurement_timestamp     object
# water_temperature        float64
# turbidity                float64
# transducer_depth         float64
# wave_height              float64
# wave_period              float64
# battery_life             float64
# measurement_id            object
# dtype: object

# %%
#Convert measurement_timestamp to datetime
df.measurement_timestamp = pd.to_datetime(df.measurement_timestamp)

# %%
#Check again
df.dtypes
# Out:
# beach_name                       object
# measurement_timestamp    datetime64[ns]
# water_temperature               float64
# turbidity                       float64
# transducer_depth                float64
# wave_height                     float64
# wave_period                     float64
# battery_life                    float64
# measurement_id                   object
# dtype: object

# %% [markdown]
# measurement_id columns looks like number but appearing as object. Lets explore it.

# %%
df.measurement_id.unique()
# Out:
# array(['MontroseBeach201308300800', 'OhioStreetBeach201605261300',
#        'CalumetBeach201309031600', ..., 'OhioStreetBeach201709121500',
#        'OhioStreetBeach201709121700', 'OhioStreetBeach201709121800'],
#       dtype=object)

# %% [markdown]
# The values are not numeric as they are having some intelligence embedded in their values.

# %% [markdown]
# <b> 4. Dropping rows

# %% [markdown]
# We still have the missing values for some of the columns.

# %%
df.isnull().sum()
# Out:
# beach_name                   0
# measurement_timestamp        6
# water_temperature            0
# turbidity                    0
# transducer_depth         24889
# wave_height                  0
# wave_period                  0
# battery_life                 0
# measurement_id               0
# dtype: int64

# %% [markdown]
# Missing values for measurement_timestamp are very less as compared to total number of records hence I can afford to drop them.

# %%
#Drop missing values for measurement_timestamp and check again
df = df.dropna(subset=['measurement_timestamp'])
df.isnull().sum()
# Out:
# beach_name                   0
# measurement_timestamp        0
# water_temperature            0
# turbidity                    0
# transducer_depth         24883
# wave_height                  0
# wave_period                  0
# battery_life                 0
# measurement_id               0
# dtype: int64

# %%
#Rows are reduced by 6
df.shape
# Out:
# (34917, 9)

# %% [markdown]
# For transducer_depth majority of the cells does not have values, so is it really an important attribute. Need to check with domain and decide whether to drop it or not.

# %% [markdown]
# <b> 5. Dropping column

# %% [markdown]
# Let's drop transducer_depth column as majority of values are missing for it.

# %%
#Drop and check
df.drop('transducer_depth', inplace=True, axis=1)
# Out:
# C:\Users\Dilip\AppData\Local\Temp\ipykernel_18020\444751605.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('transducer_depth', inplace=True, axis=1)

# %%
df.columns
# Out:
# Index(['beach_name', 'measurement_timestamp', 'water_temperature', 'turbidity',
#        'wave_height', 'wave_period', 'battery_life', 'measurement_id'],
#       dtype='object')

# %% [markdown]
# <b> 6. Dropping duplicate rows

# %% [markdown]
# Check for the duplicate records

# %%
# Selecting duplicate rows except first occurrence based on all columns 
duplicate = df[df.duplicated()] 
duplicate.shape
# Out:
# (0, 8)

# %%
df.shape
# Out:
# (34917, 8)

# %% [markdown]
# <b> 7. Renaming a column

# %% [markdown]
# Some of the columns have very big names, can those be shortened or renamed ?

# %%
df.columns
# Out:
# Index(['beach_name', 'measurement_timestamp', 'water_temperature', 'turbidity',
#        'wave_height', 'wave_period', 'battery_life', 'measurement_id'],
#       dtype='object')

# %%
df.rename(columns = {'measurement_timestamp':'timestamp', 'water_temperature':'temp'}, inplace=True)
# Out:
# C:\Users\Dilip\AppData\Local\Temp\ipykernel_18020\130918385.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {'measurement_timestamp':'timestamp', 'water_temperature':'temp'}, inplace=True)

# %%
#Check the renamed columns again
df.columns
# Out:
# Index(['beach_name', 'timestamp', 'temp', 'turbidity', 'wave_height',
#        'wave_period', 'battery_life', 'measurement_id'],
#       dtype='object')

# %% [markdown]
# <b> 8. Replacing the cell values of a column

# %% [markdown]
# Some of the column values are still categorial (string) in nature, those can be replaced with the numeric categories.

# %%
df['beach_name']=df['beach_name'].replace({"Montrose Beach":0, "Calumet Beach":1})
# Out:
# C:\Users\Dilip\AppData\Local\Temp\ipykernel_18020\1840027514.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['beach_name']=df['beach_name'].replace({"Montrose Beach":0, "Calumet Beach":1})

# %%
df.beach_name.unique()
# Out:
# array([0, 'Ohio Street Beach', 1, '63rd Street Beach', 'Osterman Beach',
#        'Rainbow Beach'], dtype=object)

# %%
#Do it for all column values of beach
df['beach_name']=df['beach_name'].replace({"Montrose Beach":0, "Calumet Beach":1, "Ohio Street Beach":2, "63rd Street Beach":3, "Osterman Beach":4, "Rainbow Beach":5})
# Out:
# C:\Users\Dilip\AppData\Local\Temp\ipykernel_18020\2830516504.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['beach_name']=df['beach_name'].replace({"Montrose Beach":0, "Calumet Beach":1, "Ohio Street Beach":2, "63rd Street Beach":3, "Osterman Beach":4, "Rainbow Beach":5})

# %%
df.beach_name.unique()
# Out:
# array([0, 2, 1, 3, 4, 5], dtype=int64)

# %%
df.head()
# Out:
#    beach_name           timestamp  temp  turbidity  wave_height  wave_period  \
# 0           0 2013-08-30 08:00:00  20.3       1.18        0.080          3.0
# 1           2 2016-05-26 13:00:00  14.4       1.23        0.111          4.0
# 2           1 2013-09-03 16:00:00  23.2       3.63        0.174          6.0
# 3           1 2014-05-28 12:00:00  16.2       1.26        0.147          4.0
# 4           0 2014-05-28 12:00:00  14.4       3.36        0.298          4.0
#
#    battery_life               measurement_id
# 0           9.4    MontroseBeach201308300800
# 1          12.4  OhioStreetBeach201605261300
# 2           9.4     CalumetBeach201309031600
# 3          11.7     CalumetBeach201405281200
# 4          11.9    MontroseBeach201405281200

# %% [markdown]
# <b> 9. Exporting the prepared dataset

# %%
# %ls
# Out:
#  Volume in drive I is Monika
#  Volume Serial Number is 24D4-7A8E
#
#  Directory of I:\BITS-IoT Data Management\Session8-Data Preprocessing lab\Labs\Lab1-  Data preparation Lab
#
# 10-09-2023  10:08    <DIR>          .
# 10-09-2023  10:08    <DIR>          ..
# 09-09-2023  15:34    <DIR>          .ipynb_checkpoints
# 10-09-2023  10:08           786,469 10-Sep Lab1 - Beach Water Quality Analysis.ipynb
# 28-01-2021  08:51         3,769,904 beach_water_quality_automated_sensors_1.csv
# 07-09-2023  19:47           737,800 DMIoT - Lab1 - Beach Water Quality Analysis -1.ipynb
# 02-09-2023  20:11           719,293 DMIoT - Lab1 - Beach Water Quality Analysis -1-Copy1.ipynb
# 28-01-2021  11:36            47,147 DMIoT Lab1-  Data preparation Lab.docx
# 02-09-2023  21:53         2,801,173 exported_data.csv
#                6 File(s)      8,861,786 bytes
#                3 Dir(s)  383,577,456,640 bytes free

# %%
! del  exported_data.csv

# %%
# %ls
# Out:
#  Volume in drive I is Monika
#  Volume Serial Number is 24D4-7A8E
#
#  Directory of I:\BITS-IoT Data Management\Session8-Data Preprocessing lab\Labs\Lab1-  Data preparation Lab
#
# 10-09-2023  10:09    <DIR>          .
# 10-09-2023  10:09    <DIR>          ..
# 09-09-2023  15:34    <DIR>          .ipynb_checkpoints
# 10-09-2023  10:08           786,469 10-Sep Lab1 - Beach Water Quality Analysis.ipynb
# 28-01-2021  08:51         3,769,904 beach_water_quality_automated_sensors_1.csv
# 07-09-2023  19:47           737,800 DMIoT - Lab1 - Beach Water Quality Analysis -1.ipynb
# 02-09-2023  20:11           719,293 DMIoT - Lab1 - Beach Water Quality Analysis -1-Copy1.ipynb
# 28-01-2021  11:36            47,147 DMIoT Lab1-  Data preparation Lab.docx
#                5 File(s)      6,060,613 bytes
#                3 Dir(s)  383,580,258,304 bytes free

# %%
df.to_csv("exported_data.csv")

# %%
ls
# Out:
#  Volume in drive I is Monika
#  Volume Serial Number is 24D4-7A8E
#
#  Directory of I:\BITS-IoT Data Management\Session8-Data Preprocessing lab\Labs\Lab1-  Data preparation Lab
#
# 10-09-2023  10:10    <DIR>          .
# 10-09-2023  10:10    <DIR>          ..
# 09-09-2023  15:34    <DIR>          .ipynb_checkpoints
# 10-09-2023  10:10           791,626 10-Sep Lab1 - Beach Water Quality Analysis.ipynb
# 28-01-2021  08:51         3,769,904 beach_water_quality_automated_sensors_1.csv
# 07-09-2023  19:47           737,800 DMIoT - Lab1 - Beach Water Quality Analysis -1.ipynb
# 02-09-2023  20:11           719,293 DMIoT - Lab1 - Beach Water Quality Analysis -1-Copy1.ipynb
# 28-01-2021  11:36            47,147 DMIoT Lab1-  Data preparation Lab.docx
# 10-09-2023  10:10         2,801,173 exported_data.csv
#                6 File(s)      8,866,943 bytes
#                3 Dir(s)  383,577,452,544 bytes free
