# %% [markdown]
# # Support Vector Machines (SVM)
#
# logistic regression and naive Bayes.  are not for  more complex classification problems, such as image classification.
#
#
#
# SVMs are capable of dealing with quite complex such as image recognition, voice detection etc. extremely popular classification models
#
#
#
# SVMs are mostly used for classification tasks, but they can also be used for regression.
#
# The topics covered in this module are limited to classification tasks. In this module, you will apply SVMs to email spam detection and alphabetic letter recognition problems.
#
#
# In this session
#
# You will understand the following concepts:
#
# - Hyperplane
# - Hyperplane in 2D
# - Hyperplane in 3D and nD
# - Maximal Margin Classifier
#
#
#  SVMs belong to the class of linear machine learning models (logistic regression is also a linear model)
#
#
# A linear model uses a linear function (i.e. of the form y = ax +b) to model the relationship between the input x and output y. For example, in logistic regression, the log(odds) of an outcome (say, defaulting on a credit card) is linearly related to the attributes x1, x2, etc.
#
# ![](https://latex.upgrad.com/render?formula=log%28odds%5C%5C%20of%20%5C%5C%20default%29%20%3D%20%5Cbeta%20_%7B0%7D%2B%5Cbeta%20_%7B1%7D%20X_%7B1%7D%2B%5Cbeta%20_%7B2%7D%20X_%7B2%7D%2B...%5Cbeta%20_%7Bn%7D%20X_%7Bn%7D)
#
#
# To summarise, **SVMs** are linear models that **require numeric attributes**. In case the attributes are **non-numeric**, you need to **convert them to a numeric form** in the data preparation stage.
#
#
# example of email classification, the features are the ‘frequency of words’ in an email. Word frequency is a very common type of feature in text classification, and reasonably so. For example, words such as ‘Hurry’, ‘FREE’ and ‘Discount’ are likely to be more frequent in spam emails than ‘meeting’, ‘PPT’, ‘weekly report’, and others that are characteristic of office emails. To get a sense of how the data set looks, find the dataset link [here](https://ml-course3-upgrad.s3.amazonaws.com/Support+Vector+Machines/SVM+-+Maximal+Margin+Classifier/Spam.csv):
#
# ![110.png](attachment:4bc98eca-3a24-401b-b5ec-3327a50a161d.png)
#
# ## Concept of a Hyperplane in 2D
# it is a **boundary which 'separates' the data set into its classes** (in this case, separates spam emails from the ham ones). It could be lines, 2D planes, or even n-dimensional planes that are beyond our imagination.
#
#
# You can find the data dictionary of the email spam dataset from the UCI repository link [here](https://archive.ics.uci.edu/ml/machine-learning-databases/spambase/spambase.names) and find the dataset link [here](https://ml-course3-upgrad.s3.amazonaws.com/Support+Vector+Machines/SVM+-+Maximal+Margin+Classifier/Spam.csv):
#
# Now, let’s try to imagine how a spam or ham classifies in 2D for the email spam data set.
#
# ![111.png](attachment:13060503-b1e9-40b2-a7ac-5bb7bdd4bf36.png)
#
#
# ![112.png](attachment:67a34633-2994-4b68-8055-c7ea5f7bf990.png)
#
# <p>The standard equation of a line is given by <strong>ax+by+c = 0</strong>. You could generalise it as <span aria-label="span widget" class="cke_widget_wrapper cke_widget_inline cke_widget_equation-editor cke_widget_wrapper_equation-content cke_widget_selected" contenteditable="false" data-cke-display-name="span" data-cke-filter="off" data-cke-widget-id="5" data-cke-widget-wrapper="1" role="region" tabindex="-1"><img alt="Equation" data-latex="W_{0} + W_{1}x_{1} + W_{2}x_{2} = 0" src="https://latex.upgrad.com/render?formula=W_%7B0%7D%20%2B%20W_%7B1%7Dx_%7B1%7D%20%2B%20W_%7B2%7Dx_%7B2%7D%20%3D%200" style="vertical-align: middle;display: inline;"></span>, where x1 and x2 are the features — such as 'word_freq_technology' and 'word_freq_money' — and <span aria-label="span widget" class="cke_widget_wrapper cke_widget_inline cke_widget_equation-editor cke_widget_wrapper_equation-content cke_widget_selected" contenteditable="false" data-cke-display-name="span" data-cke-filter="off" data-cke-widget-id="4" data-cke-widget-wrapper="1" role="region" tabindex="-1"><img alt="Equation" data-latex="W_{1}" src="https://latex.upgrad.com/render?formula=W_%7B1%7D" style="vertical-align: middle;display: inline;"></span> and <span aria-label="span widget" class="cke_widget_wrapper cke_widget_inline cke_widget_equation-editor cke_widget_wrapper_equation-content cke_widget_selected" contenteditable="false" data-cke-display-name="span" data-cke-filter="off" data-cke-widget-id="3" data-cke-widget-wrapper="1" role="region" tabindex="-1"><img alt="Equation" data-latex="W_{2}" src="https://latex.upgrad.com/render?formula=W_%7B2%7D" style="vertical-align: middle;display: inline;"></span> are the coefficients. For any line with W coefficients, substituting the value of features <span aria-label="span widget" class="cke_widget_wrapper cke_widget_inline cke_widget_equation-editor cke_widget_wrapper_equation-content cke_widget_selected" contenteditable="false" data-cke-display-name="span" data-cke-filter="off" data-cke-widget-id="2" data-cke-widget-wrapper="1" role="region" tabindex="-1"><img alt="Equation" data-latex="x_{1}" src="https://latex.upgrad.com/render?formula=x_%7B1%7D" style="vertical-align: middle;display: inline;"></span> and <span aria-label="span widget" class="cke_widget_wrapper cke_widget_inline cke_widget_equation-editor cke_widget_wrapper_equation-content cke_widget_selected" contenteditable="false" data-cke-display-name="span" data-cke-filter="off" data-cke-widget-id="1" data-cke-widget-wrapper="1" role="region" tabindex="-1"><img alt="Equation" data-latex="x_{2}" src="https://latex.upgrad.com/render?formula=x_%7B2%7D" style="vertical-align: middle;display: inline;"></span> in the equation of the line determined by its W coefficients, will return a value.&nbsp;</p>
#
# <p>The standard equation of a line is given by <strong>ax+by+c = 0</strong>. You could generalise it as <span aria-label="span widget" class="cke_widget_wrapper cke_widget_inline cke_widget_equation-editor cke_widget_wrapper_equation-content cke_widget_selected" contenteditable="false" data-cke-display-name="span" data-cke-filter="off" data-cke-widget-id="5" data-cke-widget-wrapper="1" role="region" tabindex="-1"><img alt="Equation" data-latex="W_{0} + W_{1}x_{1} + W_{2}x_{2} = 0" src="https://latex.upgrad.com/render?formula=W_%7B0%7D%20%2B%20W_%7B1%7Dx_%7B1%7D%20%2B%20W_%7B2%7Dx_%7B2%7D%20%3D%200" style="vertical-align: middle;display: inline;"></span>, where x1 and x2 are the features — such as 'word_freq_technology' and 'word_freq_money' — and <span aria-label="span widget" class="cke_widget_wrapper cke_widget_inline cke_widget_equation-editor cke_widget_wrapper_equation-content cke_widget_selected" contenteditable="false" data-cke-display-name="span" data-cke-filter="off" data-cke-widget-id="4" data-cke-widget-wrapper="1" role="region" tabindex="-1"><img alt="Equation" data-latex="W_{1}" src="https://latex.upgrad.com/render?formula=W_%7B1%7D" style="vertical-align: middle;display: inline;"></span> and <span aria-label="span widget" class="cke_widget_wrapper cke_widget_inline cke_widget_equation-editor cke_widget_wrapper_equation-content cke_widget_selected" contenteditable="false" data-cke-display-name="span" data-cke-filter="off" data-cke-widget-id="3" data-cke-widget-wrapper="1" role="region" tabindex="-1"><img alt="Equation" data-latex="W_{2}" src="https://latex.upgrad.com/render?formula=W_%7B2%7D" style="vertical-align: middle;display: inline;"></span> are the coefficients. For any line with W coefficients, substituting the value of features <span aria-label="span widget" class="cke_widget_wrapper cke_widget_inline cke_widget_equation-editor cke_widget_wrapper_equation-content cke_widget_selected" contenteditable="false" data-cke-display-name="span" data-cke-filter="off" data-cke-widget-id="2" data-cke-widget-wrapper="1" role="region" tabindex="-1"><img alt="Equation" data-latex="x_{1}" src="https://latex.upgrad.com/render?formula=x_%7B1%7D" style="vertical-align: middle;display: inline;"></span> and <span aria-label="span widget" class="cke_widget_wrapper cke_widget_inline cke_widget_equation-editor cke_widget_wrapper_equation-content cke_widget_selected" contenteditable="false" data-cke-display-name="span" data-cke-filter="off" data-cke-widget-id="1" data-cke-widget-wrapper="1" role="region" tabindex="-1"><img alt="Equation" data-latex="x_{2}" src="https://latex.upgrad.com/render?formula=x_%7B2%7D" style="vertical-align: middle;display: inline;"></span> in the equation of the line determined by its W coefficients, will return a value.&nbsp;</p>
#
# <p>A <strong>positive value</strong> (blue points in the plot above) would mean that the set of values of the features is in one class; however, a <strong>negative value</strong> (red points in the plot above) would imply it belongs to the other class. A value of zero would imply that the point lies on the line (hyperplane) because any point on the line will satisfy the equation: <span aria-label="span widget" class="cke_widget_wrapper cke_widget_inline cke_widget_equation-editor cke_widget_wrapper_equation-content cke_widget_selected" contenteditable="false" data-cke-display-name="span" data-cke-filter="off" data-cke-widget-id="0" data-cke-widget-wrapper="1" role="region" tabindex="-1"><img alt="Equation" data-latex="W_{0} + W_{1}x_{1} + W_{2}x_{2} = 0" src="https://latex.upgrad.com/render?formula=W_%7B0%7D%20%2B%20W_%7B1%7Dx_%7B1%7D%20%2B%20W_%7B2%7Dx_%7B2%7D%20%3D%200" style="vertical-align: middle;display: inline;"></span>.</p>

# %% [markdown]
# As you learnt in the last lecture, a 2D hyperplane can be represented by a line, and the equation of this hyperplane will be expressed as ax+by+c = 0. But if you have 3 attributes, what will the hyperplane look like, and what will the expression of such a hyperplane be?
#
#
# ![113.png](attachment:57659725-5f19-4198-8d3f-a0a465ff04e9.png)
#
# In general, you can conclude that the hyperplane in 2D can be represented by a line, whereas a hyperplane in 3D can be represented by a plane.
#
# Now, let’s see how you can extend the 2D expression for 3D and for a d-dimensional space.
#
# ![114.png](attachment:b4d94a76-e602-4e70-877e-650801f4300f.png)
#
# In general, if you derive the d-dimensional hyperplane from d attributes, you can write the expression as follows:
#
# ![](https://latex.upgrad.com/render?formula=%5Csum_%7Bi%20%3D%201%7D%5E%7Bd%7D%20%5Cleft%28%5Cright.%20W_%7Bi%7D%20.%20X_%7Bi%7D%20%5Cleft.%5Cright%29%20%2B%20W_%7B0%7D%20%3D%200)
#
# The model denoted by the expression given above is called a **linear discriminator**. Let's learn more about linear discriminator expression
#
# ![115.png](attachment:aff41bfb-f0c3-4a11-bcf9-d862e9cc2608.png)
#
# Similar to the 2D and 3D expressions, an n-dimensional hyperplane also follows the general rule: all points above the plane will yield a value greater than 0, and those below it will yield lesser than 0 when plugged into the expression of the hyperplane.
#
# Let’s focus our discussion on the 2-dimensional case again. Consider the hyperplanes (lines) drawn below. You can have multiple such lines correctly performing the classification task. But don't you think it would be a better idea to see which one is best suited?
#
# ![](https://d35ev2v1xsdze0.cloudfront.net/7de71968-2481-40b0-9658-630eb8be2067-6kwwvxhu.png)

# %% [markdown]
# ## Maximal Margin Classifier
#
# There could be multiple lines (or hyperplanes in general) possible, which perfectly divide the two classes. Let’s learn how to get the optimum hyperplane.
#
# The best line is the one that **maintains the largest possible equal distance**  from the nearest points of both the **classes**. It is also referred to as a **maximal margin classifier**. You can think of the margin as a 'band' that the hyperplane has on both its sides.
#
# There can be several lines (hyperplanes) possible in the same data set, as shown in the figure below, with different values of margins. Among these, the line with the maximum margin would be considered the best fit line for the given data.
#
# ![116.png](attachment:5a9bae78-4c09-482e-b3d0-28fd4edaed1a.png)
#
# It's obvious, from the given margin values, that the **third hyperplane is the best** of the lot. Why? **Because it maintains the maximum margin value**.
#
#
#
# But finding the maximal margin hyperplane needs a **mathematical formulation**.

# %% [markdown]
# # MCQ
#
# <div class="text_component"><p><strong>Practice Questions</strong><br><br></p><p>Consider a data set with two independent variables, say <strong>X</strong><strong>1</strong> and <strong>X</strong><strong>2,</strong> and one dependent binary variable,<strong>&nbsp;Y</strong>, with two classes, +1 or -1. The data set is plotted in the figure below.</p><p><br></p><table align="center" border="1" cellpadding="1" cellspacing="1" style="width: 500px;"><thead><tr><th scope="col" style="text-align: center;">Observations</th><th scope="col" style="text-align: center;">X1</th><th scope="col" style="text-align: center;">X2</th><th scope="col" style="text-align: center;">Y</th></tr></thead><tbody><tr><td style="text-align: center;">1</td><td style="text-align: center;">3</td><td style="text-align: center;">4</td><td style="text-align: center;">1</td></tr><tr><td style="text-align: center;">2</td><td style="text-align: center;">2</td><td style="text-align: center;">2</td><td style="text-align: center;">1</td></tr><tr><td style="text-align: center;">3</td><td style="text-align: center;">4</td><td style="text-align: center;">4</td><td style="text-align: center;">1</td></tr><tr><td style="text-align: center;">4</td><td style="text-align: center;">1</td><td style="text-align: center;">4</td><td style="text-align: center;">1</td></tr><tr><td style="text-align: center;">5</td><td style="text-align: center;">2</td><td style="text-align: center;">1</td><td style="text-align: center;">-1</td></tr><tr><td style="text-align: center;">6</td><td style="text-align: center;">4</td><td style="text-align: center;">3</td><td style="text-align: center;">-1</td></tr><tr><td style="text-align: center;">7</td><td style="text-align: center;">4</td><td style="text-align: center;">1</td><td style="text-align: center;">-1</td></tr></tbody></table><p style="text-align: center;"><em>Table-1: <strong>Data Set</strong></em></p><p><br></p><p style="text-align: center;"><em><strong><img class="image-editor fr-fic fr-dib" data-height="396" src="https://d35ev2v1xsdze0.cloudfront.net/ba0cb2c0-aa7d-4021-b48a-c28e975a2479-1742885141256.png" style="width: 500px;" data-etag="&quot;eb9a23b1e4801c28512daa3ec2c50869&quot;" data-serversideencryption="AES256" data-location="https://d35ev2v1xsdze0.cloudfront.net/ba0cb2c0-aa7d-4021-b48a-c28e975a2479-1742885141256.png" data-key="ba0cb2c0-aa7d-4021-b48a-c28e975a2479-1742885141256.png" data-bucket="upgrad-prod" data-originalname="1742885141256.png" data-fieldname="upload" data-contenttype="image/png" data-mimetype="image/png" data-size="18911" data-encoding="7bit" data-acl="public-read"></strong></em></p><p><br></p><p style="text-align: center;"><em><strong>Figure-1</strong>: Data Distribution</em></p><p><br></p></div>

# %% [markdown]
# #### Q1. Based on the information above, can the data set be separated by a hyperplane, i.e. a straight line?
#
# - [ ] Yes. It is possible to divide the classes by a straight line
#
# - [ ] No. It is not possible to divide the classes by a straight line
#
# - [ ] Can’t say
#
# ans:
# As shown in the plot above, points 1, 2, 3 and 4 can be separated from 5, 6 and 7 by the hyperplane or line.
#
# #### Q2. If the equation of the optimal hyperplane is represented by Equation, then (Hint: Equation is the slope of the line and Equation is the intercept, i.e. the point where it cuts the Equation axis) imagine the hyperplane and say whether the slope and intercept will be positive or negative.
#
# - [ ]  ​W1​< 0, ​W0​ = 0
# - [x]  ​W1 > 0, ​W0​ < 0
# - [ ]  ​W1 > 0, ​W0​> 0
# - [ ]  ​W1 < 0, ​W0​ > 0
#
# ans
#
# ![image.png](attachment:72b4f804-8a2b-43d3-8c4c-758db35a4647.png)
#
# we can see that the inmtercept will be negative ‘W1’ is the slope of the line and ‘W0’ is the intercept (the point where it cuts the X2 axis). The slope will be positive since the hyperplane or line is tilted towards the right. The constant 'W0' is where it cuts the X2 axis, which is a point below X2 = 0.
#
#
# #### Q3. The Y labels for classes 1 and 2 are 1 and -1 respectively. If the optimal separating hyperplane is represented byEquation, then the classification rule to classify a general point (p, q) is given by:
#
# - [ ] ​(W1.p−q+W0).Y>=0​
# - [ ] ​(W1.q−p+W0).Y<=0​
# - [ ] ​(W1.p−q+W0).Y>0​
# - [ ] ​(W1.q−p+W0).Y<0
#
# ans:
# The equation of the hyperplane is given as ​W1X1−X2+W0=0​.If any new point lies below the line, the value of Y will be -1, and the value of the expression ​W1X1−X2+W0​ is less than zero; this means the product will be positive. Similarly, if the point lies above the line, the value of Y will be +1, and the expression W1X1 - X2 + W0 is greater than zero. Thus, the product is positive. Also, in the case of the point on the line, the value of the expression ​W1X1−X2+W0​ is equal to zero. Thus, the expression ​(W1.p−q+W0).Y​ gives a positive value or zero.
#
# .
#
# #### Q3. What will the dimension of a hyperplane in a 3D space be?
#
# ![](https://images.upgrad.com/aa0f473d-0f68-4ce9-a3c4-87802b317f88-14.PNG)
#
#
# - [ ] 6
#
# - [ ] 9
#
# - [ ] 3
#
# - [x] 2
#
# ans:
# The dimension of the hyperplane is 2. It can be calculated as [number of features - 1]. If you look at the 3D plot as well, you will see that the data can be easily separated by a plane.
#
# #### Q4. In an n-dimensional setting, with n features and p data points, what will the equation of the hyperplane be?
#
# - [ ] ​W0+W1x1+W2x2+...+Wpxn=0​
# - [ ] ​W0+W1x1+W2x2+...Wn−3xn−3=0​
# - [x] ​W0+W1x1+W2x2+...+Wn−1xn−1+Wnxn=0​
# - [ ] ​W0+W1x1+W2x2+...+Wp−1xp−1+Wpxp=0
#
# ans:
# If there are n features, the equation of the hyperplane will be the additive sum of xn ​features multiplied by ​Wn​ coefficients. The number of data points does not affect the hyperplane equation. For example, with two features, say ​x1​ and ​x2​ , the equation of the hyperplane will be a straight line — i.e. ​W0+W1x1+W2x2=0,​ where ​W0​ is the intercept.
#
#
# #### Q5. In a 5-dimensional setting, if the point X = (X1, X2, X3, X4, X5) lies exactly on the hyperplane, then
#
# - [ ] W0 + W1X1 + W2X2 + W3X3 + W4X4 + W5X5 <0
# - [ ] W0 + WX1 + W2X2 + W3X3 + W4X4 + W5X5 > 0
# - [x] W0 + W1X1 + W2X2 + W3X3 + W4X4 + W5X5 = 0
# - [ ] W0 + W1X1 + W2X2 + W3X3 + W4X4 + W5X5 > 0
# ans:
# The equation of the hyperplane is given by W0 + W1X1 + W2X2 + . . . + WnXn in an n-dimensional space. If a point is exactly on the hyperplane, it will be equal to zero.
