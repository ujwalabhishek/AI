# %% [markdown]
# # Data visualization & Statitics

# %% [markdown]
# ODI: Ind Batting : https://gramener.com/cricket/
#
# How do markets react to the budget? https://gramener.com/budget/?Year=2007
#
# Software Ecosystem: https://gramener.com/software/

# %% [markdown]
# ### Notes:
#
# 1. stastical data can be misleading so visualization is necessary to draw correct analysis
#
# ![1.png](attachment:0f1bc174-2c91-4296-a17f-dc4208da3310.png)
#
# ![2.png](attachment:d399a79c-d395-4dda-aa73-5f5d774a4e99.png)
#
# 2. The visualization should be accompanied with voice or text narrative to improve user experience and understanding
#
#    ![3.jpg](attachment:60973bee-208e-44c8-b591-9af75a8b0561.jpg)
#
# 3. visualisation can help in visual exploratory analytics.  visualisation helped in understanding the connections between different musicsoftware and clustering them together based on common features
#
# ![4.png](attachment:0241f90b-ba3b-4cef-a119-6dd59f34f138.png)
#
# 4. elements that help us create charts and plots effectively. There are two types of data, which are as follows:
#
#     * Facts - Facts are **numerical data**
#
#     * Dimensions - dimensions are metadata, explains the additional information associated with the factual variable
#
# Both facts and dimensions are equally important for generating actionable insights from a given data set. For example, in a data set about the height of students in a class, the height of the students would be a fact variable, whereas the gender of the students would be a dimensional variable. You can use dimensions to slice data for easier analysis. In this case, the distribution of height based on the gender of a student can be studied.

# %% [markdown]
# # Matplotlib
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplot.html

# %%
import numpy as np
import matplotlib.pyplot as plt

product_category= np.array(['Furniture', 'Technology', 'Office Supplies'])
sales = [4110451.90, 4744557.50, 3787492.52]

# %% [markdown]
# ### Bar chart
#
# A bar graph is helpful when you need to visualise a numeric feature (fact) across multiple categories.
#
# Below we plotted the sales amount (numeric feature) under three different product categories

# %%
plt.bar(product_category, sales)
plt.show()

# %%
#plotting the bar chart and setting the bar width to 0.5 and aligining to center
plt.bar(product_category, sales, width=0.5, align='center', edgecolor= 'Orange',color='Black')
#  Ading and formatting the title
plt.title("Sales Across Catgories", fontdict={'fontsize': 20, 'fontweight':45, 'color':'Green'})
# Labeling Axes
plt.xlabel("Category", fontdict={'fontsize': 20, 'fontweight':45, 'color':'Brown'})
plt.ylabel("Sales",fontdict={'fontsize': 20, 'fontweight':45, 'color':'Brown'})
# modifying the tics to show info in million USD
ticks = np.arange(0, 6000000, 1000000)
labels = ["{} M".format(i//1000000) for i in ticks]
plt.yticks(ticks,labels)
# Out:
# ([<matplotlib.axis.YTick at 0x20d816ffb10>,
# ...
#  [Text(0, 0, '0 M'),
#   Text(0, 1000000, '1 M'),
#   Text(0, 2000000, '2 M'),
#   Text(0, 3000000, '3 M'),
#   Text(0, 4000000, '4 M'),
#   Text(0, 5000000, '5 M')])

# %%
# add diff color for each cartegory

colors = ['#4287f5', '#135dd4', '#052659']
plt.bar(product_category, sales, width=0.5, align='center',color=colors)
plt.show()

# %% [markdown]
# ### Scatter plot
#
# 1. Displays how the variables are spread across the range considered.
# 2. It can be used to identify a relationship or pattern between two quantitative variables and the presence of outliers within them.
# 3. Show relationship between two facts or measures
#
# ✅ a. To check whether a relationship exists between the age of a person and their income.
# Reason: Scatterplots are ideal for visualizing relationships (correlation) between two continuous variables like age and income.
#
# ✅ c. To check whether stock prices are positively related to the profit of a company.
# Reason: This is another example of examining a potential relationship (correlation) between two numerical variables.
#
# ❌ b. To check whether there are any irregular entries in the data range.
# Reason: Scatterplots aren't typically used for detecting irregular (anomalous) entries; box plots or data profiling tools are better for that.
#
# ❌ e. To understand the distribution of the salaries of the employees in a company.
# Reason: For distributions of a single variable, histograms or box plots are more appropriate than scatterplots.

# %% [markdown]
#  **Plot sales vs  profits  across various countries and product Categories**

# %%
# Plot sales vs  profits  across various countries and product Categories 
# Data
sales = np.array ([1013.14, 8298.48, 875.51, 22320.83, 9251.6, 4516.86, 585.16, 836154.03, 216748.48, 174.2, 27557.79, 563.25, 558.11, 37117.45, 357.36, 2206.96, 709.5, 35064.03, 7230.78, 235.33, 148.32, 3973.27, 11737.8, 7104.63, 83.67, 5569.83, 92.34, 107104.36, 1045.62, 9072.51, 42485.82, 5093.82, 14846.16, 943.92, 684.36, 15012.03, 38196.18, 2448.75, 28881.96, 13912.14, 4507.2, 4931.06, 12805.05, 67912.73, 4492.2, 1740.01, 458.04, 16904.32, 21744.53, 10417.26, 18665.33, 2808.42, 54195.57, 67332.5, 24390.95, 1790.43, 2234.19, 9917.5, 7408.14, 36051.99, 1352.22, 1907.7, 245722.14, 2154.66, 1078.21, 3391.65, 28262.73, 5177.04, 66.51, 2031.34, 1683.72, 1970.01, 6515.82, 1055.31, 1029.48, 5303.4, 1850.96, 1159.41, 39989.13, 1183.87, 96365.09, 8356.68, 7010.24, 23119.23, 46109.28, 146071.84, 242259.03, 9058.95, 1313.67, 31525.06, 2019.94, 703.04, 1868.79, 700.5, 55512.02, 243.5, 2113.18, 11781.81, 262189.49, 3487.29, 513.12, 312050.42, 5000.7, 121.02, 1302.78, 169.92, 124.29, 57366.05, 29445.93, 4614.3, 45009.98, 309.24, 3353.67, 41348.34, 2280.27, 61193.7, 1466.79, 12419.94, 445.12, 25188.65, 263514.92, 12351.23, 1152.3, 26298.81, 9900.78, 5355.57, 2325.66, 6282.81, 127707.92, 1283.1, 3560.15, 3723.84, 13715.01, 4887.9, 3396.89, 33348.42, 625.02, 1665.48, 32486.97, 340212.44, 20516.22, 8651.16, 13590.06, 2440.35, 6462.57, 1770.13, 7527.18, 1433.65, 423.3, 21601.72, 10035.72, 2378.49, 3062.38, 719469.32, 179366.79, 345.17, 30345.78, 300.71, 940.81, 36468.08, 1352.85, 1755.72, 2391.96, 19.98, 19792.8, 15633.88, 7.45, 521.67, 1118.24, 7231.68, 12399.32, 204.36, 23.64, 5916.48, 313.98, 108181.5, 9212.42, 27476.91, 1761.33, 289.5, 780.3, 15098.46, 813.27, 47.55, 8323.23, 22634.64, 1831.02, 28808.1, 10539.78, 588.99, 939.78, 7212.41, 15683.01, 41369.09, 5581.6, 403.36, 375.26, 12276.66, 15393.56, 76.65, 5884.38, 18005.49, 3094.71, 43642.78, 35554.83, 22977.11, 1026.33, 665.28, 9712.49, 6038.52, 30756.51, 3758.25, 4769.49, 2463.3, 160153.16, 967.11, 2311.74, 1414.83, 12764.91, 4191.24, 110.76, 637.34, 1195.12, 2271.63, 804.12, 196.17, 167.67, 131.77, 2842.05, 9969.12, 1784.35, 3098.49, 25005.54, 1300.1, 118697.39, 7920.54, 6471.78, 31707.57, 37636.47, 118777.77, 131170.76, 3980.88, 3339.39, 26563.9, 4038.73, 124.8, 196.65, 2797.77, 29832.76, 184.84, 79.08, 8047.83, 205313.25, 1726.98, 899.73, 224.06, 304763.54, 6101.31, 729.6, 896.07, 17.82, 26.22, 46429.78, 31167.27, 2455.94, 37714.3, 1506.93, 3812.78, 25223.34, 3795.96, 437.31, 41278.86, 2091.81, 6296.61, 468.82, 23629.64, 160435.53, 9725.46, 1317.03, 1225.26, 30034.08, 7893.45, 2036.07, 215.52, 3912.42, 82783.43, 253.14, 966.96, 3381.26, 164.07, 1984.23, 75.12, 25168.17, 3295.53, 991.12, 10772.1, 44.16, 1311.45, 35352.57, 245783.54, 20.49, 13471.06, 8171.16, 14075.67, 611.82, 3925.56, 981.84, 10209.84, 156.56, 243.06, 21287.52, 7300.51, 434.52, 6065.0, 741577.51, 132461.03, 224.75, 28953.6, 757.98, 528.15, 34922.41, 50.58, 2918.48, 1044.96, 22195.13, 3951.48, 6977.64, 219.12, 5908.38, 10987.46, 4852.26, 445.5, 71860.82, 14840.45, 24712.08, 1329.9, 1180.44, 85.02, 10341.63, 690.48, 1939.53, 20010.51, 914.31, 25223.82, 12804.66, 2124.24, 602.82, 2961.66, 15740.79, 74138.35, 7759.39, 447.0, 2094.84, 22358.95, 21734.53, 4223.73, 17679.53, 1019.85, 51848.72, 69133.3, 30146.9, 705.48, 14508.88, 7489.38, 20269.44, 246.12, 668.13, 768.93, 215677.35, 899.16, 2578.2, 4107.99, 20334.57, 366.84, 3249.27, 98.88, 3497.88, 3853.05, 786.75, 1573.68, 458.36, 1234.77, 1094.22, 2300.61, 970.14, 3068.25, 35792.85, 4277.82, 71080.28, 3016.86, 3157.49, 15888.0, 30000.36, 140037.89, 216056.25, 1214.22, 1493.94, 32036.69, 4979.66, 106.02, 46257.68, 1033.3, 937.32, 3442.62, 160633.45, 213.15, 338.88, 242117.13, 9602.34, 2280.99, 73759.08, 23526.12, 6272.74, 43416.3, 576.78, 1471.61, 20844.9, 3497.7, 56382.38, 902.58, 6235.26, 48.91, 32684.24, 276611.58, 13370.38, 10595.28, 4555.14, 10084.38, 267.72, 1012.95, 4630.5, 149433.51, 364.32, 349.2, 4647.56, 504.0, 10343.52, 5202.66, 2786.26, 34135.95, 2654.58, 24699.51, 339239.87, 136.26, 23524.51, 8731.68, 8425.86, 835.95, 11285.19])
profit = np.array([-1213.46, 1814.13, -1485.7, -2286.73, -2872.12, 946.8, 198.48, 145454.95, 49476.1, -245.56, 5980.77, -790.47, -895.72, -34572.08, 117.9, 561.96, 152.85, 1426.05, 1873.17, -251.03, 68.22, 635.11, 3722.4, -3168.63, 27.6, 952.11, 7.38, 20931.13, 186.36, -5395.38, 9738.45, 525.27, 3351.99, 120.78, 266.88, 3795.21, 8615.97, 609.54, 7710.57, 2930.43, 1047.96, -2733.32, 2873.73, -5957.89, -909.6, 163.41, -376.02, -6322.68, -10425.86, 2340.36, -28430.53, 756.12, 12633.33, 7382.54, -14327.69, 436.44, 683.85, -694.91, 1960.56, 10925.82, 334.08, 425.49, 53580.2, 1024.56, 110.93, 632.22, 8492.58, 1418.88, 19.26, -2567.57, 346.26, 601.86, 1318.68, 304.05, 428.37, 1416.24, -2878.18, 283.41, 12611.04, 261.95, -648.43, 1112.88, -2640.29, 6154.32, 11558.79, 15291.4, 56092.65, 1515.39, 342.03, -10865.66, -902.8, 351.52, 364.17, 87.72, 11565.66, 75.4, 289.33, 3129.63, 50795.72, 783.72, 215.46, 29196.89, 1147.26, 53.22, 286.56, 73.02, 42.24, 13914.85, 5754.54, 998.04, -1476.04, 86.58, -1636.35, 10511.91, 647.34, 13768.62, 338.67, 3095.67, 173.84, 5632.93, 64845.11, 3297.33, 338.61, 7246.62, 2255.52, 1326.36, 827.64, 1100.58, 9051.36, 412.23, 1063.91, 940.59, 3891.84, 1599.51, 1129.57, 8792.64, 6.24, 592.77, 8792.85, 47727.5, -4597.68, 2242.56, 3546.45, 321.87, 1536.72, -2463.29, 1906.08, -1916.99, 186.24, 3002.05, -3250.98, 554.7, 830.64, 122612.79, 33894.21, -559.03, 7528.05, -477.67, -1660.25, -33550.96, 481.68, 425.08, 450.3, 9.57, -3025.29, 2924.62, -11.84, 87.36, 26.51, 1727.19, -6131.18, 59.16, 3.06, 1693.47, 74.67, 24729.21, -4867.94, 6705.18, 410.79, 70.74, 101.7, 3264.3, 137.01, 6.18, 2100.21, 5295.24, 520.29, 7205.52, 2602.65, 116.67, 224.91, -5153.93, 3882.69, -6535.24, -1254.1, 84.56, -186.38, -3167.2, -7935.59, 37.02, 1908.06, -27087.84, 829.32, 8727.44, 2011.47, -11629.64, 234.96, 53.1, 1248.14, 1511.07, 7374.24, 1193.28, 1090.23, 553.86, 38483.86, 255.81, 528.54, 326.07, 3924.36, 1018.92, 36.48, 113.24, -1770.05, 527.64, 224.49, 79.53, 64.77, 38.08, 868.08, 2265.06, -2643.62, 833.73, 5100.03, 326.44, 18158.84, 1682.01, -3290.22, 8283.33, 7926.18, 1694.41, 30522.92, 1214.07, 900.6, -6860.8, -865.91, 26.16, 47.22, 863.52, 7061.26, 73.92, 33.12, 1801.23, 38815.44, 431.13, 216.81, 16.5, 53688.2, 1210.32, 236.94, 210.84, 3.18, 2.22, 10265.64, 7212.3, 343.56, 3898.28, 568.11, -1867.85, 5782.38, 697.29, -192.06, 10179.02, 616.32, 1090.47, 165.84, 6138.28, 39723.06, 2085.14, 90.0, 129.93, 7957.53, 2131.86, 562.44, 99.12, 1298.37, 7580.33, 113.73, 139.71, 456.0, 21.24, 292.68, 30.34, 5817.15, 1060.89, 252.9, 3060.61, 6.6, 219.09, 8735.82, 31481.09, 2.85, -3124.72, 2195.94, 3464.7, 141.12, 1125.69, -1752.03, 3281.52, -303.77, 114.18, -2412.63, -5099.61, 146.64, 660.22, 18329.28, 28529.84, -232.27, 7435.41, -1157.94, -746.73, -30324.2, 2.52, 1313.44, 213.72, -5708.95, 930.18, 1663.02, 31.59, 1787.88, -8219.56, 973.92, 4.32, 8729.78, -2529.52, 5361.06, 69.21, 519.3, 13.56, 2236.77, 213.96, 367.98, 5074.2, 206.61, 7620.36, 2093.19, 164.07, 230.01, -815.82, 4226.7, -3635.09, -3344.17, 167.26, 143.79, -8233.57, -4085.21, 919.35, -25232.35, 234.33, 12040.68, 7206.28, -15112.76, 206.04, -2662.49, 2346.81, 4461.36, 93.48, 82.11, 147.87, 10389.53, 395.58, 474.74, 1333.26, 3913.02, 117.36, 858.78, 6.9, -4628.49, 1170.6, 218.55, 539.58, -211.0, 438.87, 317.16, 310.8, -1578.09, 706.56, 6617.4, 803.84, 2475.26, 764.34, -1461.88, 3805.56, 7371.27, -1377.13, 42435.03, 472.47, 315.48, -11755.91, -2418.6, 6.36, 9317.76, 326.88, -287.31, 637.68, 17579.17, 70.83, 47.4, 26143.92, 1548.15, 612.78, 17842.76, 6735.39, 1206.5, -10035.74, 149.4, -777.85, 5566.29, 748.92, 14941.58, 348.93, 1944.06, -5.51, 7026.84, 46114.92, 2361.86, 2613.24, 1277.37, 2587.74, 103.08, 311.43, 1250.58, 13055.21, 18.21, 108.24, 709.44, 115.92, 1863.6, 1873.86, 817.32, 7577.64, 1019.19, 6813.03, 24698.84, 66.24, -10971.39, 2056.47, 2095.35, 246.33, 2797.89])
product_category = np.array(['Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Technology', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Office Supplies', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture', 'Furniture'])
country = np.array(['Zimbabwe', 'Zambia', 'Yemen', 'Vietnam', 'Venezuela', 'Uzbekistan', 'Uruguay', 'United States', 'United Kingdom', 'United Arab Emirates', 'Ukraine', 'Uganda', 'Turkmenistan', 'Turkey', 'Tunisia', 'Trinidad and Tobago', 'Togo', 'Thailand', 'Tanzania', 'Tajikistan', 'Taiwan', 'Syria', 'Switzerland', 'Sweden', 'Swaziland', 'Sudan', 'Sri Lanka', 'Spain', 'South Sudan', 'South Korea', 'South Africa', 'Somalia', 'Singapore', 'Sierra Leone', 'Serbia', 'Senegal', 'Saudi Arabia', 'Rwanda', 'Russia', 'Romania', 'Qatar', 'Portugal', 'Poland', 'Philippines', 'Peru', 'Paraguay', 'Papua New Guinea', 'Panama', 'Pakistan', 'Norway', 'Nigeria', 'Niger', 'Nicaragua', 'New Zealand', 'Netherlands', 'Nepal', 'Namibia', 'Myanmar (Burma)', 'Mozambique', 'Morocco', 'Mongolia', 'Moldova', 'Mexico', 'Mauritania', 'Martinique', 'Mali', 'Malaysia', 'Madagascar', 'Luxembourg', 'Lithuania', 'Libya', 'Liberia', 'Lesotho', 'Lebanon', 'Kyrgyzstan', 'Kenya', 'Kazakhstan', 'Jordan', 'Japan', 'Jamaica', 'Italy', 'Israel', 'Ireland', 'Iraq', 'Iran', 'Indonesia', 'India', 'Hungary', 'Hong Kong', 'Honduras', 'Haiti', 'Guyana', 'Guinea-Bissau', 'Guinea', 'Guatemala', 'Guadeloupe', 'Greece', 'Ghana', 'Germany', 'Georgia', 'Gabon', 'France', 'Finland', 'Ethiopia', 'Estonia', 'Eritrea', 'Equatorial Guinea', 'El Salvador', 'Egypt', 'Ecuador', 'Dominican Republic', 'Djibouti', 'Denmark', 'Democratic Republic of the Congo', 'Czech Republic', 'Cuba', 'Croatia', "Cote d'Ivoire", 'Costa Rica', 'Colombia', 'China', 'Chile', 'Central African Republic', 'Canada', 'Cameroon', 'Cambodia', 'Burkina Faso', 'Bulgaria', 'Brazil', 'Bosnia and Herzegovina', 'Bolivia', 'Benin', 'Belgium', 'Belarus', 'Barbados', 'Bangladesh', 'Bahrain', 'Azerbaijan', 'Austria', 'Australia', 'Argentina', 'Angola', 'Algeria', 'Albania', 'Afghanistan', 'Zimbabwe', 'Zambia', 'Yemen', 'Western Sahara', 'Vietnam', 'Venezuela', 'Uzbekistan', 'Uruguay', 'United States', 'United Kingdom', 'United Arab Emirates', 'Ukraine', 'Uganda', 'Turkmenistan', 'Turkey', 'Tunisia', 'Trinidad and Tobago', 'Togo', 'The Gambia', 'Thailand', 'Tanzania', 'Tajikistan', 'Taiwan', 'Syria', 'Switzerland', 'Sweden', 'Swaziland', 'Suriname', 'Sudan', 'Sri Lanka', 'Spain', 'South Korea', 'South Africa', 'Somalia', 'Slovenia', 'Slovakia', 'Singapore', 'Sierra Leone', 'Serbia', 'Senegal', 'Saudi Arabia', 'Rwanda', 'Russia', 'Romania', 'Republic of the Congo', 'Qatar', 'Portugal', 'Poland', 'Philippines', 'Peru', 'Paraguay', 'Papua New Guinea', 'Panama', 'Pakistan', 'Oman', 'Norway', 'Nigeria', 'Niger', 'Nicaragua', 'New Zealand', 'Netherlands', 'Nepal', 'Namibia', 'Myanmar (Burma)', 'Mozambique', 'Morocco', 'Montenegro', 'Mongolia', 'Moldova', 'Mexico', 'Mauritania', 'Martinique', 'Mali', 'Malaysia', 'Madagascar', 'Macedonia', 'Luxembourg', 'Lithuania', 'Libya', 'Liberia', 'Lesotho', 'Lebanon', 'Laos', 'Kyrgyzstan', 'Kenya', 'Kazakhstan', 'Jordan', 'Japan', 'Jamaica', 'Italy', 'Israel', 'Ireland', 'Iraq', 'Iran', 'Indonesia', 'India', 'Hungary', 'Hong Kong', 'Honduras', 'Haiti', 'Guyana', 'Guinea-Bissau', 'Guinea', 'Guatemala', 'Guadeloupe', 'Greece', 'Ghana', 'Germany', 'Georgia', 'Gabon', 'French Guiana', 'France', 'Finland', 'Ethiopia', 'Estonia', 'Eritrea', 'Equatorial Guinea', 'El Salvador', 'Egypt', 'Ecuador', 'Dominican Republic', 'Djibouti', 'Denmark', 'Democratic Republic of the Congo', 'Czech Republic', 'Cyprus', 'Cuba', 'Croatia', "Cote d'Ivoire", 'Costa Rica', 'Colombia', 'China', 'Chile', 'Chad', 'Central African Republic', 'Canada', 'Cameroon', 'Cambodia', 'Burkina Faso', 'Bulgaria', 'Brazil', 'Botswana', 'Bosnia and Herzegovina', 'Bolivia', 'Bhutan', 'Benin', 'Belize', 'Belgium', 'Belarus', 'Barbados', 'Bangladesh', 'Bahrain', 'Azerbaijan', 'Austria', 'Australia', 'Armenia', 'Argentina', 'Angola', 'Algeria', 'Albania', 'Afghanistan', 'Zimbabwe', 'Zambia', 'Yemen', 'Western Sahara', 'Vietnam', 'Venezuela', 'Uzbekistan', 'Uruguay', 'United States', 'United Kingdom', 'United Arab Emirates', 'Ukraine', 'Uganda', 'Turkmenistan', 'Turkey', 'Tunisia', 'Trinidad and Tobago', 'Togo', 'Thailand', 'Tanzania', 'Taiwan', 'Syria', 'Switzerland', 'Sweden', 'Sudan', 'Sri Lanka', 'Spain', 'South Korea', 'South Africa', 'Somalia', 'Slovenia', 'Slovakia', 'Singapore', 'Sierra Leone', 'Senegal', 'Saudi Arabia', 'Rwanda', 'Russia', 'Romania', 'Republic of the Congo', 'Qatar', 'Portugal', 'Poland', 'Philippines', 'Peru', 'Paraguay', 'Papua New Guinea', 'Panama', 'Pakistan', 'Norway', 'Nigeria', 'Niger', 'Nicaragua', 'New Zealand', 'Netherlands', 'Nepal', 'Myanmar (Burma)', 'Mozambique', 'Morocco', 'Montenegro', 'Mongolia', 'Moldova', 'Mexico', 'Mauritania', 'Martinique', 'Mali', 'Malaysia', 'Malawi', 'Madagascar', 'Macedonia', 'Lithuania', 'Libya', 'Liberia', 'Lebanon', 'Laos', 'Kyrgyzstan', 'Kuwait', 'Kenya', 'Kazakhstan', 'Jordan', 'Japan', 'Jamaica', 'Italy', 'Israel', 'Ireland', 'Iraq', 'Iran', 'Indonesia', 'India', 'Hungary', 'Hong Kong', 'Honduras', 'Haiti', 'Guyana', 'Guatemala', 'Guadeloupe', 'Greece', 'Ghana', 'Germany', 'Georgia', 'Gabon', 'France', 'Finland', 'Estonia', 'El Salvador', 'Egypt', 'Ecuador', 'Dominican Republic', 'Djibouti', 'Denmark', 'Democratic Republic of the Congo', 'Czech Republic', 'Cuba', 'Croatia', "Cote d'Ivoire", 'Costa Rica', 'Colombia', 'China', 'Chile', 'Canada', 'Cameroon', 'Cambodia', 'Burundi', 'Burkina Faso', 'Bulgaria', 'Brazil', 'Botswana', 'Bosnia and Herzegovina', 'Bolivia', 'Benin', 'Belgium', 'Belarus', 'Barbados', 'Bangladesh', 'Azerbaijan', 'Austria', 'Australia', 'Armenia', 'Argentina', 'Angola', 'Algeria', 'Albania', 'Afghanistan'])

# %%
# Plotting scatter plot 
plt.scatter(sales, profit, alpha=0.5)
plt.title("Sales vs profit", fontdict={'fontsize':20,'color':'green'})
plt.xlabel('Sales', fontdict={'fontsize':20,'color':'Brown'})
plt.ylabel('Profit', fontdict={'fontsize':20,'color':'Brown'})
plt.show()

# %% [markdown]
# **Scatter Chart** - Plot Sales versus Profits across various Countries and Product Categories
#  * Represent product category using different colors
#  * Adding a Legend to Product Categories

# %%
plt.scatter(profit[product_category =='Technology'], sales[product_category =='Technology'], alpha=0.5, c='Green', label='Technology', s=150)
plt.scatter(profit[product_category =='Office Supplies'], sales[product_category =='Office Supplies'], alpha=0.5, c='Yellow', label='Office Supplies', s=100)
plt.scatter(profit[product_category =='Furniture'], sales[product_category =='Furniture'], alpha=0.5, c='Red', label='Furniture', s=50)
plt.xlabel('Sales', fontdict={'fontsize':20,'color':'Brown'})
plt.ylabel('Profit', fontdict={'fontsize':20,'color':'Brown'})
#show title
plt.title("Sales vs Profit across various Category ", fontdict={'fontsize':20,'color':'green'})
# Show legends
plt.legend()
plt.show()

# %% [markdown]
# Now lets use the fourth data set which is 'country' see below
#
# Suppose you have the array ‘country’, which indicates the **country where the sales were generated**. Now you want to highlight the points belonging to a particular country in the previous scatter plot.
#
# You can use the following command to add a note (annotate) with a point in the scatter plot

# %%
plt.scatter(profit[product_category =='Technology'], sales[product_category =='Technology'], alpha=0.5, c='Green', label='Technology', s=150)
plt.scatter(profit[product_category =='Office Supplies'], sales[product_category =='Office Supplies'], alpha=0.5, c='Yellow', label='Office Supplies', s=100)
plt.scatter(profit[product_category =='Furniture'], sales[product_category =='Furniture'], alpha=0.5, c='Red', label='Furniture', s=50)
plt.xlabel('Sales', fontdict={'fontsize':20,'color':'Brown'})
plt.ylabel('Profit', fontdict={'fontsize':20,'color':'Brown'})
#show title
plt.title("Sales vs Profit across various Category ", fontdict={'fontsize':20,'color':'green'})
# Show legends
plt.legend()
for xy in zip(profit[country=='India'], sales[country=='India']):
    plt.annotate(text='India', xy = xy)
plt.show()

# %% [markdown]
# #### Markup in graph with arrow

# %%
# Use of drop arrowe and xytext 
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 1, 4]

# Create scatter plot
plt.scatter(x, y, color='blue')

# Annotate the third point (x=3, y=5)
plt.annotate(
    'Important Point',        # The text
    xy=(3, 5),                # The point to annotate
    xytext=(4, 6),            # The position of the text
    arrowprops=dict(arrowstyle='->', color='red')  # Draw an arrow
)

plt.title('Scatter Plot with Annotation')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Line Graph
#
# A line graph is used to present continuous time-dependent data. It accurately depicts the trend of a variable over a specified time period

# %% [markdown]
#  **Plot Sales Across 2015**

# %%
#data
months = np.array(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
sales = np.array([241268.56, 184837.36, 263100.77, 242771.86, 288401.05, 401814.06, 258705.68, 456619.94, 481157.24, 422766.63, 555279.03, 503143.69])

plt.plot(months,sales)
plt.xlabel('Months', fontdict={'fontsize':20,'color':'Brown'})
plt.ylabel('Sales', fontdict={'fontsize':20,'color':'Brown'})
plt.title("Sales across 2015", fontdict={'fontsize':20,'color':'green'})
ticks = np.arange(0, 600000, 50000)
labels = ["{}K".format(i/1000) for i in ticks]
plt.yticks(ticks, labels) 
#| Parameter  | Description                                                                        |
# | ---------- | ---------------------------------------------------------------------------------- |
# | `ticks`    | List of positions (floats or ints) where you want the ticks to appear.             |
# | `labels`   | List of strings (same length as `ticks`) for custom tick labels.                   |
# | `**kwargs` | Keyword arguments for `Text` objects (like `fontsize`, `rotation`, `color`, etc.). |

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
#  ## Text Styling for labels:

# %% [markdown]
# | Kwarg        | Purpose                  |
# | ------------ | ------------------------ |
# | `fontsize`   | Font size of tick labels |
# | `rotation`   | Rotate text (in degrees) |
# | `color`      | Color of labels          |
# | `fontweight` | 'bold', 'normal', etc.   |
# | `ha`         | Horizontal alignment     |
# | `va`         | Vertical alignment       |
#
#
#
#
# | Keyword                       | Description                                                                            |
# | ----------------------------- | -------------------------------------------------------------------------------------- |
# | `fontsize`                    | Font size of the text (e.g., `10`, `'large'`, `'x-small'`)                             |
# | `fontweight`                  | Weight of the font: `'normal'`, `'bold'`, `'light'`, `'heavy'`                         |
# | `fontstyle`                   | Style of font: `'normal'`, `'italic'`, `'oblique'`                                     |
# | `fontfamily`                  | Font family: `'serif'`, `'sans-serif'`, `'monospace'`, etc.                            |
# | `color`                       | Text color (name or hex): `'blue'`, `'#FF5733'`                                        |
# | `rotation`                    | Angle of rotation for the text (in degrees)                                            |
# | `horizontalalignment` or `ha` | `'left'`, `'center'`, `'right'`                                                        |
# | `verticalalignment` or `va`   | `'top'`, `'center'`, `'bottom'`, `'baseline'`                                          |
# | `alpha`                       | Transparency (0 to 1)                                                                  |
# | `backgroundcolor`             | Background fill color behind the text                                                  |
# | `bbox`                        | A dictionary to style the background box (e.g., `dict(facecolor='yellow', alpha=0.5)`) |
# | `label`                       | Text label (not used often with ticks)                                                 |
# | `zorder`                      | Layering order of the text (higher = in front)                                         |
# | `clip_on`                     | Whether the text should be clipped at the axes boundary (`True` or `False`)            |

# %%
# Example using many kwargs 
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y)
plt.xticks(
    [1, 2, 3, 4],
    ['One', 'Two', 'Three', 'Four'],
    fontsize=12,
    fontweight='bold',
    color='green',
    rotation=45,
    ha='right',
    va='top',
    backgroundcolor='yellow',
    bbox=dict(boxstyle='round,pad=0.3', fc='lightblue', ec='black', lw=1)
)
plt.show()

# %%
y = np.random.randint(1,100, 50)
plt.plot(y, 'ro') # ‘ro’ represents color (r) and marker (o) markers can be + also

# %%
plt.plot(y, 'red', marker = 'D')

# %% [markdown]
# | Marker Symbol | Description      |
# | ------------- | ---------------- |
# | `'o'`         | Circle (default) |
# | `'^'`         | Triangle up      |
# | `'v'`         | Triangle down    |
# | `'s'`         | Square           |
# | `'p'`         | Pentagon         |
# | `'*'`         | Star             |
# | `'+'`         | Plus             |
# | `'x'`         | Cross (x)        |
# | `'D'`         | Diamond          |
# | `'h'`         | Hexagon          |

# %% [markdown]
# ### Add markers

# %%
months = np.array(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
sales = np.array([241268.56, 184837.36, 263100.77, 242771.86, 288401.05, 401814.06, 258705.68, 456619.94, 481157.24, 422766.63, 555279.03, 503143.69])

plt.plot(months,sales)
plt.xlabel('Months', fontdict={'fontsize':20,'color':'Brown'})
plt.ylabel('Sales', fontdict={'fontsize':20,'color':'Brown'})
plt.title("Sales across 2015", fontdict={'fontsize':20,'color':'green'})
ticks = np.arange(0, 600000, 50000)
labels = ["{}K".format(i/1000) for i in ticks]
plt.yticks(ticks, labels) 
#| Parameter  | Description                                                                        |
# | ---------- | ---------------------------------------------------------------------------------- |
# | `ticks`    | List of positions (floats or ints) where you want the ticks to appear.             |
# | `labels`   | List of strings (same length as `ticks`) for custom tick labels.                   |
# | `**kwargs` | Keyword arguments for `Text` objects (like `fontsize`, `rotation`, `color`, etc.). |

plt.xticks(rotation=90)
for xy in zip(months,sales):
    plt.annotate("{}K".format(xy[1]//1000), xy=xy, textcoords='data')

plt.show()

# %% [markdown]
# ### Label Positioning
# #### Common textcoords Values:
# | Value               | Meaning                                  |
# | ------------------- | ---------------------------------------- |
# | `'offset points'`   | Offset (in points) from `xy`             |
# | `'offset pixels'`   | Offset (in pixels) from `xy`             |
# | `'data'`            | Use data coordinates (same as plot axes) |
# | `'axes fraction'`   | Fraction of axes (0 to 1)                |
# | `'figure fraction'` | Fraction of figure window (0 to 1)       |
# | `'axes points'`     | Offset in points from axes origin        |
# | `'figure points'`   | Offset in points from figure origin      |

# %%
# Example: textcoords='offset points'

plt.plot(months,sales)
plt.xlabel('Months', fontdict={'fontsize':20,'color':'Brown'})
plt.ylabel('Sales', fontdict={'fontsize':20,'color':'Brown'})
plt.title("Sales across 2015", fontdict={'fontsize':20,'color':'green'})
ticks = np.arange(0, 600000, 50000)
labels = ["{}K".format(i/1000) for i in ticks]
plt.yticks(ticks, labels) 
#| Parameter  | Description                                                                        |
# | ---------- | ---------------------------------------------------------------------------------- |
# | `ticks`    | List of positions (floats or ints) where you want the ticks to appear.             |
# | `labels`   | List of strings (same length as `ticks`) for custom tick labels.                   |
# | `**kwargs` | Keyword arguments for `Text` objects (like `fontsize`, `rotation`, `color`, etc.). |

plt.xticks(rotation=90)
for xy in zip(months,sales):
    plt.annotate(text="{}K".format(xy[1]//1000), xy=xy,  xytext=(5, 5),textcoords='offset points')
    
# | Value               | Meaning                                  |
# | ------------------- | ---------------------------------------- |
# | `'offset points'`   | Offset (in points) from `xy`             |
# | `'offset pixels'`   | Offset (in pixels) from `xy`             |
# | `'data'`            | Use data coordinates (same as plot axes) |
# | `'axes fraction'`   | Fraction of axes (0 to 1)                |
# | `'figure fraction'` | Fraction of figure window (0 to 1)       |
# | `'axes points'`     | Offset in points from axes origin        |
# | `'figure points'`   | Offset in points from figure origin      |

plt.show()

# %% [markdown]
# ## Histogram
#
# Histogram is a frequency chart that records the number of occurrences of an entry or an element in a data set. It can be useful when you want to understand the

# %%
# Data
profit = np.array([-5428.79, 7001.73, -3706.46, 300.42, -1697.31, -11222.71, 1648.14, 1689.34, -1036.86, 20944.23, -2426.09, -3302.71, 602.1, 2300.48, 816.87, 9.57, -7308.2, 5727.97, -262.87, 1818.6, 693.21, 7237.47, -17519.37, 86.76, 3.06, 3619.5, 86.37, 54390.12, 186.36, -12792.83, 21804.69, 1005.27, 590.04, 115.26, 8853.06, 471.75, 273.06, 6263.4, 18985.41, 1336.44, 22536.45, 7626.27, 280.74, 1502.88, -8703.06, 10983.12, -16128.23, -5507.88, 415.23, -418.61, -17723.45, -22446.65, 37.02, 5167.77, 1819.77, 33401.44, 16600.28, 877.44, 736.95, -2109.26, 5818.44, 22761.42, 1286.76, 1506.42, 1127.22, 1675.95, 1114.21, 2291.55, 16329.96, 117.36, 3296.58, 43.38, 132.5, -8966.12, 2044.5, 1044.9, 1398.21, 908.4, -172.92, 1735.32, 317.16, 3992.1, -7099.9, 1823.7, 24328.47, 1392.23, 19985.68, 3559.23, -7392.38, 18243.21, 26856.24, 15608.68, 3201.93, 1558.11, -29482.37, -4187.31, 384.04, 411.39, 951.24, 27944.69, 476.2, 35.14, 5568.54, 1285.68, 479.67, 16.5, 3905.73, 290.16, 1110.18, 76.2, 44.46, 42023.24, 19702.23, 2548.1, -7613.5, 804.09, -4282.05, 21860.58, 2093.55, -192.06, 38889.22, 1303.92, 6130.2, 334.17, 18798.05, 7744.33, 90.0, 468.54, 17817.39, 5664.75, 4476.54, 103.08, 1238.19, 3649.53, 29686.9, 131.94, 660.18, 2229.35, 21.24, 1349.19, 30.34, 11572.59, 4534.26, 2199.79, 19430.89, 12.84, 1831.05, 24341.7, 69.09, -18693.8, 6494.97, 9106.5, 709.32, 5460.3])

# %%
plt.hist(profit, bins=100, edgecolor='Orange', color='Blue')
plt.show()

# %%
#xtick 

out1 , bins , out2 = plt.hist(profit, bins=20, edgecolor='Orange', color='Blue')
# | Variable | What It Contains                  | Type                    |
# | -------- | --------------------------------- | ----------------------- |
# | `out1`   | Heights of each bar (frequencies) | `numpy.ndarray`         |
# | `bins`   | Bin edge values                   | `numpy.ndarray`         |
# | `out2`   | List of bar rectangles            | `list of Patch objects` |
plt.xticks(bins,rotation=90)
plt.show()

# out2 → patches:
# This is a list of rectangle objects (bars) drawn in the histogram.
# Each one is a matplotlib.patches.Rectangle object, representing one bar.

# You can use it to change the appearance of individual bars, e.g.:

# for patch in out2:
#     patch.set_linewidth(5)

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.randn(1000)
#print(data)
# Histogram with 20 bins
plt.hist(data, bins=20, color='skyblue', edgecolor='black')
# | String      | Description                             |
# | ----------- | --------------------------------------- |
# | `'auto'`    | Automatic based on data size and spread |
# | `'fd'`      | Freedman–Diaconis estimator             |
# | `'sturges'` | Sturges’ formula                        |
# | `'sqrt'`    | Square root of number of data points    |

plt.title("Histogram with 20 Bins")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Understanding Bins
#
# Suppose we have the following ages of 10 people:
#
#  >ages = [5, 7, 8, 12, 13, 14, 18, 21, 22, 25]
#
# If you draw a histogram with:
#
#  > plt.hist(ages, bins=4)
#
#  **Here's What Happens:**
#
#  Python divides the range of values (5 to 25) into 4 equal parts (bins):
#
#     | Bin # | Range    | Values that fall in this bin | Count |
#     | ----- | -------- | ---------------------------- | ----- |
#     | 1     | 5 to 10  | 5, 7, 8                      | 3     |
#     | 2     | 10 to 15 | 12, 13, 14                   | 3     |
#     | 3     | 15 to 20 | 18                           | 1     |
#     | 4     | 20 to 25 | 21, 22, 25                   | 3     |
#
# The histogram will show bars for each bin height (3, 3, 1, 3).
#
# Visualizing with Code:

# %%
import matplotlib.pyplot as plt

ages = [5, 7, 8, 12, 13, 14, 18, 21, 22, 25]

plt.hist(ages, bins=4, edgecolor='black')
plt.title("Histogram of Ages with 4 Bins")
plt.xlabel("Age Ranges (Bins)")
plt.ylabel("Number of People")
plt.grid(True)
plt.show()

# %% [markdown]
# So, in simplest terms:
#
# A "bin" is a bucket for values.
#
# The number of bins controls how many bars your histogram has.
#
# More bins = more detail, fewer bins = more summary.

# %% [markdown]
# ## Box Plot
#
# It is used to visualise the spread of a numerical variable.
#
# You can also use line graphs to plot and visualize time series data.
#
# Box plots are quite effective in summarising the spread of a large data set into a visual representation.
# They use percentiles to divide the data range.
#
# The percentile value gives the proportion of the data range that falls below a chosen data point when all the data points are arranged in the descending order. For example, if a data point with a value of **700 has a percentile value of 99%** in a data set, then it **means that 99% of the values in the data set are less than 700**.

# %% [markdown]
# Box and Whisker Chart - Sales across Countries and Product Categories
#
# A Box and Whisker Plot (or Box Plot) is a convenient way of visually **displaying the data distribution through their quartiles**. The lines extending parallel from the boxes are known as the **“whiskers”, which are used to indicate variability outside the upper and lower quartiles**. Outliers are sometimes plotted as individual dots that are in-line with whiskers. Box Plots can be drawn either vertically or horizontally.

# %%
# Data
sales_technology = np.array ([1013.14, 8298.48, 875.51, 22320.83, 9251.6, 4516.86, 585.16, 174.2, 27557.79, 563.25, 558.11, 37117.45, 357.36, 2206.96, 709.5, 35064.03, 7230.78, 235.33, 148.32, 3973.27, 11737.8, 7104.63, 83.67, 5569.83, 92.34, 1045.62, 9072.51, 42485.82, 5093.82, 14846.16, 943.92, 684.36, 15012.03, 38196.18, 2448.75, 28881.96, 13912.14, 4507.2, 4931.06, 12805.05, 67912.73, 4492.2, 1740.01, 458.04, 16904.32, 21744.53, 10417.26, 18665.33, 2808.42, 54195.57, 67332.5, 24390.95, 1790.43, 2234.19, 9917.5, 7408.14, 36051.99, 1352.22, 1907.7, 2154.66, 1078.21, 3391.65, 28262.73, 5177.04, 66.51, 2031.34, 1683.72, 1970.01, 6515.82, 1055.31, 1029.48, 5303.4, 1850.96, 1159.41, 39989.13, 1183.87, 96365.09, 8356.68, 7010.24, 23119.23, 46109.28, 9058.95, 1313.67, 31525.06, 2019.94, 703.04, 1868.79, 700.5, 55512.02, 243.5, 2113.18, 11781.81, 3487.29, 513.12, 5000.7, 121.02, 1302.78, 169.92, 124.29, 57366.05, 29445.93, 4614.3, 45009.98, 309.24, 3353.67, 41348.34, 2280.27, 61193.7, 1466.79, 12419.94, 445.12, 25188.65, 12351.23, 1152.3, 26298.81, 9900.78, 5355.57, 2325.66, 6282.81, 1283.1, 3560.15, 3723.84, 13715.01, 4887.9, 3396.89, 33348.42, 625.02, 1665.48, 32486.97, 20516.22, 8651.16, 13590.06, 2440.35, 6462.57])
sales_office_supplies = np.array ([1770.13, 7527.18, 1433.65, 423.3, 21601.72, 10035.72, 2378.49, 3062.38, 345.17, 30345.78, 300.71, 940.81, 36468.08, 1352.85, 1755.72, 2391.96, 19.98, 19792.8, 15633.88, 7.45, 521.67, 1118.24, 7231.68, 12399.32, 204.36, 23.64, 5916.48, 313.98, 9212.42, 27476.91, 1761.33, 289.5, 780.3, 15098.46, 813.27, 47.55, 8323.23, 22634.64, 1831.02, 28808.1, 10539.78, 588.99, 939.78, 7212.41, 15683.01, 41369.09, 5581.6, 403.36, 375.26, 12276.66, 15393.56, 76.65, 5884.38, 18005.49, 3094.71, 43642.78, 35554.83, 22977.11, 1026.33, 665.28, 9712.49, 6038.52, 30756.51, 3758.25, 4769.49, 2463.3, 967.11, 2311.74, 1414.83, 12764.91, 4191.24, 110.76, 637.34, 1195.12, 2271.63, 804.12, 196.17, 167.67, 131.77, 2842.05, 9969.12, 1784.35, 3098.49, 25005.54, 1300.1, 7920.54, 6471.78, 31707.57, 37636.47, 3980.88, 3339.39, 26563.9, 4038.73, 124.8, 196.65, 2797.77, 29832.76, 184.84, 79.08, 8047.83, 1726.98, 899.73, 224.06, 6101.31, 729.6, 896.07, 17.82, 26.22, 46429.78, 31167.27, 2455.94, 37714.3, 1506.93, 3812.78, 25223.34, 3795.96, 437.31, 41278.86, 2091.81, 6296.61, 468.82, 23629.64, 9725.46, 1317.03, 1225.26, 30034.08, 7893.45, 2036.07, 215.52, 3912.42, 82783.43, 253.14, 966.96, 3381.26, 164.07, 1984.23, 75.12, 25168.17, 3295.53, 991.12, 10772.1, 44.16, 1311.45, 35352.57, 20.49, 13471.06, 8171.16, 14075.67, 611.82, 3925.56])
sales_furniture = np.array ([981.84, 10209.84, 156.56, 243.06, 21287.52, 7300.51, 434.52, 6065.0, 224.75, 28953.6, 757.98, 528.15, 34922.41, 50.58, 2918.48, 1044.96, 22195.13, 3951.48, 6977.64, 219.12, 5908.38, 10987.46, 4852.26, 445.5, 71860.82, 14840.45, 24712.08, 1329.9, 1180.44, 85.02, 10341.63, 690.48, 1939.53, 20010.51, 914.31, 25223.82, 12804.66, 2124.24, 602.82, 2961.66, 15740.79, 74138.35, 7759.39, 447.0, 2094.84, 22358.95, 21734.53, 4223.73, 17679.53, 1019.85, 51848.72, 69133.3, 30146.9, 705.48, 14508.88, 7489.38, 20269.44, 246.12, 668.13, 768.93, 899.16, 2578.2, 4107.99, 20334.57, 366.84, 3249.27, 98.88, 3497.88, 3853.05, 786.75, 1573.68, 458.36, 1234.77, 1094.22, 2300.61, 970.14, 3068.25, 35792.85, 4277.82, 71080.28, 3016.86, 3157.49, 15888.0, 30000.36, 1214.22, 1493.94, 32036.69, 4979.66, 106.02, 46257.68, 1033.3, 937.32, 3442.62, 213.15, 338.88, 9602.34, 2280.99, 73759.08, 23526.12, 6272.74, 43416.3, 576.78, 1471.61, 20844.9, 3497.7, 56382.38, 902.58, 6235.26, 48.91, 32684.24, 13370.38, 10595.28, 4555.14, 10084.38, 267.72, 1012.95, 4630.5, 364.32, 349.2, 4647.56, 504.0, 10343.52, 5202.66, 2786.26, 34135.95, 2654.58, 24699.51, 136.26, 23524.51, 8731.68, 8425.86, 835.95, 11285.19])

plt.boxplot([sales_technology, sales_furniture, sales_office_supplies])
plt.title("Sales Data", fontdict={'fontsize':20,'color':'green'})
plt.xlabel('Categories', fontdict={'fontsize':20,'color':'Brown'})
plt.ylabel('Sales', fontdict={'fontsize':20,'color':'Brown'})
plt.xticks((1,2,3),['Technology','Furniture','Office Suppilies'])
# Out:
# ([<matplotlib.axis.XTick at 0x20d840bbc50>,
# ...
#  [Text(1, 0, 'Technology'),
#   Text(2, 0, 'Furniture'),
#   Text(3, 0, 'Office Suppilies')])

# %% [markdown]
# ![5.png](attachment:945ec183-6098-4652-90c5-5ef62c66c1f3.png)
#
# Box plots divide the data range into three important categories, which are as follows:
#
#  **Median value**: This is the value that divides the data range into two equal halves, i.e., the 50th percentile.
#
#  **Interquartile range (IQR):** These data points range between the 25th and 75th percentile values.
#
#  **Outliers:** These are data points that differ significantly from other observations and lie beyond the whiskers.

# %% [markdown]
# ## SubPlots
#
# Different plots presented in a single plot object are commonly referred to as subplots
#
# *suppose you have some data on e-commerce purchases. If you want to analyse the number of purchases across different categories, you can create multiple bar charts for each category, for example, one for male buyers and another for female buyers. These two charts, when placed next to each other, make it easy for you to compare the buying patterns of the male and female consumers.*
#
# more: https://www.youtube.com/watch?v=XFZRVnP-MTU

# %%
years = np.array(['2012', '2013', '2014', '2015'])

sales_africa = np.array([127187.27, 144480.70, 229068.79, 283036.44])

sales_USCA = np.array([492756.60, 486629.30, 627634.98, 757108.13])

sales_LATAM = np.array([385098.15, 464733.29, 608140.77, 706632.93])

sales_Asia_Pacific = np.array([713658.22, 863983.97, 1092231.65, 1372784.40])

sales_Europe = np.array([540750.63, 717611.40, 848670.24, 1180303.95])

# %% [markdown]
# ### SubPlots shown in same graph as line charts with diff colors

# %%
fig, ax = plt.subplots()

europe, =ax.plot(years,sales_Europe)
europe.set_label('Europe')

asia, =ax.plot(years,sales_Asia_Pacific)
asia.set_label('Asia')

latam, =ax.plot(years,sales_LATAM)
latam.set_label('LATAM')
latam.set_dashes([2,2,5,2])

usca, =ax.plot(years,sales_USCA)
usca.set_label('USCA')
usca.set_dashes([2,2,2,2])

africa , =ax.plot(years,sales_africa)
africa .set_label('Africa')
africa.set_dashes([2,2,10,2])

plt.legend()
plt.show()

# %% [markdown]
# ### Show legendms outside box

# %%
fig, ax = plt.subplots()

europe, =ax.plot(years,sales_Europe)
europe.set_label('Europe')

asia, =ax.plot(years,sales_Asia_Pacific)
asia.set_label('Asia')

latam, =ax.plot(years,sales_LATAM)
latam.set_label('LATAM')
latam.set_dashes([2,2,5,2])

usca, =ax.plot(years,sales_USCA)
usca.set_label('USCA')
usca.set_dashes([2,2,2,2])

africa , =ax.plot(years,sales_africa)
africa .set_label('Africa')
africa.set_dashes([2,2,10,2])

plt.legend()
plt.legend(bbox_to_anchor=(1.3,0.4))
plt.show()

# %% [markdown]
# ### Subplots are shopwn in different charts erach chart ,can be different

# %%
fig , ax = plt.subplots(nrows=2, ncols=3, sharex=True, sharey=True)
# sharex=True, sharey=True will allow the axis lables to be shared ones 
# ax[i][j] access the individual charts

europe, =ax[0][0].plot(years,sales_Europe)
europe.set_label('Europe')

asia =ax[0][1].bar(years,sales_Asia_Pacific)
asia.set_label('Asia')

latam =ax[0][2].scatter(years,sales_LATAM)
latam.set_label('LATAM')

usca, =ax[1][0].plot(years,sales_USCA)
usca.set_label('USCA')
usca.set_dashes([2,2,2,2])

africa , =ax[1][1].plot(years,sales_africa)
africa .set_label('Africa')
africa.set_dashes([2,2,10,2])

# %%
fig, ax = plt.subplots(ncols=4, sharey=True)

europe, =ax[0].plot(years,sales_Europe)
europe.set_label('Europe')
europe.set_color('Red')
ax[0].set_title('Sales in Europe')

asia =ax[1].bar(years,sales_Asia_Pacific)
asia.set_label('Asia')
ax[1].set_title('Sales in Asia')

latam =ax[2].scatter(years,sales_LATAM)
latam.set_label('LATAM')
ax[2].set_title('Sales in Latin America')

usca =ax[3].bar(years, sales_USCA, width=0.5, color='royalblue')
africa =ax[3].bar(years,sales_africa, width=0.5, color='seagreen')
ax[3].set_title('Sales in USA and Africa')
ax[3].legend((usca,africa), ('USA','Africa'))

fig.set_size_inches(20.5,5.5, forward=True)

# %% [markdown]
# **What the arguments mean in plt.subplot(4, 4, 2):**
#
# 4: Total number of rows in the grid
#
# 4: Total number of columns in the grid
#
# 2: This subplot will go in the 2nd position, counting left to right, top to bottom

# %% [markdown]
# # Principles of selecting a chart type
# <div class="MuiBox-root css-ab8yd1"><main drawerposition="left" class="css-mpncgp"><div class="MuiBox-root css-177wn66"><div class="MuiBox-root css-i97fac"></div><div class="MuiBox-root css-1ryrkgo"><div data-resource-woolf="67696a94396d20ef48eb142d_C676010cd62fde39221972224_V2"><div class="MuiBox-root css-1hqgrfy-fullWidthWithAssetNameContainer"><div class="MuiBox-root css-qgb4hw"><div class="MuiBox-root css-1xzog2f" id="switch-player-content"></div><div class="MuiBox-root css-j7qwjs"><div class="MuiBox-root css-lrle2m-container"><div class="text_component"><p><br></p><p style="text-align: justify;"><span style="font-size: 14px;">Let's summarise the points discussed in the video.&nbsp;</span></p><p style="text-align: justify;"><span style="font-size: 14px;"><br></span></p><p style="text-align: justify;"><span style="font-size: 14px;"><strong>Comparison</strong></span></p><p style="text-align: justify;"><span style="font-size: 14px;"><br></span></p><p style="text-align: justify;"><span style="font-size: 14px;">These charts can be used when you want to compare one set of values with other sets of values. The objective is to differentiate one particular set of values from the other sets, for example, quarterly sales of competing phones in the market. The following two types of charts are used to show a comparison: &nbsp;</span></p><p style="text-align: justify;"><span style="font-size: 14px;"><br></span></p><p style="text-align: justify;"><span style="font-size: 14px;">1. Column Chart</span></p><p><br></p><p><img class="image-editor fr-fic fr-dib" data-height="638" height="422.98342541436466" width="600" src="https://d35ev2v1xsdze0.cloudfront.net/f38b208c-1ca8-461e-8ea3-fd20339623e2-1734961517415.png" style="width: 300px;" etag="&quot;f91bcc9eddb7b8a07363e9e85d559bb7&quot;" serversideencryption="AES256" location="https://d35ev2v1xsdze0.cloudfront.net/f38b208c-1ca8-461e-8ea3-fd20339623e2-1734961517415.png" key="f38b208c-1ca8-461e-8ea3-fd20339623e2-1734961517415.png" bucket="upgrad-prod" originalname="1734961517415.png" fieldname="upload" contenttype="image/png" mimetype="image/png" size="55636" encoding="7bit" acl="public-read"></p><p><br></p><p>2. Bar chart</p><p><img class="image-editor fr-fic fr-dib" data-height="596" height="539.3665158371041" width="600" src="https://d35ev2v1xsdze0.cloudfront.net/edf4ece2-98c5-41c8-ba3d-ff6bb0380197-1734961517320.png" style="width: 300px;" etag="&quot;0746582111757056691f4db460613a58&quot;" serversideencryption="AES256" location="https://d35ev2v1xsdze0.cloudfront.net/edf4ece2-98c5-41c8-ba3d-ff6bb0380197-1734961517320.png" key="edf4ece2-98c5-41c8-ba3d-ff6bb0380197-1734961517320.png" bucket="upgrad-prod" originalname="1734961517320.png" fieldname="upload" contenttype="image/png" mimetype="image/png" size="42132" encoding="7bit" acl="public-read"></p><p><br></p><p style="text-align: justify;"><strong><br></strong></p><p><strong>Composition</strong></p><p><br></p><p dir="ltr">You would need to use a composition chart to display how the various elements make up the complete data. Composition charts can be static, which shows the composition at a particular instance of time, or dynamic, which shows the changes in the composition over a period of time. Two of the popular composition charts are as follows:</p><p><br></p><p>1. Pie/ Doughnut Chart<br><img class="image-editor fr-fic fr-dib" data-height="854" height="529.8862461220269" width="600" src="https://d35ev2v1xsdze0.cloudfront.net/22f19612-6611-48c7-aa08-d48dfe4d86e1-1734961565437.png" style="width: 300px;" etag="&quot;1505b76e15e646e4bda10e90f1dfa861&quot;" serversideencryption="AES256" location="https://d35ev2v1xsdze0.cloudfront.net/22f19612-6611-48c7-aa08-d48dfe4d86e1-1734961565437.png" key="22f19612-6611-48c7-aa08-d48dfe4d86e1-1734961565437.png" bucket="upgrad-prod" originalname="1734961565437.png" fieldname="upload" contenttype="image/png" mimetype="image/png" size="151664" encoding="7bit" acl="public-read"></p><p><br></p><p>2. Stacked Column chart</p><p><br></p><p><img class="image-editor fr-fic fr-dib" data-height="652" height="432.2651933701657" width="600" src="https://d35ev2v1xsdze0.cloudfront.net/d6330c46-4fa9-4a85-b414-51ac987ef287-1734961565685.png" style="width: 300px;" etag="&quot;181b967ba37d3a5f56096ada2c58c889&quot;" serversideencryption="AES256" location="https://d35ev2v1xsdze0.cloudfront.net/d6330c46-4fa9-4a85-b414-51ac987ef287-1734961565685.png" key="d6330c46-4fa9-4a85-b414-51ac987ef287-1734961565685.png" bucket="upgrad-prod" originalname="1734961565685.png" fieldname="upload" contenttype="image/png" mimetype="image/png" size="88607" encoding="7bit" acl="public-read"></p><p style="text-align: justify;"><span style="font-size: 14px;">The pie chart is by far the most common way to represent static composition, while the stacked column chart can be used to show the variation of composition over a period of time.&nbsp;</span></p><p style="text-align: justify;"><span style="font-size: 14px;"><br></span></p><p style="text-align: justify;"><span style="font-size: 14px;"><strong>Relationship</strong></span></p><p style="text-align: justify;"><span style="font-size: 14px;"><br></span></p><p dir="ltr" style="text-align: justify;"><span style="font-size: 14px;">A relationship chart helps in visualising the correlation between variables. It can help in answering questions such as ‘Is there a correlation between the amount spent on marketing and the sales revenue?’ and ‘How does the gross profit vary with the change in offers?’. Two of the most common types of charts used to visualise relationships between variables are as follows:</span></p><p><br></p><p>1. Scatter plot</p><p><br></p><p><img class="image-editor fr-fic fr-dib" data-height="889" height="439.01234567901236" width="600" src="https://d35ev2v1xsdze0.cloudfront.net/7bdfe181-28cd-4623-a9f5-e70961c57220-1734961586292.png" style="width: 300px;" etag="&quot;79fd1253200b4f3f3911b00f412165d6&quot;" serversideencryption="AES256" location="https://d35ev2v1xsdze0.cloudfront.net/7bdfe181-28cd-4623-a9f5-e70961c57220-1734961586292.png" key="7bdfe181-28cd-4623-a9f5-e70961c57220-1734961586292.png" bucket="upgrad-prod" originalname="1734961586292.png" fieldname="upload" contenttype="image/png" mimetype="image/png" size="144714" encoding="7bit" acl="public-read"></p><p><br></p><p>2. Bubble Plot<br><br></p><p><br></p><p><br></p><p><img class="image-editor fr-fic fr-dib" data-height="521" height="480.184331797235" width="600" src="https://d35ev2v1xsdze0.cloudfront.net/2a004c46-f4d6-441b-bfc4-0a1928dfeb8f-1734961586379.png" style="width: 300px;" etag="&quot;b11b62416dd834d26ed6951cbab224aa&quot;" serversideencryption="AES256" location="https://d35ev2v1xsdze0.cloudfront.net/2a004c46-f4d6-441b-bfc4-0a1928dfeb8f-1734961586379.png" key="2a004c46-f4d6-441b-bfc4-0a1928dfeb8f-1734961586379.png" bucket="upgrad-prod" originalname="1734961586379.png" fieldname="upload" contenttype="image/png" mimetype="image/png" size="123152" encoding="7bit" acl="public-read"></p><p style="text-align: justify;"><span style="font-size: 14px;">A scatter plot can help correlate two variables, whereas a bubble chart adds one more dimension, i.e., the size of the bubble (usually indicative of the frequency of occurrence of that particular data point)</span></p><p style="text-align: justify;"><span style="font-size: 14px;"><br></span></p><p style="text-align: justify;"><span style="font-size: 14px;"><strong>Distribution</strong></span></p><p style="text-align: justify;"><span style="font-size: 14px;"><br></span></p><p style="text-align: justify;"><span style="font-size: 14px;">A distribution chart tries to answer the question ‘How is the data distributed?’. For example, suppose you asked everyone their age in a survey. Using a distribution chart will help you visualise the distribution of ages in the data set. The distribution can be over a variable, or it can also be over a period of time. Two of the most commonly used charts for visualising distribution are as follows:&nbsp;</span></p><p style="text-align: justify;"><span style="font-size: 14px;"><br></span></p><p style="text-align: justify;"><span style="font-size: 14px;">1. Histogram</span></p><p><span style="font-size: 14px;"><br></span></p><p><span style="font-size: 14px;"><img class="image-editor fr-fic fr-dib" data-height="810" height="433.5414808206958" width="600" src="https://d35ev2v1xsdze0.cloudfront.net/b4b65538-90f9-4890-9e14-c30e255a6a0e-1734961606967.png" style="width: 300px;" etag="&quot;d9271b633c92ffbc8e2955eab1af8eb4&quot;" serversideencryption="AES256" location="https://d35ev2v1xsdze0.cloudfront.net/b4b65538-90f9-4890-9e14-c30e255a6a0e-1734961606967.png" key="b4b65538-90f9-4890-9e14-c30e255a6a0e-1734961606967.png" bucket="upgrad-prod" originalname="1734961606967.png" fieldname="upload" contenttype="image/png" mimetype="image/png" size="82461" encoding="7bit" acl="public-read"></span></p><p><span style="font-size: 14px;"><br></span></p><p><span style="font-size: 14px;">2. Scatter plots<br><br></span></p><p><span style="font-size: 14px;"><br></span></p><p><span style="font-size: 14px;"><img class="image-editor fr-fic fr-dib" data-height="889" height="439.01234567901236" width="600" src="https://d35ev2v1xsdze0.cloudfront.net/bfbf26fd-58c5-4daf-afd5-c6e0f13396ad-1734961607131.png" style="width: 300px;" etag="&quot;79fd1253200b4f3f3911b00f412165d6&quot;" serversideencryption="AES256" location="https://d35ev2v1xsdze0.cloudfront.net/bfbf26fd-58c5-4daf-afd5-c6e0f13396ad-1734961607131.png" key="bfbf26fd-58c5-4daf-afd5-c6e0f13396ad-1734961607131.png" bucket="upgrad-prod" originalname="1734961607131.png" fieldname="upload" contenttype="image/png" mimetype="image/png" size="144714" encoding="7bit" acl="public-read"></span></p><p style="text-align: justify;"><span style="font-size: 14px;">Histograms are quite good at displaying the distribution of data over intervals, whereas scatter plots are good at visualising the distribution of data over two different variables.&nbsp;</span></p><p style="text-align: justify;"><span style="font-size: 14px;"><br></span></p><p style="text-align: justify;"><span style="font-size: 14px;">These are the most common objectives of data visualisation, and the aforementioned types of charts help in achieving these objectives. However, this list is not exhaustive; you can always find more goals to create a visualisation. One of the key takeaways from this segment is to observe the chart that you have prepared and check whether it serves the purpose for which it was created. If it does serve the purpose, then you have created the right type of chart. If it doesn't, then you need to try other options to make the message of the chart very clear.</span></p><p style="text-align: justify;"><span style="font-size: 14px;"><br></span></p><p style="text-align: justify;"><span style="font-size: 14px;">You can apply your learnings from this segment in the practice notebook attached below.</span></p><p><span style="font-size: 14px;"><br></span></p><p>Link to the <a href="https://drive.google.com/file/d/1tfuaBM-KqJ4wKA1pwGeLCqqAolAO8wKt/view?usp=drive_link">file</a>.</p></div></div><div class="MuiBox-root css-0"></div></div></div></div></div></div></div></main><div class="MuiDrawer-root MuiDrawer-docked css-2vnr09"><div class="MuiPaper-root MuiPaper-elevation MuiPaper-elevation0 MuiDrawer-paper MuiDrawer-paperAnchorLeft MuiDrawer-paperAnchorDockedLeft css-1bs9ff9-leftDrawer" style="visibility: hidden; transform: translateX(-745.556px);"><div class="css-9jdz9v"><div class="MuiBox-root css-1rr4qq7"><div class="css-8vnv0e"><p class="MuiTypography-root MuiTypography-body1 css-1t5mpng-h8-bold">Notes</p><div class="MuiBox-root css-adzu6j"><svg class="MuiSvgIcon-root MuiSvgIcon-fontSizeMedium css-6eiy26" focusable="false" aria-hidden="true" viewBox="0 0 32 32" aria-label="Trainer will reply to your queries post the session"><g clip-path="url(#clip0_103_1405)"><path d="M9.4541 9.4541L22.545 22.545M22.545 9.4541L9.4541 22.545" stroke="#2C3E50" stroke-width="2" stroke-linecap="round" stroke-linejoin="round"></path></g><defs><clipPath id="clip0_103_1405"><rect width="32" height="32" fill="white"></rect></clipPath></defs></svg></div></div><div class="MuiDivider-root MuiDivider-fullWidth css-1q2aaa7" role="separator"></div><div class="MuiBox-root css-8hmz09"></div></div><div class="MuiDivider-root MuiDivider-fullWidth css-aiec70" role="separator"></div><div class="MuiBox-root css-iv33n6"><form><div class="css-40u8vs-root"><textarea rows="1" id="subject" aria-label="maximum height" placeholder="Type a new message" name="subject" style="height: 133px; overflow: hidden;"></textarea><textarea aria-hidden="true" readonly="" tabindex="-1" style="visibility: hidden; position: absolute; overflow: hidden; height: 0px; top: 0px; left: 0px; transform: translateZ(0px); padding: 0px; width: 226.007px;"></textarea><p class="MuiTypography-root MuiTypography-body1 css-19ohxfv"></p></div><div class="MuiFormControl-root MuiFormControl-fullWidth css-tzsjye" style="display: none;"><div class="MuiFormControl-root MuiTextField-root css-13quz26-root"><label class="MuiFormLabel-root MuiInputLabel-root MuiInputLabel-formControl MuiInputLabel-animated MuiInputLabel-outlined MuiFormLabel-colorPrimary MuiInputLabel-root MuiInputLabel-formControl MuiInputLabel-animated MuiInputLabel-outlined css-1cwqx25" data-shrink="false" for=":r10:" id=":r10:-label">note Id</label><div class="MuiInputBase-root MuiOutlinedInput-root MuiInputBase-colorPrimary MuiInputBase-formControl css-12x8yxb"><input aria-invalid="false" autocomplete="off" id=":r10:" name="id" type="text" class="MuiInputBase-input MuiOutlinedInput-input css-1x5jdmq" value=""><fieldset aria-hidden="true" class="MuiOutlinedInput-notchedOutline css-igs3ac"><legend class="css-yjsfm1"><span>note Id</span></legend></fieldset></div></div></div><div class="MuiBox-root css-1yz5gze"></div><div class="MuiBox-root css-3oohm3"><div class="MuiBox-root css-4s95f4"><div class="MuiBox-root css-0"><button class="MuiButtonBase-root MuiButton-root MuiButton-text MuiButton-textPrimary MuiButton-sizeMedium MuiButton-textSizeMedium MuiButton-root MuiButton-text MuiButton-textPrimary MuiButton-sizeMedium MuiButton-textSizeMedium css-3xhnhd" tabindex="0" type="submit">Save</button></div></div></div></form></div></div></div></div></div>

# %% [markdown]
# ## Different Types of Graphs for Data Visualization
#
# ### Bar Graph
#
# I strongly suggest using a bar graph to avoid clutter when one data label is long or if you have more than 10 items to compare. Also, fun fact: If the example below was vertical it would be a column graph.
#
# Customer bar graph example
#
# ![6.webp](attachment:8eb75d6f-5e4a-415c-bc66-e130f1fb4839.webp)
#
# Best Use Cases for These Types of Graphs
# Bar graphs can help track changes over time. I've found that bar graphs are most useful when there are big changes or to show how one group compares against other groups.
#
# The example above compares the number of customers by business role. It makes it easy to see that there is more than twice the number of customers per role for individual contributors than any other group.
#
# A bar graph also makes it easy to see which group of data is highest or most common.
#
# For example, at the start of the pandemic, online businesses saw a big jump in traffic. So, if you want to look at monthly traffic for an online business, a bar graph would make it easy to see that jump.
#
# Other use cases for bar graphs include:
#
# 1. Product comparisons.
# 2. Product usage.
# 3. Category comparisons.
# 4. Marketing traffic by month or year.
# 5. Marketing conversions.
#
# **Design Best Practices for Bar Graphs**
#
# Use consistent colors throughout the chart, selecting accent colors to highlight meaningful data points or changes over time.
#
# You should also use horizontal labels to improve its readability, and start the y-axis at 0 to appropriately reflect the values in your graph.
#
# ### Column Chart
# Use a column chart to show a comparison among different items or to show a comparison of items over time. You could use this format to see the revenue per landing page or customers by close date.
#
# ![8.webp](attachment:fb1de2f1-1471-4450-a53c-ecc2f6efcc82.webp)
#
# **Best Use Cases for This Type of Chart**
#
# I use both column charts to display changes in data, but I've noticed column charts are best for negative data. The main difference, of course, is that column charts show information vertically while bar charts show data horizontally.
#
# For example, warehouses often track the number of accidents on the shop floor. When the number of incidents falls below the monthly average, a column chart can make that change easier to see in a presentation.
#
# In the example above, this column chart measures the number of customers by close date. Column charts make it easy to see data changes over a period of time. This means that they have many use cases, including:
#
# 1. Customer survey data, like showing how many customers prefer a specific product or how much a customer uses a product each day.
# 2. Sales volume, like showing which services are the top sellers each month or the number of sales per week.
# 3. Profit and loss, showing where business investments are growing or falling.
#
# **Design Best Practices for Column Charts**
# * Use consistent colors throughout the chart, selecting accent colors to highlight meaningful data points or changes over time.
# * Use horizontal labels to improve readability.
# * Start the y-axis at 0 to appropriately reflect the values in your chart.
#
# ### Line Graph
# A line graph reveals trends or progress over time, and you can use it to show many different categories of data. You should use it when you track a continuous data set.
#
# This makes the terms line graphs and line charts interchangeable because the very nature of both is to track how variables impact each other, particularly how something changes over time. Yeah, it confused me, too.
#
# ![7.webp](attachment:d241a1c8-507e-476a-95af-f7651d116470.webp)
#
# **Best Use Cases for These Types of Graphs**
# * Line graphs help users track changes over short and long periods. Because of this, I find these types of graphs are best for seeing small changes.
#
# * Line graphs help me compare changes for more than one group over the same period. They're also helpful for measuring how different groups relate to each other.
#
# * A business might use this graph to compare sales rates for different products or services over time.
#
# These charts are also helpful for measuring service channel performance. For example, a line graph that tracks how many chats or emails your team responds to per month.
#
# **Design Best Practices for Line Graphs**
#
# 1. Use solid lines only.
# 2. Don't plot more than four lines to avoid visual distractions.
# 3. Use the right height so the lines take up roughly 2/3 of the y-axis' height.
#
# ### Area Chart
# Okay, an area chart is basically a line chart, but I swear there's a meaningful difference.
#
# The space between the x-axis and the line is filled with a color or pattern. It is useful for showing part-to-whole relations, like showing individual sales reps’ contributions to total sales for a year.
#
# It helps me analyze both overall and individual trend information.
#
# ![9.webp](attachment:d5e9613a-faae-4188-816c-2aff971975c0.webp)
#
# Best Use Cases for These Types of Charts
# Area charts help show changes over time. They work best for big differences between data sets and help visualize big trends.
#
# For example, the chart above shows users by creation date and life cycle stage.
#
# A line chart could show more subscribers than marketing qualified leads. But this area chart emphasizes how much bigger the number of subscribers is than any other group.
#
# These charts make the size of a group and how groups relate to each other more visually important than data changes over time.
#
# Area charts can help your business to:
#
# 1. Visualize which product categories or products within a category are most popular.
# 2. Show key performance indicator (KPI) goals vs. outcomes.
# 3. Spot and analyze industry trends.
#
# **Design Best Practices for Area Charts**
# * Use transparent colors so information isn't obscured in the background.
# * Don't display more than four categories to avoid clutter.
# * Organize highly variable data at the top of the chart to make it easy to read.
#
# ### Pie Chart
# Remember, a pie chart represents numbers in percentages, and the total sum of all segments needs to equal 100%.
#
# ![10.webp](attachment:4f1dad33-c48b-4c22-8ba2-571b59076f3e.webp)
#
# **Best Use Cases for This Type of Chart**
# The image above shows another example of customers by role in the company.
#
# The bar chart example shows you that there are more individual contributors than any other role. But this pie chart makes it clear that they make up over 50% of customer roles.
#
# Pie charts make it easy to see a section in relation to the whole, so they are good for showing:
#
# 1. Customer personas in relation to all customers.
# 2. Revenue from your most popular products or product types in relation to all product sales.
# 3. Percent of total profit from different store locations.
#
# **Design Best Practices for Pie Charts**
# * Don't illustrate too many categories to ensure differentiation between slices.
# * Ensure that the slice values add up to 100%.
# * Order slices according to their size.
#
# ### Scatter Plot Chart
# As I said earlier, a scatter plot or scattergram chart will show the relationship between two different variables or reveal distribution trends.
#
# Use this chart when there are many different data points, and you want to highlight similarities in the data set. This is useful when looking for outliers or understanding your data's distribution.
#
# ![11.webp](attachment:d14c21ff-ca1c-438d-bd66-824d082ba2cf.webp)
#
# Best Use Cases for These Types of Charts
# Scatter plots are helpful in situations where you have too much data to see a pattern quickly. They are best when you use them to show relationships between two large data sets.
#
# In the example above, this chart shows how customer happiness relates to the time it takes for them to get a response.
#
# This type of chart makes it easy to compare two data sets. Use cases might include:
#
# 1. Employment and manufacturing output.
# 2. Retail sales and inflation.
# 3. Visitor numbers and outdoor temperature.
# 4. Sales growth and tax laws.
#
# Try to choose two data sets that already have a positive or negative relationship. That said, this type of chart can also make it easier to see data that falls outside of normal patterns.
#
# **Design Best Practices for Scatter Plots**
# * Include more variables, like different sizes, to incorporate more data.
# * Start the y-axis at 0 to represent data accurately.
# * If you use trend lines, only use a maximum of two to make your plot easy to understand.
#
# ### Bubble Chart
# A bubble chart is similar to a scatter plot in that it can show distribution or relationship. There is a third data set shown by the size of the bubble or circle.
#
# ![12.webp](attachment:e4f243c6-affe-436f-971a-71c895c18cce.webp)
#
# **Best Use Cases for This Type of Chart**
# In the example above, the number of hours spent online isn't just compared to the user's age, as it would be on a scatter plot chart.
#
# Instead, you can also see how the gender of the user impacts time spent online.
#
# This makes bubble charts useful for seeing the rise or fall of trends over time. It also lets you add another option when you're trying to understand relationships between different segments or categories.
#
# For example, if you want to launch a new product, this chart could help you quickly see your new product's cost, risk, and value. This can help you focus your energies on a low-risk new product with a high potential return.
#
# You can also use bubble charts for:
#
# 1. Top sales by month and location.
# 2. Customer satisfaction surveys.
# 3. Store performance tracking.
# 4. Marketing campaign reviews.
#
# **Design Best Practices for Bubble Charts**
# * Scale bubbles according to area, not diameter.
# * Make sure labels are clear and visible.
# * Use circular shapes only.

# %% [markdown]
# <div class="MuiBox-root css-10khgmf"><div class="text_component"><p style="text-align: justify;"><span style="font-size: 14px;">You started this session by understanding the importance of visualisation in interpreting data. Then you learnt about the different types of graphs and charts, namely:</span></p><ul><li style="font-size: 14px; text-align: justify;">Bar chart</li><li style="font-size: 14px; text-align: justify;">Scatter plot</li><li style="font-size: 14px; text-align: justify;">Line graph</li><li style="font-size: 14px; text-align: justify;">Histogram</li><li style="font-size: 14px; text-align: justify;">Box plot</li></ul><p style="text-align: justify;"><span style="font-size: 14px;"><br></span></p><p style="text-align: justify;"><span style="font-size: 14px;">Further, you learnt about the elements that help display additional information about a plot. Also, you learnt how to fit several subplots inside a single plot object, which is useful for comparing different properties or elements of your data.</span></p><p style="text-align: justify;"><span style="font-size: 14px;"><br></span></p><h2 style="text-align: justify;"><span style="font-size: 14px;">Additional References:</span></h2><p style="text-align: justify;"><span style="font-size: 14px;">You can refer to the links provided below to learn more about visualisation:</span></p><p style="text-align: justify;"><span style="font-size: 14px;"><br></span></p><p>1. You can go to this <a data-cke-saved-href="https://gramener.com/posters/Winning-Parties.pdf" href="https://gramener.com/posters/Winning-Parties.pdf" target="_blank">link</a> from Gramener to know how data visualisation can help you derive insights about the winning political parties in India.</p><p>2. You can view this <a data-cke-saved-href="https://blog.socialcops.com/open-data/aging-population" href="https://blog.socialcops.com/open-data/aging-population" target="_blank">link</a> from SocialCops to see a creative visualisation on the ageing world population.</p><p>3. You can refer to this <a data-cke-saved-href="https://blog.hubspot.com/marketing/data-visualization-choosing-chart#sm.000vodl7ch6rf7e112a2q13r9cno0" href="https://blog.hubspot.com/marketing/data-visualization-choosing-chart#sm.000vodl7ch6rf7e112a2q13r9cno0" target="_blank">link</a> to learn how to choose a graph plot for your data.</p><p>4. You can refer to this <a href="http://www.youtube.com/watch?v=UO98lJQ3QGI&amp;list=PL-osiE80TeTvipOqomVEeZ1HRrcEvtZB_">link</a> to find additional video tutorials by Corey Shaffer on Matplotlib.</p><p>5. You can refer to this <a data-cke-saved-href="https://matplotlib.org/3.2.1/tutorials/index.html" href="https://matplotlib.org/3.2.1/tutorials/index.html" target="_blank">link&nbsp;</a>to find <strong>official Matplotlib Documentation</strong></p><p>6. You can learn more about choosing the right plot type by referring to this <a data-cke-saved-href="https://chartio.com/learn/charts/how-to-choose-data-visualization/" href="https://chartio.com/learn/charts/how-to-choose-data-visualization/" target="_blank">link</a>. <strong>&nbsp;</strong></p><p>7. You can refer to this <a data-cke-saved-href="https://www.youtube.com/watch?v=Ercd-Ip5PfQ" href="https://www.youtube.com/watch?v=Ercd-Ip5PfQ" target="_blank">link&nbsp;</a>to find out additional information about plotting real-time data.&nbsp;</p><p><br></p><p>In the next session, you will go through a case study which will make use of the tools you learnt in this session. </p></div></div>

# %% [markdown]
# # Questions :
#
# What is sample count in scatter plot

# %% [markdown]
# 1. You are provided with a list of weights of individuals stored as float:
#
#  > list_1 = [48.49, 67.54, 57.47, 68.17, 51.18, 68.31, 50.33, 66.7, 45.62, 43.59, 53.64, 70.08, 47.69, 61.27, 44.14, 51.62, 48.72, 65.11]
#
# You want to check which bucket has maximum entries when divided into the following four groups:
#
# [40-50)
#
# [50-60)
#
# [60-70)
#
# [70-80)
#
# Which code will help you find the correct answer?
#
# plt.hist(list_1, edgecolor = 'white')
#
#
# plt.hist(list_1, bins = 4, edgecolor = 'white')
#
#
# plt.hist(list_1, bins = 4, range =[40, 80], edgecolor = 'white') - **right answer**
#
#
# plt.hist( list_1, range =[40, 80])

# %%
list_1 = [48.49, 67.54, 57.47, 68.17, 51.18, 68.31, 50.33, 66.7, 45.62, 43.59, 53.64, 70.08, 47.69, 61.27, 44.14, 51.62, 48.72, 65.11]
plt.hist(list_1, bins = 4, edgecolor = 'white')
# Out:
# (array([6., 4., 2., 6.]),
#  array([43.59  , 50.2125, 56.835 , 63.4575, 70.08  ]),
#  <BarContainer object of 4 artists>)

# %%
plt.hist(list_1, bins = 4, range =[40, 80], edgecolor = 'white')
# Out:
# (array([6., 5., 6., 1.]),
#  array([40., 50., 60., 70., 80.]),
#  <BarContainer object of 4 artists>)

# %%
plt.hist( list_1, range =[40, 80])
# Out:
# (array([1., 3., 5., 1., 1., 1., 3., 3., 0., 0.]),
#  array([40., 44., 48., 52., 56., 60., 64., 68., 72., 76., 80.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 2. Find the interquartile range for the box plot created over the following list:
#
# >list_1 = [48.49, 67.54, 57.47, 68.17, 51.18, 68.31, 50.33, 66.7, 45.62, 43.59, 53.64, 70.08, 47.69, 61.27, 44.14, 51.62, 48.72, 65.11]
#
# [Hint: use np.percentile to find the percentile values]

# %%
list_1 = [48.49, 67.54, 57.47, 68.17, 51.18, 68.31, 50.33, 66.7, 45.62, 43.59, 53.64, 70.08, 47.69, 61.27, 44.14, 51.62, 48.72, 65.11]
list_1.sort()
list_1
q1 = np.percentile(list_1,25)
q2 = np.percentile(list_1,75)
print(f"{q1} + {q2}")
# Out:
# 48.5475 + 66.30250000000001

# %% [markdown]
# Which of the following plots can be used to show the relationship between two quantitative variables?
#
# 1. Box plot
#
# 2. Line plot
#
# 3. Scatter plot
#
# 4. Histogram

# %% [markdown]
# You have some data of credit card transactions. In this data, you're trying to find transaction values that are way outside the usual data range, in order to investigate some fraud.
# Which type of plot will you use in this case?
#
# 1. Line Chart
# 2. Scatter Plot
# 3. Histogram
# 4. Box Plot

# %% [markdown]
# Q. As you learnt, in plt.subplot(), the numbering starts from the top-left element of the grid and moves rightward along each row. Out of the following subplots, which one does NOT represent a plot that is part of the second column from the left in the array of subplots?
#
# 1. plt.subplot(4,4,2)
# 2. plt.subplot(4,4,14)
# 3. plt.subplot(3,3,7)
# 4. plt.subplot(3,3,8)
