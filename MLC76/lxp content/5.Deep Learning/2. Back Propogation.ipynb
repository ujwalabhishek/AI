# %% [markdown]
# # Back Propogation
#
# In the previous session, you learnt that training refers to the task of finding the optimal combination of weights and biases to minimize the total loss (with a fixed set of hyperparameters).
#
#
# This optimization is achieved using the familiar gradient descent algorithm.
#
#
#
# For a neural network, you will learn how the loss function is minimized using the gradient descent function by finding the optimum values of weights and biases using backpropagation.
#
# <div class="text_component" data-testid="text-component"><p>In this video, you learnt that the gradient descent algorithm presents us with the following parameter update equation:</p><p style="text-align: center;"><img alt="Equation" data-latex="w_{kj}^{l}=w_{kj}^{l}-\eta \frac{\partial L}{\partial w_{kj}^{l}}" src="https://latex.upgrad.com/render?formula=w_%7Bkj%7D%5E%7Bl%7D%3Dw_%7Bkj%7D%5E%7Bl%7D-%5Ceta%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7Bkj%7D%5E%7Bl%7D%7D"></p><p>where&nbsp;<img alt="Equation" data-latex="k" src="https://latex.upgrad.com/render?formula=k" style="vertical-align: middle;display: inline;"> and&nbsp;<img alt="Equation" data-latex="j" src="https://latex.upgrad.com/render?formula=j" style="vertical-align: middle;display: inline;"> are the indices of the weight in the weight matrix and&nbsp;<img alt="Equation" data-latex="l" src="https://latex.upgrad.com/render?formula=l" style="vertical-align: middle;display: inline;"> is the index of the layer to which it belongs.</p><p><img alt="Backpropagation" src="https://images.upgrad.com/dd815728-a334-4a24-9573-08aa555fe008-forward%20pass.png"></p><p>Given the neural network in the diagram, for the <strong>output</strong> layer, the following weights and bias terms will be updated using the gradient descent update equation:</p><p style="text-align: center;"><img alt="Equation" data-latex="w_{11}^{2}=w_{11}^{2}-\eta \frac{\partial L}{\partial w_{11}^{2}}" src="https://latex.upgrad.com/render?formula=w_%7B11%7D%5E%7B2%7D%3Dw_%7B11%7D%5E%7B2%7D-%5Ceta%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B11%7D%5E%7B2%7D%7D"></p><p style="text-align: center;"><img alt="Equation" data-latex="w_{12}^{2}=w_{12}^{2}-\eta \frac{\partial L}{\partial w_{12}^{2}}" src="https://latex.upgrad.com/render?formula=w_%7B12%7D%5E%7B2%7D%3Dw_%7B12%7D%5E%7B2%7D-%5Ceta%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B12%7D%5E%7B2%7D%7D"></p><p style="text-align: center;"><img alt="Equation" data-latex="b_{1}^{2}=b_{1}^{2}-\eta \frac{\partial L}{\partial b_{1}^{2}}" src="https://latex.upgrad.com/render?formula=b_%7B1%7D%5E%7B2%7D%3Db_%7B1%7D%5E%7B2%7D-%5Ceta%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20b_%7B1%7D%5E%7B2%7D%7D"></p><p>Now, for the <strong>hidden</strong> layer, the following weight and biases will be updated:</p><p style="text-align: center;"><img alt="Equation" data-latex="w_{11}^{1}=w_{11}^{1}-\eta \frac{\partial L}{\partial w_{11}^{1}}" src="https://latex.upgrad.com/render?formula=w_%7B11%7D%5E%7B1%7D%3Dw_%7B11%7D%5E%7B1%7D-%5Ceta%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B11%7D%5E%7B1%7D%7D">&nbsp; &nbsp; &nbsp;<img alt="Equation" data-latex="w_{21}^{1}=w_{21}^{1}-\eta \frac{\partial L}{\partial w_{21}^{1}}" src="https://latex.upgrad.com/render?formula=w_%7B21%7D%5E%7B1%7D%3Dw_%7B21%7D%5E%7B1%7D-%5Ceta%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B21%7D%5E%7B1%7D%7D"></p><p style="text-align: center;"><img alt="Equation" data-latex="w_{12}^{1}=w_{12}^{1}-\eta \frac{\partial L}{\partial w_{12}^{1}}" src="https://latex.upgrad.com/render?formula=w_%7B12%7D%5E%7B1%7D%3Dw_%7B12%7D%5E%7B1%7D-%5Ceta%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B12%7D%5E%7B1%7D%7D">&nbsp; &nbsp;<img alt="Equation" data-latex="w_{22}^{1}=w_{22}^{1}-\eta \frac{\partial L}{\partial w_{22}^{1}}" src="https://latex.upgrad.com/render?formula=w_%7B22%7D%5E%7B1%7D%3Dw_%7B22%7D%5E%7B1%7D-%5Ceta%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B22%7D%5E%7B1%7D%7D"></p><p style="text-align: center;"><img alt="Equation" data-latex="b_{1}^{1}=b_{1}^{1}-\eta \frac{\partial L}{\partial b_{1}^{1}}" src="https://latex.upgrad.com/render?formula=b_%7B1%7D%5E%7B1%7D%3Db_%7B1%7D%5E%7B1%7D-%5Ceta%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20b_%7B1%7D%5E%7B1%7D%7D">&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;&nbsp;<img alt="Equation" data-latex="b_{2}^{1}=b_{2}^{1}-\eta \frac{\partial L}{\partial b_{2}^{1}}" src="https://latex.upgrad.com/render?formula=b_%7B2%7D%5E%7B1%7D%3Db_%7B2%7D%5E%7B1%7D-%5Ceta%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20b_%7B2%7D%5E%7B1%7D%7D"></p><p>To compute these gradients, we use an algorithm called <strong>backpropagation</strong>.</p><p><br>As you can see in the formulas above, there exist partial derivatives of the loss function&nbsp;<img alt="Equation" data-latex="L" src="https://latex.upgrad.com/render?formula=L" style="vertical-align: middle;display: inline;"> with respect to the weights and biases in these equations given above. To compute these, we use the chain rule; you can observe the dependencies of different layers in the gradient computation.</p><p>Now, let’s simplify the neural network given above and represent it in a condensed format - this is shown below.</p><p><img data-height="330" data-width="538" height="330" src="https://images.upgrad.com/270e5272-e7fa-48c1-b318-a5ff22078c6b-chain_rule.png" width="538"></p><p>In this case, the loss function is a function of <img alt="Equation" data-latex="w_{1}" src="https://latex.upgrad.com/render?formula=w_%7B1%7D" style="vertical-align: middle;display: inline;">, <img alt="Equation" data-latex="b_{1}" src="https://latex.upgrad.com/render?formula=b_%7B1%7D" style="vertical-align: middle;display: inline;">, <img alt="Equation" data-latex="w_{2}" src="https://latex.upgrad.com/render?formula=w_%7B2%7D" style="vertical-align: middle;display: inline;">&nbsp;and <img alt="Equation" data-latex="b_{2}" src="https://latex.upgrad.com/render?formula=b_%7B2%7D" style="vertical-align: middle;display: inline;">.</p><p>The loss function, the activation function and the cumulative input are shown in the following expressions:</p><p>Loss function:&nbsp;<img alt="Equation" data-latex="Loss = \frac{1}{2}(y-h_{2})^{2}" src="https://latex.upgrad.com/render?formula=Loss%20%3D%20%5Cfrac%7B1%7D%7B2%7D%28y-h_%7B2%7D%29%5E%7B2%7D" style="vertical-align: middle;display: inline;"></p><p>Cumulative Input:<b>&nbsp;<b><img alt="Equation" data-latex="z_{i}=w_{i}h_{i-1}+b_{i}" src="https://latex.upgrad.com/render?formula=z_%7Bi%7D%3Dw_%7Bi%7Dh_%7Bi-1%7D%2Bb_%7Bi%7D" style="vertical-align: middle;display: inline;"></b></b></p><p>Output using tanh activation function:&nbsp;<img alt="Equation" data-latex="h_{i}=tanh(z_{i})" src="https://latex.upgrad.com/render?formula=h_%7Bi%7D%3Dtanh%28z_%7Bi%7D%29" style="vertical-align: middle;display: inline;"></p><p>Now, let’s compute the gradient of the loss function with respect to one of the weights to understand how <strong>backpropagation</strong> works.&nbsp;Suppose we want to calculate <img alt="Equation" data-latex="\frac{\partial L}{\partial w_{2}}" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B2%7D%7D" style="vertical-align: middle;display: inline;">:</p><p><img data-height="434" data-width="1068" height="243.82022471910113" src="https://images.upgrad.com/c93418e9-de20-4c7a-84ad-4ef2ce5ae73e-Screenshot 2022-02-13 at 5.41.24 PM.png" width="600"></p><p><br>Using the chain rule, we can say that:</p><p style="text-align: center;"><img alt="Equation" data-latex="\frac{\partial L}{\partial w_{2}}= \frac{\partial L}{\partial h_{2}}\frac{\partial h_{2}}{\partial z_{2}}\frac{\partial z_{2}}{\partial w_{2}}" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B2%7D%7D%3D%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20h_%7B2%7D%7D%5Cfrac%7B%5Cpartial%20h_%7B2%7D%7D%7B%5Cpartial%20z_%7B2%7D%7D%5Cfrac%7B%5Cpartial%20z_%7B2%7D%7D%7B%5Cpartial%20w_%7B2%7D%7D"></p><p>Based on the definition of the loss function,&nbsp;<img alt="Equation" data-latex="L" src="https://latex.upgrad.com/render?formula=L" style="vertical-align: middle;display: inline;"> is a direct function of <img alt="Equation" data-latex="h_{2}" src="https://latex.upgrad.com/render?formula=h_%7B2%7D" style="vertical-align: middle;display: inline;">, <img alt="Equation" data-latex="h_{2}" src="https://latex.upgrad.com/render?formula=h_%7B2%7D" style="vertical-align: middle;display: inline;">&nbsp;is a direct function of&nbsp;<img alt="Equation" data-latex="z_{2}" src="https://latex.upgrad.com/render?formula=z_%7B2%7D" style="vertical-align: middle;display: inline;"> and <img alt="Equation" data-latex="z_{2}" src="https://latex.upgrad.com/render?formula=z_%7B2%7D" style="vertical-align: middle;display: inline;">&nbsp;is a direct function of <img alt="Equation" data-latex="w_{2}" src="https://latex.upgrad.com/render?formula=w_%7B2%7D" style="vertical-align: middle;display: inline;">. Now, in the following video, let’s calculate all of them one by one.</p></div>
#
#
# ![40.png](attachment:09654433-727b-4b66-b2aa-eb7cfaa07cc3.png)

# %% [markdown]
# <div class="MuiBox-root css-1bi8ut6"><div class="text_component" data-testid="text-component"><p>In this video, you saw the following computations of the gradients to compute&nbsp;<img alt="Equation" data-latex="\frac{\partial L}{\partial w_{2}}" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B2%7D%7D" style="vertical-align: middle;display: inline;"> .</p><p>We know that&nbsp;<img alt="Equation" data-latex="\frac{\partial L}{\partial w_{2}}= \frac{\partial L}{\partial h_{2}}\frac{\partial h_{2}}{\partial z_{2}}\frac{\partial z_{2}}{\partial w_{2}}" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B2%7D%7D%3D%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20h_%7B2%7D%7D%5Cfrac%7B%5Cpartial%20h_%7B2%7D%7D%7B%5Cpartial%20z_%7B2%7D%7D%5Cfrac%7B%5Cpartial%20z_%7B2%7D%7D%7B%5Cpartial%20w_%7B2%7D%7D" style="vertical-align: middle;display: inline;">; let's compute each term present in this expression.</p><p><strong><u>First term</u></strong>:</p><p>Loss function:&nbsp;<img alt="Equation" data-latex="L=\frac{1}{2}(y-h_{2})^{2}" src="https://latex.upgrad.com/render?formula=L%3D%5Cfrac%7B1%7D%7B2%7D%28y-h_%7B2%7D%29%5E%7B2%7D" style="vertical-align: middle;display: inline;"></p><p>&nbsp;Taking the derivative of the loss function&nbsp;<img alt="Equation" data-latex="L" src="https://latex.upgrad.com/render?formula=L" style="vertical-align: middle;display: inline;"> with respect to&nbsp;<img alt="Equation" data-latex="h_{2}" src="https://latex.upgrad.com/render?formula=h_%7B2%7D" style="vertical-align: middle;display: inline;">:&nbsp;<img alt="Equation" data-latex="\frac{\partial L}{\partial h_{2}}= \frac{\partial }{\partial h_{2}} \frac{1}{2}(y-h_{2})^{2} =- (y-h_{2})....(1)" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20h_%7B2%7D%7D%3D%20%5Cfrac%7B%5Cpartial%20%7D%7B%5Cpartial%20h_%7B2%7D%7D%20%5Cfrac%7B1%7D%7B2%7D%28y-h_%7B2%7D%29%5E%7B2%7D%20%3D-%20%28y-h_%7B2%7D%29....%281%29" style="vertical-align: middle;display: inline;"></p><p><strong><u>Second term</u></strong>:</p><p>Applying the tanh activation function on the cumulative input&nbsp;<img alt="Equation" data-latex="z_{2}" src="https://latex.upgrad.com/render?formula=z_%7B2%7D" style="vertical-align: middle;display: inline;">&nbsp;we get&nbsp;<img alt="Equation" data-latex="h_{2}" src="https://latex.upgrad.com/render?formula=h_%7B2%7D" style="vertical-align: middle;display: inline;">:</p><p><img alt="Equation" data-latex="h_{2}=tanz(z_{2})" src="https://latex.upgrad.com/render?formula=h_%7B2%7D%3Dtanz%28z_%7B2%7D%29" style="vertical-align: middle;display: inline;"></p><p>Taking the derivative of&nbsp;<img alt="Equation" data-latex="h_{2}" src="https://latex.upgrad.com/render?formula=h_%7B2%7D" style="vertical-align: middle;display: inline;">&nbsp;with respect to&nbsp;<img alt="Equation" data-latex="z_{2}" src="https://latex.upgrad.com/render?formula=z_%7B2%7D" style="vertical-align: middle;display: inline;">:<img alt="Equation" data-latex="\frac{\partial h_{2}}{\partial z_{2}}=1-tanh^{2}(z_{2})=1-(h_{2})^{2}....(2)" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20h_%7B2%7D%7D%7B%5Cpartial%20z_%7B2%7D%7D%3D1-tanh%5E%7B2%7D%28z_%7B2%7D%29%3D1-%28h_%7B2%7D%29%5E%7B2%7D....%282%29" style="vertical-align: middle;display: inline;"></p><p><strong><u>Third term</u></strong>:</p><p>Cumulative Input:&nbsp;<img alt="Equation" data-latex="z_{2}=w_{2}h_{1}+b_{2}" src="https://latex.upgrad.com/render?formula=z_%7B2%7D%3Dw_%7B2%7Dh_%7B1%7D%2Bb_%7B2%7D" style="vertical-align: middle;display: inline;"></p><p>Taking the derivative of&nbsp;<img alt="Equation" data-latex="z_{2}" src="https://latex.upgrad.com/render?formula=z_%7B2%7D" style="vertical-align: middle;display: inline;">&nbsp;with respect to&nbsp;<img alt="Equation" data-latex="w_{2}" src="https://latex.upgrad.com/render?formula=w_%7B2%7D" style="vertical-align: middle;display: inline;">:<img alt="Equation" data-latex="\frac{\partial z_{2}}{\partial w_{2}} = h_{1}....(3)" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20z_%7B2%7D%7D%7B%5Cpartial%20w_%7B2%7D%7D%20%3D%20h_%7B1%7D....%283%29" style="vertical-align: middle;display: inline;"></p><p>Hence, from expressions (1),(2) and (3), we get the gradient of the Loss function <img alt="Equation" data-latex="L" src="https://latex.upgrad.com/render?formula=L" style="vertical-align: middle;display: inline;">&nbsp;with respect to <img alt="Equation" data-latex="w_{2}" src="https://latex.upgrad.com/render?formula=w_%7B2%7D" style="vertical-align: middle;display: inline;">, which is shown below.</p><p><img alt="Equation" data-latex="\frac{\partial L}{\partial w_{2}}=\frac{\partial L}{\partial h_{2}}\frac{\partial h_{2}}{\partial z_{2}}\frac{\partial z_{2}}{\partial w_{2}}=[-(y-h_{2})][1-(h_{2})^{2}][h_{1}]" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B2%7D%7D%3D%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20h_%7B2%7D%7D%5Cfrac%7B%5Cpartial%20h_%7B2%7D%7D%7B%5Cpartial%20z_%7B2%7D%7D%5Cfrac%7B%5Cpartial%20z_%7B2%7D%7D%7B%5Cpartial%20w_%7B2%7D%7D%3D%5B-%28y-h_%7B2%7D%29%5D%5B1-%28h_%7B2%7D%29%5E%7B2%7D%5D%5Bh_%7B1%7D%5D" style="vertical-align: middle;display: inline;"></p><p>Now, we have completed the computation of the gradient of the loss function&nbsp;<img alt="Equation" data-latex="L" src="https://latex.upgrad.com/render?formula=L" style="vertical-align: middle;display: inline;"> with respect to the weight <img alt="Equation" data-latex="w_{2}" src="https://latex.upgrad.com/render?formula=w_%7B2%7D" style="vertical-align: middle;display: inline;">&nbsp;for backpropagation. We can similarly compute the gradient of the loss function with respect to all the weights and biases present in the network.</p><p>In the next video, we will observe the iterative nature of the computation of the gradients for multiple hidden layers.</p></div></div>

# %% [markdown]
# **Extending pattern to 3 neurons and updating weight terms**
#
# ![41.png](attachment:a98aeeee-7204-402d-bdfd-e74b8a5d8f08.png)

# %% [markdown]
# Once the gradients of all the weights and biases are computed, the gradient descent update equation can be used to obtain the updated values of the weights and biases.
#
# Now that you have learnt about backpropagation in a simple network. Let’s proceed to the next segment to apply the technique of backpropogation to a numerical example

# %% [markdown]
# ## Numerical Example Demonstrating Backpropagation
#
# <div class="MuiBox-root css-1bi8ut6"><div class="text_component" data-testid="text-component"><p>You gained an understanding of the backpropagation technique on a very simple neural network. You will now learn how the weights and biases, i.e., the parameters of the neural network considered for the house price prediction example, change.&nbsp;</p><p dir="ltr">The housing data set has two inputs, which are the size of the house and the number of rooms available, and one output, which is the price of the house.</p><p dir="ltr">As seen in the computation of the forward pass, we randomly initialise the weights and biases in the network. Let’s take the same initialisation and the same input observation that we used earlier while doing forward propagation.</p><p dir="ltr"><strong>Note</strong>: Solve these equations using pen and paper for better understanding. Do keep in mind that understanding how backpropagation works takes time and effort and it may take a few repetitions to understand it well. Please be patient!</p><p>So, we initialised the parameters to the values shown below when doing forward propagation. We will use the same values when doing backpropagation. Also, we will consider the same input observation. The values of the weights, biases and the input are as follows:</p><p>Weights:</p><p><img alt="Equation" data-latex="W^{1}=\begin{bmatrix}
# w_{11}^{1} &amp;w_{12}^{1} \\
#  w_{21}^{1}&amp; w_{22}^{1}
# \end{bmatrix}= \begin{bmatrix}
# 0.2 &amp;0.15 \\
#  0.5&amp;0.6
# \end{bmatrix}\\
# W^{2}=
# \begin{bmatrix}
# w_{11}^{2}\\
# w_{12}^{2}
# \end{bmatrix}=\begin{bmatrix}
# 0.3\\
# 0.2
# \end{bmatrix}" src="https://latex.upgrad.com/render?formula=W%5E%7B1%7D%3D%5Cbegin%7Bbmatrix%7D%0Aw_%7B11%7D%5E%7B1%7D%20%26w_%7B12%7D%5E%7B1%7D%20%5C%5C%20%0A%20w_%7B21%7D%5E%7B1%7D%26%20w_%7B22%7D%5E%7B1%7D%0A%5Cend%7Bbmatrix%7D%3D%20%5Cbegin%7Bbmatrix%7D%0A0.2%20%260.15%20%5C%5C%20%0A%200.5%260.6%20%0A%5Cend%7Bbmatrix%7D%5C%5C%0AW%5E%7B2%7D%3D%0A%5Cbegin%7Bbmatrix%7D%0Aw_%7B11%7D%5E%7B2%7D%5C%5C%20%0Aw_%7B12%7D%5E%7B2%7D%0A%5Cend%7Bbmatrix%7D%3D%5Cbegin%7Bbmatrix%7D%0A0.3%5C%5C%20%0A0.2%0A%5Cend%7Bbmatrix%7D"></p><p>Biases:</p><p><img alt="Equation" data-latex="b^{1}=\begin{bmatrix}
# b_{1}^{1}  \\
#  b_{2}^{1}
# \end{bmatrix}=\begin{bmatrix}
# 0.1\\
# 0.25
# \end{bmatrix}\\b^{2}=\begin{bmatrix}
# b_{1}^{2}
# \end{bmatrix}= \begin{bmatrix}
# 0.4
# \end{bmatrix}" src="https://latex.upgrad.com/render?formula=b%5E%7B1%7D%3D%5Cbegin%7Bbmatrix%7D%0Ab_%7B1%7D%5E%7B1%7D%20%20%5C%5C%20%0A%20b_%7B2%7D%5E%7B1%7D%0A%5Cend%7Bbmatrix%7D%3D%5Cbegin%7Bbmatrix%7D%0A0.1%5C%5C%20%0A0.25%0A%5Cend%7Bbmatrix%7D%5C%5Cb%5E%7B2%7D%3D%5Cbegin%7Bbmatrix%7D%0Ab_%7B1%7D%5E%7B2%7D%0A%5Cend%7Bbmatrix%7D%3D%20%5Cbegin%7Bbmatrix%7D%0A0.4%0A%5Cend%7Bbmatrix%7D"></p><p>Input data:</p><p><img alt="Equation" data-latex="X^{1}=\begin{bmatrix}
# x_{1}\\
# x_{2}
# \end{bmatrix} = \begin{bmatrix}
# -0.32\\
# -0.66
# \end{bmatrix}" src="https://latex.upgrad.com/render?formula=X%5E%7B1%7D%3D%5Cbegin%7Bbmatrix%7D%0Ax_%7B1%7D%5C%5C%20%0Ax_%7B2%7D%0A%5Cend%7Bbmatrix%7D%20%3D%20%5Cbegin%7Bbmatrix%7D%0A-0.32%5C%5C%20%0A-0.66%0A%5Cend%7Bbmatrix%7D"></p><p dir="ltr">The network architecture we consider is shown below:</p><p style="text-align: center;"><img data-height="554" data-width="1010" height="329.1089108910891" src="https://images.upgrad.com/6f0d59dd-a89b-42a2-b1d9-a826f237fc8b-backprop.png" width="600"></p><p>As we have calculated previously, the output prediction <img alt="Equation" data-latex="h_{1}^{2}" src="https://latex.upgrad.com/render?formula=h_%7B1%7D%5E%7B2%7D" style="vertical-align: middle;display: inline;">&nbsp;obtained is 0.63, whereas the actual output&nbsp;<img alt="Equation" data-latex="y" src="https://latex.upgrad.com/render?formula=y" style="vertical-align: middle;display: inline;"> is&nbsp;−0.54. Using backpropagation, we will update the weights and biases such that this difference between the predicted and the actual output gets minimised.</p><p dir="ltr">Now, let’s revise the notations of some terms:</p><ol><li aria-level="1" dir="ltr"><p dir="ltr" role="presentation"><img alt="Equation" data-latex="h^{2}" src="https://latex.upgrad.com/render?formula=h%5E%7B2%7D" style="vertical-align: middle;display: inline;">&nbsp;is the final predicted output that is obtained by applying the activation function (in this case, linear) on the cumulative input.&nbsp;</p></li><li aria-level="1" dir="ltr"><p dir="ltr" role="presentation"><img alt="Equation" data-latex="z^{2}" src="https://latex.upgrad.com/render?formula=z%5E%7B2%7D" style="vertical-align: middle;display: inline;">&nbsp;is the cumulative input fed to the output neuron.</p></li><li aria-level="1" dir="ltr"><p dir="ltr" role="presentation"><img alt="Equation" data-latex="W^{2}" src="https://latex.upgrad.com/render?formula=W%5E%7B2%7D" style="vertical-align: middle;display: inline;">&nbsp;and&nbsp;<img alt="Equation" data-latex="b^{2}" src="https://latex.upgrad.com/render?formula=b%5E%7B2%7D" style="vertical-align: middle;display: inline;"> are the weights and biases between the hidden layer and the output layer.</p></li><li aria-level="1" dir="ltr"><p dir="ltr" role="presentation"><img alt="Equation" data-latex="h^{1}" src="https://latex.upgrad.com/render?formula=h%5E%7B1%7D" style="vertical-align: middle;display: inline;">&nbsp;is the output of the hidden layer.</p></li><li aria-level="1" dir="ltr"><p dir="ltr" role="presentation"><img alt="Equation" data-latex="z^{1}" src="https://latex.upgrad.com/render?formula=z%5E%7B1%7D" style="vertical-align: middle;display: inline;">&nbsp;is the cumulative input to the hidden layer.</p></li><li aria-level="1" dir="ltr"><p dir="ltr" role="presentation"><img alt="Equation" data-latex="W^{1}" src="https://latex.upgrad.com/render?formula=W%5E%7B1%7D" style="vertical-align: middle;display: inline;">&nbsp;and&nbsp;<img alt="Equation" data-latex="b^{1}" src="https://latex.upgrad.com/render?formula=b%5E%7B1%7D" style="vertical-align: middle;display: inline;"> are the weights and biases of the hidden layer, respectively.</p></li><li aria-level="1" dir="ltr"><p dir="ltr" role="presentation"><img alt="Equation" data-latex="X^{1}" src="https://latex.upgrad.com/render?formula=X%5E%7B1%7D" style="vertical-align: middle;display: inline;">&nbsp;is the input from the housing data set.</p></li></ol><p dir="ltr">We will only focus on updating the weights and biases in this network.&nbsp;</p><p dir="ltr">We strongly recommend that you perform the calculations yourself along with Gunnvant to grasp the concepts efficiently.</p><p dir="ltr">Note: At timestamp 3:32, Gunnvant mentioned that “we can use the gradient descent update equation to get the updated value of the error term”. It is not the updated value of the error term but the updated value of the weight term&nbsp;<img alt="Equation" data-latex="w_{11}^{2}" src="https://latex.upgrad.com/render?formula=w_%7B11%7D%5E%7B2%7D" style="vertical-align: middle;display: inline;">.</p></div></div>

# %% [markdown]
# <div class="MuiBox-root css-1bi8ut6"><div class="text_component" data-testid="text-component"><p>As seen in the video, the steps taken to update the weights and biases between the hidden layer and the output layer are shown below.&nbsp;</p><p><img data-height="551" data-width="1019" height="324.4357212953876" src="https://images.upgrad.com/81a4c1af-648b-47c5-bafc-b611ddb9c0f6-backprop2.png" width="600"></p><p>First, we will focus on the weights for the output layer.</p><p><strong>Output Layer: Compute gradient of&nbsp;<strong><img alt="Equation" data-latex="L" src="https://latex.upgrad.com/render?formula=L" style="vertical-align: middle;display: inline;"></strong> with respect to&nbsp;</strong><img alt="Equation" data-latex="w_{11}^{2}" src="https://latex.upgrad.com/render?formula=w_%7B11%7D%5E%7B2%7D" style="vertical-align: middle;display: inline;">:</p><p>First, let’s take the gradient of&nbsp;<img alt="Equation" data-latex="L" src="https://latex.upgrad.com/render?formula=L" style="vertical-align: middle;display: inline;"> with respect to <img alt="Equation" data-latex="w_{11}^{2}" src="https://latex.upgrad.com/render?formula=w_%7B11%7D%5E%7B2%7D" style="vertical-align: middle;display: inline;">.<br>We know that:<br><img alt="Equation" data-latex="\frac{\partial L}{\partial w_{11}^{2}}= \frac{\partial L}{\partial h_{1}^{2}}\frac{\partial h_{1}^{2}}{\partial z_{1}^{2}}\frac{\partial z_{1}^{2}}{\partial w_{11}^{2}}" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B11%7D%5E%7B2%7D%7D%3D%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%5Cfrac%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%7B%5Cpartial%20z_%7B1%7D%5E%7B2%7D%7D%5Cfrac%7B%5Cpartial%20z_%7B1%7D%5E%7B2%7D%7D%7B%5Cpartial%20w_%7B11%7D%5E%7B2%7D%7D">(using the chain rule)</p><p>1) First term <img alt="Equation" data-latex="\frac{\partial L}{\partial h_{1}^{2}}" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D" style="vertical-align: middle;display: inline;">:</p><p><img alt="Equation" data-latex="\frac{\partial L}{\partial h_{1}^{2}}= \frac{\partial }{\partial h_{1}^{2}}\frac{1}{2}(y-h_{1}^{2})^{2}=-(y-h_{1}^{2})" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%3D%20%5Cfrac%7B%5Cpartial%20%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%5Cfrac%7B1%7D%7B2%7D(y-h_%7B1%7D%5E%7B2%7D)%5E%7B2%7D%3D-(y-h_%7B1%7D%5E%7B2%7D)"></p><p><img alt="Equation" data-latex="\frac{\partial L}{\partial h_{1}^{2}}= -(-0.54-0.63)=1.17" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%3D%20-(-0.54-0.63)%3D1.17"></p><p>2) Second term <img alt="Equation" data-latex="\frac{\partial h_{1}^{2}}{\partial z_{1}^{2}}" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%7B%5Cpartial%20z_%7B1%7D%5E%7B2%7D%7D" style="vertical-align: middle;display: inline;">:&nbsp;</p><p><img alt="Equation" data-latex="\frac{\partial h_{1}^{2}}{\partial z_{1}^{2}}= 1 " src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%7B%5Cpartial%20z_%7B1%7D%5E%7B2%7D%7D%3D%201%20">&nbsp;and&nbsp;<img alt="Equation" data-latex="h_{1}^{2}=z_{1}^{2}" src="https://latex.upgrad.com/render?formula=h_%7B1%7D%5E%7B2%7D%3Dz_%7B1%7D%5E%7B2%7D"> (using linear activation function)</p><p>3) Third term:</p><p><img alt="Equation" data-latex="\frac{\partial L}{\partial h_{1}^{2}}= \frac{\partial }{\partial h_{1}^{2}}\frac{1}{2}(y-h_{1}^{2})^{2}=-(y-h_{1}^{2})" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%3D%20%5Cfrac%7B%5Cpartial%20%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%5Cfrac%7B1%7D%7B2%7D(y-h_%7B1%7D%5E%7B2%7D)%5E%7B2%7D%3D-(y-h_%7B1%7D%5E%7B2%7D)"></p><p><img alt="Equation" data-latex="\frac{\partial z_{1}^{2}}{\partial h_{1}^{2}}= (h_{1}^{1})=0.484" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20z_%7B1%7D%5E%7B2%7D%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%3D%20(h_%7B1%7D%5E%7B1%7D)%3D0.484"></p><p>Hence, <img alt="Equation" data-latex="\frac{\partial L}{\partial w_{11}^{2}}" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B11%7D%5E%7B2%7D%7D">&nbsp;evaluates to&nbsp;<img alt="Equation" data-latex="\frac{\partial L}{\partial w_{11}^{2}}= 1.17 * 1*0.484=0.5663" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B11%7D%5E%7B2%7D%7D%3D%201.17%20*%201*0.484%3D0.5663"></p><p>Now,&nbsp;using the update rule for <strong>gradient descent</strong> and considering the learning rate&nbsp;<img alt="Equation" data-latex="\eta" src="https://latex.upgrad.com/render?formula=%5Ceta" style="vertical-align: middle;display: inline;">&nbsp;as 0.2.<br><img alt="Equation" data-latex="w_{11(updated)}^{2}=w_{11}^{2}-\eta \frac{\partial L}{\partial w_{11}^{2}}= 0.3-( 0.2*0.5663)=0.1867" src="https://latex.upgrad.com/render?formula=w_%7B11(updated)%7D%5E%7B2%7D%3Dw_%7B11%7D%5E%7B2%7D-%5Ceta%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B11%7D%5E%7B2%7D%7D%3D%200.3-(%200.2*0.5663)%3D0.1867"></p><p><strong>Output Layer: Compute gradient of&nbsp;<strong><strong><strong><img alt="Equation" data-latex="L" src="https://latex.upgrad.com/render?formula=L" style="vertical-align: middle;display: inline;"></strong></strong></strong> with respect to&nbsp;</strong><img alt="Equation" data-latex="w_{12}^{2}" src="https://latex.upgrad.com/render?formula=w_%7B12%7D%5E%7B2%7D" style="vertical-align: middle;display: inline;">:</p><p>Similarly&nbsp;<img alt="Equation" data-latex="\frac{\partial L}{\partial w_{12}^{2}}= \frac{\partial L}{\partial h_{1}^{2}}\frac{\partial h_{1}^{2}}{\partial z_{1}^{2}}\frac{\partial z_{1}^{2}}{\partial w_{12}^{2}}" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B12%7D%5E%7B2%7D%7D%3D%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%5Cfrac%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%7B%5Cpartial%20z_%7B1%7D%5E%7B2%7D%7D%5Cfrac%7B%5Cpartial%20z_%7B1%7D%5E%7B2%7D%7D%7B%5Cpartial%20w_%7B12%7D%5E%7B2%7D%7D"></p><p>Since we have already computed the first two derivatives, let’s compute the third one:</p><p><img alt="Equation" data-latex="\frac{\partial z_{1}^{2}}{\partial w_{12}^{2}}= (h_{1}^{2})=0.424" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20z_%7B1%7D%5E%7B2%7D%7D%7B%5Cpartial%20w_%7B12%7D%5E%7B2%7D%7D%3D%20(h_%7B1%7D%5E%7B2%7D)%3D0.424"></p><p>Hence, this evaluates to&nbsp;<img alt="Equation" data-latex="\frac{\partial L}{\partial w_{12}^{1}}= 1.17*1*0.424=0.4961" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B12%7D%5E%7B1%7D%7D%3D%201.17*1*0.424%3D0.4961"></p><p>Now, using <strong>gradient descent</strong> update equation,</p><p><img alt="Equation" data-latex="w_{12(updated)}^{2}=w_{12}^{2}-\eta \frac{\partial L}{\partial w_{12}^{2}}= 0.2-( 0.2*0.4961)=0.1008" src="https://latex.upgrad.com/render?formula=w_%7B12(updated)%7D%5E%7B2%7D%3Dw_%7B12%7D%5E%7B2%7D-%5Ceta%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B12%7D%5E%7B2%7D%7D%3D%200.2-(%200.2*0.4961)%3D0.1008"></p><p>Similarly, for the bias term, we know that:<br><img alt="Equation" data-latex="\frac{\partial L}{\partial b_{1}^{2}}= \frac{\partial L}{\partial h_{1}^{2}}\frac{\partial h_{1}^{2}}{\partial z_{1}^{2}}\frac{\partial z_{1}^{2}}{\partial b_{1}^{2}}" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20b_%7B1%7D%5E%7B2%7D%7D%3D%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%5Cfrac%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%7B%5Cpartial%20z_%7B1%7D%5E%7B2%7D%7D%5Cfrac%7B%5Cpartial%20z_%7B1%7D%5E%7B2%7D%7D%7B%5Cpartial%20b_%7B1%7D%5E%7B2%7D%7D"></p><p>We have computed the first two derivatives already, and the third one can be computed as shown below:&nbsp;</p><p><img alt="Equation" data-latex="\frac{\partial z_{2}^{1}}{\partial b_{1}^{2}}= \frac{\partial }{\partial b_{1}^{2}}(b_{1}^{2}+w_{11}^{2}h_{1}^{1}+w_{12}^{2}h_{2}^{1})" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20z_%7B2%7D%5E%7B1%7D%7D%7B%5Cpartial%20b_%7B1%7D%5E%7B2%7D%7D%3D%20%5Cfrac%7B%5Cpartial%20%7D%7B%5Cpartial%20b_%7B1%7D%5E%7B2%7D%7D(b_%7B1%7D%5E%7B2%7D%2Bw_%7B11%7D%5E%7B2%7Dh_%7B1%7D%5E%7B1%7D%2Bw_%7B12%7D%5E%7B2%7Dh_%7B2%7D%5E%7B1%7D)"></p><p><img alt="Equation" data-latex="\frac{\partial z_{2}^{1}}{\partial b_{1}^{2}}= 1" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20z_%7B2%7D%5E%7B1%7D%7D%7B%5Cpartial%20b_%7B1%7D%5E%7B2%7D%7D%3D%201"></p><p>Hence, this evaluates to,&nbsp;</p><p><img alt="Equation" data-latex="\frac{\partial L}{\partial b_{1}^{2}}= 1.17*1*1=1.17" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20b_%7B1%7D%5E%7B2%7D%7D%3D%201.17*1*1%3D1.17"></p><p>Now,</p><p><img alt="Equation" data-latex="w_{12(updated)}^{2}=w_{12}^{2}-\eta \frac{\partial L}{\partial w_{12}^{2}}= 0.2-( 0.2*0.4961)=0.1008" src="https://latex.upgrad.com/render?formula=w_%7B12(updated)%7D%5E%7B2%7D%3Dw_%7B12%7D%5E%7B2%7D-%5Ceta%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B12%7D%5E%7B2%7D%7D%3D%200.2-(%200.2*0.4961)%3D0.1008"></p><p><strong>So, we have updated values of weights and biases of the output layer from a single iteration:</strong></p><p style="text-align: center;"><img alt="Equation" data-latex="w_{11(updated)}^{2}=0.1867,w_{12(updated)}^{2}=0.1008,b_{1(updated)}^{2}=0.166" src="https://latex.upgrad.com/render?formula=w_%7B11(updated)%7D%5E%7B2%7D%3D0.1867%2Cw_%7B12(updated)%7D%5E%7B2%7D%3D0.1008%2Cb_%7B1(updated)%7D%5E%7B2%7D%3D0.166"></p><p>In the next video, we will move to the previous layer, and you will learn how to update the weights and biases of the first layer (hidden layer).&nbsp;</p></div></div>

# %% [markdown]
# ## Part 2
#
# <div class="MuiBox-root css-1bi8ut6"><div class="text_component" data-testid="text-component"><p>As seen in this video, the steps involved in computing the updated weights and biases in the hidden layer are shown below.&nbsp;</p><p>Now, let’s start with computing the weights and biases corresponding to the first neuron of the hidden layer.</p><p><img data-height="521" data-width="1035" height="302.0289855072464" src="https://images.upgrad.com/b1c0e554-f475-40e7-b4ef-5956c648bdfc-backprop3.png" width="600"></p><p><strong>Hidden Layer: Compute gradient of&nbsp;<strong><strong><strong><img alt="Equation" data-latex="L" src="https://latex.upgrad.com/render?formula=L" style="vertical-align: middle;display: inline;"></strong></strong></strong> with respect to&nbsp;</strong><img alt="Equation" data-latex="w_{11}^{1}" src="https://latex.upgrad.com/render?formula=w_%7B11%7D%5E%7B1%7D" style="vertical-align: middle;display: inline;">:<br>Taking the gradient of L with respect to <img alt="Equation" data-latex="w_{11}^{1}" src="https://latex.upgrad.com/render?formula=w_%7B11%7D%5E%7B1%7D" style="vertical-align: middle;display: inline;">, we can say that:</p><p><img alt="Equation" data-latex="\frac{\partial L}{\partial w_{11}^{1}}= \frac{\partial L}{\partial h_{1}^{2}}\frac{\partial h_{1}^{2}}{\partial h_{1}^{1}}\frac{\partial h_{1}^{1}}{\partial w_{11}^{1}}= \frac{\partial L}{\partial h_{1}^{2}}\frac{\partial h_{1}^{2}}{\partial h_{1}^{1}}[\frac{\partial h_{1}^{1}}{\partial z_{1}^{1}}\frac{\partial z_{1}^{1}}{\partial w_{11}^{1}}]" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B11%7D%5E%7B1%7D%7D%3D%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%5Cfrac%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B1%7D%7D%5Cfrac%7B%5Cpartial%20h_%7B1%7D%5E%7B1%7D%7D%7B%5Cpartial%20w_%7B11%7D%5E%7B1%7D%7D%3D%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%5Cfrac%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B1%7D%7D%5B%5Cfrac%7B%5Cpartial%20h_%7B1%7D%5E%7B1%7D%7D%7B%5Cpartial%20z_%7B1%7D%5E%7B1%7D%7D%5Cfrac%7B%5Cpartial%20z_%7B1%7D%5E%7B1%7D%7D%7B%5Cpartial%20w_%7B11%7D%5E%7B1%7D%7D%5D"></p><p>We know the first derivative term:&nbsp;</p><p><img alt="Equation" data-latex="\frac{\partial L}{\partial h_{1}^{2}}= \frac{\partial }{\partial h_{1}^{2}}\frac{1}{2}(y-h_{1}^{2})^{2}=-(y-h_{1}^{2})=-(-0.54-0.63)=1.17" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%3D%20%5Cfrac%7B%5Cpartial%20%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%5Cfrac%7B1%7D%7B2%7D(y-h_%7B1%7D%5E%7B2%7D)%5E%7B2%7D%3D-(y-h_%7B1%7D%5E%7B2%7D)%3D-(-0.54-0.63)%3D1.17"></p><p>Now, let’s compute the second, third and fourth derivative terms:</p><p><img src="data:image/png;base64,..."></p><p>Now, using the <strong>gradient descent</strong> update equation,</p><p><img alt="Equation" data-latex="w_{11(updated)}^{1}=w_{11}^{1}-\eta \frac{\partial L}{\partial w_{11}^{1}}= 0.2-0.2*( -0.028)=0.2056" src="https://latex.upgrad.com/render?formula=w_%7B11(updated)%7D%5E%7B1%7D%3Dw_%7B11%7D%5E%7B1%7D-%5Ceta%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B11%7D%5E%7B1%7D%7D%3D%200.2-0.2*(%20-0.028)%3D0.2056"></p><p><strong>Hidden Layer: Compute gradient of&nbsp;<strong><strong><strong><strong><strong><strong><strong><img alt="Equation" data-latex="L" src="https://latex.upgrad.com/render?formula=L" style="vertical-align: middle;display: inline;"></strong></strong></strong></strong></strong></strong></strong> with respect to&nbsp;</strong><img alt="Equation" data-latex="w_{12}^{1}" src="https://latex.upgrad.com/render?formula=w_%7B12%7D%5E%7B1%7D" style="vertical-align: middle;display: inline;">:</p><p>Similarly,&nbsp;<img alt="Equation" data-latex="\frac{\partial L}{\partial w_{12}^{2}}= \frac{\partial L}{\partial h_{1}^{2}}\frac{\partial h_{1}^{2}}{\partial h_{1}^{1}}\frac{\partial h_{1}^{1}}{\partial w_{12}^{1}}= \frac{\partial L}{\partial h_{1}^{2}}\frac{\partial h_{1}^{2}}{\partial h_{1}^{1}}[\frac{\partial h_{1}^{1}}{\partial z_{1}^{1}}\frac{\partial z_{1}^{1}}{\partial w_{12}^{1}}]" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B12%7D%5E%7B2%7D%7D%3D%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%5Cfrac%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B1%7D%7D%5Cfrac%7B%5Cpartial%20h_%7B1%7D%5E%7B1%7D%7D%7B%5Cpartial%20w_%7B12%7D%5E%7B1%7D%7D%3D%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%5Cfrac%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B1%7D%7D%5B%5Cfrac%7B%5Cpartial%20h_%7B1%7D%5E%7B1%7D%7D%7B%5Cpartial%20z_%7B1%7D%5E%7B1%7D%7D%5Cfrac%7B%5Cpartial%20z_%7B1%7D%5E%7B1%7D%7D%7B%5Cpartial%20w_%7B12%7D%5E%7B1%7D%7D%5D"></p><p>Since we have already computed the values of the first three terms, we simply need to calculate the pending derivative term:&nbsp;</p><p><img alt="Equation" data-latex="\frac{\partial z_{1}^{1}}{\partial w_{12}^{1}}= \frac{\partial }{\partial w_{12}^{1}}(b_{1}^{1}+w_{11}^{1}x_{1}+w_{12}^{1}x_{2}) = x_{2}=-0.66" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20z_%7B1%7D%5E%7B1%7D%7D%7B%5Cpartial%20w_%7B12%7D%5E%7B1%7D%7D%3D%20%5Cfrac%7B%5Cpartial%20%7D%7B%5Cpartial%20w_%7B12%7D%5E%7B1%7D%7D(b_%7B1%7D%5E%7B1%7D%2Bw_%7B11%7D%5E%7B1%7Dx_%7B1%7D%2Bw_%7B12%7D%5E%7B1%7Dx_%7B2%7D)%20%3D%20x_%7B2%7D%3D-0.66"></p><p>Hence, this evaluates to</p><p><img alt="Equation" data-latex="\frac{\partial L}{\partial w_{12}^{1}}= 1.17*0.30*0.484*(1-0.484)*(-0.66)=-0.058" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B12%7D%5E%7B1%7D%7D%3D%201.17*0.30*0.484*(1-0.484)*(-0.66)%3D-0.058"></p><p>Now, using the <strong>gradient descent</strong> update equation,</p><p><img alt="Equation" data-latex="w_{12(updated)}^{1}=w_{12}^{1}-\eta \frac{\partial L}{\partial w_{12}^{1}}= 0.15-0.2*( -0.058)=0.1616" src="https://latex.upgrad.com/render?formula=w_%7B12(updated)%7D%5E%7B1%7D%3Dw_%7B12%7D%5E%7B1%7D-%5Ceta%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B12%7D%5E%7B1%7D%7D%3D%200.15-0.2*(%20-0.058)%3D0.1616"></p><p><strong>Hidden Layer: Compute gradient of&nbsp;<strong><strong><strong><strong><strong><strong><strong><img alt="Equation" data-latex="L" src="https://latex.upgrad.com/render?formula=L" style="vertical-align: middle;display: inline;"></strong></strong></strong></strong></strong></strong></strong> with respect to&nbsp;</strong><img alt="Equation" data-latex="b_{12}^{1}" src="https://latex.upgrad.com/render?formula=b_%7B12%7D%5E%7B1%7D" style="vertical-align: middle;display: inline;">:</p><p><img alt="Equation" data-latex="\frac{\partial L}{\partial b_{1}^{1}}= \frac{\partial L}{\partial h_{1}^{2}}\frac{\partial h_{1}^{2}}{\partial h_{1}^{1}}[\frac{\partial h_{1}^{1}}{\partial z_{1}^{1}}\frac{\partial z_{1}^{1}}{\partial b_{12}^{1}}]" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20b_%7B1%7D%5E%7B1%7D%7D%3D%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%5Cfrac%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B1%7D%7D%5B%5Cfrac%7B%5Cpartial%20h_%7B1%7D%5E%7B1%7D%7D%7B%5Cpartial%20z_%7B1%7D%5E%7B1%7D%7D%5Cfrac%7B%5Cpartial%20z_%7B1%7D%5E%7B1%7D%7D%7B%5Cpartial%20b_%7B12%7D%5E%7B1%7D%7D%5D"></p><p>Consider the last term on the right-hand side of the equation above:</p><p><img alt="Equation" data-latex="\frac{\partial z_{1}^{1}}{\partial b_{1}^{1}}= \frac{\partial }{\partial b_{1}^{1}}(b_{1}^{1}+w_{11}^{1}x_{1}+w_{12}^{1}x_{2}) =1" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20z_%7B1%7D%5E%7B1%7D%7D%7B%5Cpartial%20b_%7B1%7D%5E%7B1%7D%7D%3D%20%5Cfrac%7B%5Cpartial%20%7D%7B%5Cpartial%20b_%7B1%7D%5E%7B1%7D%7D(b_%7B1%7D%5E%7B1%7D%2Bw_%7B11%7D%5E%7B1%7Dx_%7B1%7D%2Bw_%7B12%7D%5E%7B1%7Dx_%7B2%7D)%20%3D1"></p><p>Hence, this evaluates to&nbsp;<img alt="Equation" data-latex="\frac{\partial L}{\partial b_{1}^{1}}= 1.17*0.30*0.484*(1-0.484)*1=0.088" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20b_%7B1%7D%5E%7B1%7D%7D%3D%201.17*0.30*0.484*(1-0.484)*1%3D0.088"></p><p>Now, using the <strong>gradient descent</strong> update equation,</p><p><img alt="Equation" data-latex="b_{1(updated)}^{1}=b_{1}^{1}-\eta \frac{\partial L}{\partial b_{1}^{1}}= 0.1-0.2*( 0.088)=0.0824" src="https://latex.upgrad.com/render?formula=b_%7B1(updated)%7D%5E%7B1%7D%3Db_%7B1%7D%5E%7B1%7D-%5Ceta%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20b_%7B1%7D%5E%7B1%7D%7D%3D%200.1-0.2*(%200.088)%3D0.0824"></p><p>Hence, for the <strong>first node</strong>, the updated values of the weights and biases using gradient descent and a learning rate of 0.2 (η) are:</p><p><img src="data:image/png;base64,..."></p><p>In the same manner, we calculate the weights and biases corresponding to the second neuron in the hidden layer.</p><p><img data-height="521" data-width="1035" height="302.0289855072464" src="https://images.upgrad.com/6489b5fb-c6c2-49be-b005-d3271e56b2a6-backprop4.png" width="600"></p><p><strong>Hidden Layer: Compute gradient of&nbsp;<strong><strong><strong><strong><strong><strong><strong><img alt="Equation" data-latex="L" src="https://latex.upgrad.com/render?formula=L" style="vertical-align: middle;display: inline;"></strong></strong></strong></strong></strong></strong></strong> with respect to&nbsp;</strong><img alt="Equation" data-latex="w_{21}^{1}" src="https://latex.upgrad.com/render?formula=w_%7B21%7D%5E%7B1%7D" style="vertical-align: middle;display: inline;">:</p><p>Starting with finding the derivative of the loss function&nbsp;<img alt="Equation" data-latex="L" src="https://latex.upgrad.com/render?formula=L" style="vertical-align: middle;display: inline;"> with respect to <img alt="Equation" data-latex="w_{21}^{1}" src="https://latex.upgrad.com/render?formula=w_%7B21%7D%5E%7B1%7D" style="vertical-align: middle;display: inline;">:</p><p><img alt="Equation" data-latex="\frac{\partial L}{\partial w_{21}^{1}}= \frac{\partial L}{\partial h_{1}^{2}}\frac{\partial h_{1}^{2}}{\partial h_{2}^{1}}\frac{\partial h_{2}^{1}}{\partial w_{21}^{1}}= \frac{\partial L}{\partial h_{1}^{2}}\frac{\partial h_{1}^{2}}{\partial h_{2}^{1}}[\frac{\partial h_{2}^{1}}{\partial z_{2}^{1}}\frac{\partial z_{2}^{1}}{\partial w_{21}^{1}}]" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20w_%7B21%7D%5E%7B1%7D%7D%3D%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%5Cfrac%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%7B%5Cpartial%20h_%7B2%7D%5E%7B1%7D%7D%5Cfrac%7B%5Cpartial%20h_%7B2%7D%5E%7B1%7D%7D%7B%5Cpartial%20w_%7B21%7D%5E%7B1%7D%7D%3D%20%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%5Cfrac%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%7B%5Cpartial%20h_%7B2%7D%5E%7B1%7D%7D%5B%5Cfrac%7B%5Cpartial%20h_%7B2%7D%5E%7B1%7D%7D%7B%5Cpartial%20z_%7B2%7D%5E%7B1%7D%7D%5Cfrac%7B%5Cpartial%20z_%7B2%7D%5E%7B1%7D%7D%7B%5Cpartial%20w_%7B21%7D%5E%7B1%7D%7D%5D"></p><p>We have already computed the first derivative term:</p><p><img alt="Equation" data-latex="\frac{\partial L}{\partial h_{1}^{2}}= \frac{\partial }{\partial h_{1}^{2}}\frac{1}{2}(y-h_{1}^{2})^{2}=-(y-h_{1}^{2})= -(-0.54-0.63)=1.17" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20L%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%3D%20%5Cfrac%7B%5Cpartial%20%7D%7B%5Cpartial%20h_%7B1%7D%5E%7B2%7D%7D%5Cfrac%7B1%7D%7B2%7D(y-h_%7B1%7D%5E%7B2%7D)%5E%7B2%7D%3D-(y-h_%7B1%7D%5E%7B2%7D)%3D%20-(-0.54-0.63)%3D1.17"></p><p>Let’s compute the second, third and fourth terms:</p><p><img src="data:image/png;base64,..."></p><p>Also, for <img alt="Equation" data-latex="w_{22}^{1}" src="https://latex.upgrad.com/render?formula=w_%7B22%7D%5E%7B1%7D" style="vertical-align: middle;display: inline;"> and <img alt="Equation" data-latex="b_{2}^{1}" src="https://latex.upgrad.com/render?formula=b_%7B2%7D%5E%7B1%7D" style="vertical-align: middle;display: inline;">, the first three terms will remain the same, only the last term will change. Hence, we will compute only the last terms:&nbsp;</p><p><img alt="Equation" data-latex="\frac{\partial z_{2}^{1}}{\partial w_{22}^{1}} = \frac{\partial }{\partial w_{22}^{1}}(b_{2}^{1}+w_{21}^{1}x_{1}+w_{22}^{1}x_{2}) = x_{2}=-0.66" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20z_%7B2%7D%5E%7B1%7D%7D%7B%5Cpartial%20w_%7B22%7D%5E%7B1%7D%7D%20%3D%20%5Cfrac%7B%5Cpartial%20%7D%7B%5Cpartial%20w_%7B22%7D%5E%7B1%7D%7D%28b_%7B2%7D%5E%7B1%7D%2Bw_%7B21%7D%5E%7B1%7Dx_%7B1%7D%2Bw_%7B22%7D%5E%7B1%7Dx_%7B2%7D%29%20%3D%20x_%7B2%7D%3D-0.66" style="vertical-align: middle;display: inline;"></p><p><img alt="Equation" data-latex="\frac{\partial z_{2}^{1}}{\partial b_{2}^{1}} = \frac{\partial }{\partial b_{2}^{1}}(b_{2}^{1}+w_{21}^{1}x_{1}+w_{22}^{1}x_{2}) = 1" src="https://latex.upgrad.com/render?formula=%5Cfrac%7B%5Cpartial%20z_%7B2%7D%5E%7B1%7D%7D%7B%5Cpartial%20b_%7B2%7D%5E%7B1%7D%7D%20%3D%20%5Cfrac%7B%5Cpartial%20%7D%7B%5Cpartial%20b_%7B2%7D%5E%7B1%7D%7D%28b_%7B2%7D%5E%7B1%7D%2Bw_%7B21%7D%5E%7B1%7Dx_%7B1%7D%2Bw_%7B22%7D%5E%7B1%7Dx_%7B2%7D%29%20%3D%201" style="vertical-align: middle;display: inline;"></p><p>Hence, for the <strong>second node</strong>:</p><p><img src="data:image/png;base64,..."></p><p>Now, computing the updated values of weights and biases using <strong>gradient descent </strong>and a learning rate of 0.2 (<img alt="Equation" data-latex="\eta" src="https://latex.upgrad.com/render?formula=%5Ceta" style="vertical-align: middle;display: inline;">):</p><p><img src="data:image/png;base64,..."></p><p>To summarise, using gradient descent in backpropagation, we can update the weights and biases of the whole neural network.&nbsp;</p><p>Given below are the new values for weights and biases after one step of gradient descent for the hidden and the output layer, respectively.</p><p>Updated weights:</p><p><img alt="Equation" data-latex="w_{(updated)}^{1}=\begin{bmatrix}
#  w_{11(updated)}^{1}&amp; w_{11(updated)}^{1}\\
# w_{21(updated)}^{1} &amp; w_{22(updated)}^{1}
# \end{bmatrix}=\begin{bmatrix}
# 0.2056&amp;0.1616\\
# 0.5036&amp;0.6076
# \end{bmatrix}
# \\w_{(updated)}^{2}=
# \begin{bmatrix}
# w_{22(updated)}^{2}\\
# w_{12(updated)}^{2}
# \end{bmatrix}
# =
# \begin{bmatrix}
# 0.1867\\
# 0.1008
# \end{bmatrix}" src="https://latex.upgrad.com/render?formula=w_%7B(updated)%7D%5E%7B1%7D%3D%5Cbegin%7Bbmatrix%7D%0A%20w_%7B11(updated)%7D%5E%7B1%7D%26%20w_%7B11(updated)%7D%5E%7B1%7D%5C%5C%20%0Aw_%7B21(updated)%7D%5E%7B1%7D%20%26%20w_%7B22(updated)%7D%5E%7B1%7D%0A%5Cend%7Bbmatrix%7D%3D%5Cbegin%7Bbmatrix%7D%0A0.2056%260.1616%5C%5C%20%0A0.5036%260.6076%0A%5Cend%7Bbmatrix%7D%0A%5C%5Cw_%7B(updated)%7D%5E%7B2%7D%3D%0A%5Cbegin%7Bbmatrix%7D%0Aw_%7B22(updated)%7D%5E%7B2%7D%5C%5C%20%0Aw_%7B12(updated)%7D%5E%7B2%7D%0A%5Cend%7Bbmatrix%7D%0A%3D%0A%5Cbegin%7Bbmatrix%7D%0A0.1867%5C%5C%20%0A0.1008%0A%5Cend%7Bbmatrix%7D"></p><p>Updated biases:</p><p><img alt="Equation" data-latex="\begin{bmatrix}
#  b_{1(updated)}^{1}\\
# b_{2(updated)}^{1}
# \end{bmatrix}=
# \begin{bmatrix}
# 0.0824\\
# 0.2386
# \end{bmatrix}\\
# \begin{bmatrix}
# b_{1(updated)}^{2}
# \end{bmatrix}
# =\begin{bmatrix}
# 0.166
# \end{bmatrix}" src="https://latex.upgrad.com/render?formula=%5Cbegin%7Bbmatrix%7D%0A%20b_%7B1(updated)%7D%5E%7B1%7D%5C%5C%20%0Ab_%7B2(updated)%7D%5E%7B1%7D%0A%5Cend%7Bbmatrix%7D%3D%0A%5Cbegin%7Bbmatrix%7D%0A0.0824%5C%5C%20%0A0.2386%0A%5Cend%7Bbmatrix%7D%5C%5C%0A%5Cbegin%7Bbmatrix%7D%0Ab_%7B1(updated)%7D%5E%7B2%7D%0A%5Cend%7Bbmatrix%7D%0A%3D%5Cbegin%7Bbmatrix%7D%0A0.166%0A%5Cend%7Bbmatrix%7D"></p><p><b id="docs-internal-guid-0919251b-7fff-e88a-e977-58d33b2c9e75">Forward Pass with updated parameters</b></p><p>Now, let’s perform another forward pass and check if performing backpropagation and updating the weights and biases once has helped in reducing the loss.</p></div></div>

# %% [markdown]
# <div class="MuiBox-root css-1bi8ut6"><div class="text_component" data-testid="text-component"><p style="text-align: center;"><img data-width="861" data-height="577" height="402.0905923344948" width="600" src="https://images.upgrad.com/ebab2aa5-a447-4231-9dc2-d88f7677eaea-backprop5.png"></p><p>&nbsp;</p><p>You can see that the loss function computed on the updated weights and biases is lower than earlier, which is what we want. By repeatedly performing backpropagation to get optimum values of weights and biases, we can continue reducing the loss. This, eventually, will help us obtain the predicted output that is as close as possible to the actual expected output. This is how a neural network learns using backpropagation.</p><p dir="ltr">Since this is a simple neural network, you could compute these values manually. But as the number of hidden layers and of neurons per hidden layer increase, computing these values manually will not be possible. The machine will perform these computations. The aim of considering this example is to demonstrate how a basic neural network behaves so that you can extrapolate the ideas learnt in this simple example to larger networks.</p><p>&nbsp;</p><p dir="ltr">Now that you have an in-depth understanding of how weights and biases are optimised using the loss function and gradient descent through the neural network, we will now cover a generalised step-by-step algorithm to summarise backpropagation.</p><p dir="ltr">&nbsp;</p><p dir="ltr">Now, you have an in-depth understanding of how weights and biases are optimised using the loss function and gradient descent through the neural network. In the next segment, we will cover a generalised step-by-step algorithm to summarise backpropagation.</p></div></div>

# %% [markdown]
# ![42.png](attachment:b39823c1-63f2-476a-b8d2-e33c60c90f5b.png)
