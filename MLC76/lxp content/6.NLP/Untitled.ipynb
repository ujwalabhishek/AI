# %%
import re

re.search('ujwal' , 'my name is ujwal abhishek')
# Out:
# <re.Match object; span=(11, 16), match='ujwal'>

# %%
match = re.search('car' , 'There are cars parked')

match
# Out:
# <re.Match object; span=(10, 13), match='car'>
