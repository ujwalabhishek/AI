# %% [markdown]
# ## Plotting word frequencies

# %%
import requests
from nltk import FreqDist
from nltk.corpus import stopwords
import seaborn as sns
# %matplotlib inline
# Out:
# /Users/ujwalabhishek/myenv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# Download text of 'Alice in Wonderland' ebook from https://www.gutenberg.org/

# %%
url = "https://www.gutenberg.org/files/11/11-0.txt"
alice = requests.get(url)
#print(alice.text)

# %% [markdown]
# Define a function to plot word frequencies

# %%
def plot_word_frequency(words, top_n=10):
    word_freq = FreqDist(words)
    labels = [element[0] for element in word_freq.most_common(top_n)]
    counts = [element[1] for element in word_freq.most_common(top_n)]
    plot = sns.barplot(labels, counts)
    return plot

# %% [markdown]
# Plot words frequencies present in the gutenberg corpus

# %%
alice_words = alice.text.split()
plot_word_frequency(alice_words, 15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 alice_words = alice.text.split()
# ----> 2 plot_word_frequency(alice_words, 15)
#
# Cell In[7], line 5, in plot_word_frequency(words, top_n)
#       3 labels = [element[0] for element in word_freq.most_common(top_n)]
#       4 counts = [element[1] for element in word_freq.most_common(top_n)]
# ----> 5 plot = sns.barplot(labels, counts)
#       6 return plot
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %% [markdown]
# ## Stopwords

# %% [markdown]
# Import stopwords from nltk

# %%
from nltk.corpus import stopwords

# %% [markdown]
# Look at the list of stopwords

# %%
print(stopwords.words('english'))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~/myenv/lib/python3.9/site-packages/nltk/corpus/util.py:84, in LazyCorpusLoader.__load(self)
#      83 try:
# ---> 84     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85 except LookupError:
#
# File ~/myenv/lib/python3.9/site-packages/nltk/data.py:579, in find(resource_name, paths)
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
#     - '/Users/ujwalabhishek/nltk_data'
#     - '/Users/ujwalabhishek/myenv/nltk_data'
#     - '/Users/ujwalabhishek/myenv/share/nltk_data'
#     - '/Users/ujwalabhishek/myenv/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(stopwords.words('english'))
#
# File ~/myenv/lib/python3.9/site-packages/nltk/corpus/util.py:120, in LazyCorpusLoader.__getattr__(self, attr)
#     117 if attr == "__bases__":
#     118     raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
# --> 120 self.__load()
#     121 # This looks circular, but its not, since __load() changes our
#     122 # __class__ to something new:
#     123 return getattr(self, attr)
#
# File ~/myenv/lib/python3.9/site-packages/nltk/corpus/util.py:86, in LazyCorpusLoader.__load(self)
#      84             root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85         except LookupError:
# ---> 86             raise e
#      88 # Load the corpus.
#      89 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#
# File ~/myenv/lib/python3.9/site-packages/nltk/corpus/util.py:81, in LazyCorpusLoader.__load(self)
#      79 else:
#      80     try:
# ---> 81         root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82     except LookupError as e:
#      83         try:
#
# File ~/myenv/lib/python3.9/site-packages/nltk/data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords
#
#   Searched in:
#     - '/Users/ujwalabhishek/nltk_data'
#     - '/Users/ujwalabhishek/myenv/nltk_data'
#     - '/Users/ujwalabhishek/myenv/share/nltk_data'
#     - '/Users/ujwalabhishek/myenv/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %% [markdown]
# Let's remove stopwords from the following piece of text.

# %%
sample_text = "the great aim of education is not knowledge but action"

# %% [markdown]
# Break text into words

# %%
sample_words = sample_text.split()
print(sample_words)
# Out:
# ['the', 'great', 'aim', 'of', 'education', 'is', 'not', 'knowledge', 'but', 'action']

# %% [markdown]
# Remove stopwords

# %%
sample_words = [word for word in sample_words if word not in stopwords.words('english')]
print(sample_words)
# Out:
# ['great', 'aim', 'education', 'knowledge', 'action']

# %% [markdown]
# Join words back to sentence

# %%
sample_text = " ".join(sample_words)
print(sample_text)
# Out:
# great aim education knowledge action

# %% [markdown]
# ## Removing stopwords in the genesis corpus

# %%
no_stops = [word for word in alice_words if word not in stopwords.words("english")]

# %%
plot_word_frequency(no_stops, 10)

# %% [markdown]
# Some other things that can be done
# * Need to change tokens to lower case
# * Need to get rid of punctuations
#
# All the preprocessing steps will be covered while creating the classifier
