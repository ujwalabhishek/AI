# %%
import re
from collections import Counter

# %%
# function to tokenise words
def words(document):
    "Convert text to lower case and tokenise the document"
    return re.findall(r'\w+', document.lower())

# %%
# create a frequency table of all the words of the document
all_words = Counter(words(open('big.txt').read()))

# %%
# check frequency of a random word, say, 'chair'
all_words['chair']
# Out:
# 135

# %%
# look at top 10 frequent words
all_words.most_common(10)
# Out:
# [('the', 79809),
#  ('of', 40024),
#  ('and', 38312),
#  ('to', 28765),
#  ('in', 22023),
#  ('a', 21124),
#  ('that', 12512),
#  ('he', 12401),
#  ('was', 11410),
#  ('it', 10681)]

# %%
def edits_one(word):
    "Create all edits that are one edit away from `word`."
    alphabets    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])                   for i in range(len(word) + 1)]
    deletes    = [left + right[1:]                       for left, right in splits if right]
    inserts    = [left + c + right                       for left, right in splits for c in alphabets]
    replaces   = [left + c + right[1:]                   for left, right in splits if right for c in alphabets]
    transposes = [left + right[1] + right[0] + right[2:] for left, right in splits if len(right)>1]
    return set(deletes + inserts + replaces + transposes)

# %%
def edits_two(word):
    "Create all edits that are two edits away from `word`."
    return (e2 for e1 in edits_one(word) for e2 in edits_one(e1))

# %%
def known(words):
    "The subset of `words` that appear in the `all_words`."
    return set(word for word in words if word in all_words)

# %%
def possible_corrections(word):
    "Generate possible spelling corrections for word."
    return (known([word]) or known(edits_one(word)) or known(edits_two(word)) or [word])

# %%
def prob(word, N=sum(all_words.values())): 
    "Probability of `word`: Number of appearances of 'word' / total number of tokens"
    return all_words[word] / N

# %%
print(len(set(edits_one("monney"))))
print(edits_one("monney"))
# Out:
# 336
# {'xonney', 'mronney', 'monneny', 'monneyp', 'monnye', 'monlney', 'moznney', 'monneyh', 'momney', 'monneyw', 'monnley', 'moiney', 'mgonney', 'monnsy', 'mqonney', 'monnly', 'munney', 'monneuy', 'mlnney', 'mornney', 'monnezy', 'monnea', 'mobnney', 'monkney', 'monnfey', 'monneb', 'moinney', 'monneyg', 'mbonney', 'mbnney', 'monnyy', 'monnewy', 'manney', 'monnef', 'moqney', 'dmonney', 'mohney', 'monnbey', 'jmonney', 'mopnney', 'mtnney', 'minney', 'msonney', 'umonney', 'moynney', 'monnmey', 'myonney', 'imonney', 'monsey', 'monuey', 'monncy', 'rmonney', 'mongney', 'sonney', 'mojney', 'morney', 'vmonney', 'moncney', 'monnpey', 'monneiy', 'mpnney', 'monpey', 'mnney', 'money', 'mowney', 'mnnney', 'monnehy', 'monnemy', 'moxnney', 'monnoey', 'mponney', 'monqney', 'mmonney', 'monnjey', 'mogney', 'monneby', 'monzey', 'monnez', 'monnkey', 'monnei', 'monneyu', 'monwney', 'mvnney', 'monnby', 'monjney', 'monney', 'xmonney', 'mzonney', 'monnmy', 'emonney', 'motnney', 'monnvy', 'mconney', 'monneyj', 'tonney', 'mwonney', 'monuney', 'moqnney', 'monncey', 'mmnney', 'momnney', 'monned', 'monneh', 'ymonney', 'mooney', 'monneyz', 'monngy', 'muonney', 'monoey', 'monnoy', 'gmonney', 'monneo', 'moknney', 'montey', 'mionney', 'monnefy', 'monley', 'monneky', 'mjnney', 'mosney', 'monnay', 'monnrey', 'mqnney', 'monnen', 'monndey', 'moaney', 'montney', 'monnety', 'monnsey', 'oonney', 'moncey', 'monny', 'monnedy', 'monnky', 'ronney', 'monnwey', 'mofney', 'monwey', 'wmonney', 'monnqey', 'monnecy', 'monnzey', 'monngey', 'zonney', 'uonney', 'monnee', 'monneyq', 'modney', 'mznney', 'moneny', 'honney', 'ionney', 'monnyey', 'monnek', 'kmonney', 'moenney', 'monnel', 'moxney', 'mnonney', 'omonney', 'monndy', 'molnney', 'yonney', 'mhonney', 'mononey', 'monnhey', 'aonney', 'mxonney', 'monnew', 'monnex', 'mondney', 'monsney', 'monnet', 'mdonney', 'monmney', 'mwnney', 'monnfy', 'mohnney', 'monnzy', 'modnney', 'monhney', 'moneney', 'monnery', 'msnney', 'mongey', 'monvney', 'monneyv', 'monnuey', 'monnqy', 'monneyx', 'monnej', 'monbey', 'moniney', 'monneyl', 'smonney', 'moyney', 'mobney', 'monaney', 'mnoney', 'monfey', 'monneyy', 'moneey', 'monvey', 'mjonney', 'monhey', 'monnwy', 'monnaey', 'monnep', 'mownney', 'qonney', 'monnely', 'monrney', 'hmonney', 'monnry', 'movnney', 'mxnney', 'monniey', 'monner', 'menney', 'maonney', 'moonney', 'monneey', 'mcnney', 'monkey', 'monyney', 'mdnney', 'monjey', 'eonney', 'bonney', 'mlonney', 'amonney', 'mozney', 'onney', 'monnem', 'mounney', 'monnesy', 'monnes', 'monnepy', 'monnuy', 'bmonney', 'motney', 'mknney', 'monnpy', 'mfnney', 'moniey', 'movney', 'pmonney', 'monneym', 'monneqy', 'monneyt', 'monneyb', 'monnney', 'monneoy', 'mtonney', 'monnvey', 'monpney', 'monnegy', 'mocney', 'monnxey', 'moeney', 'mognney', 'mokney', 'mondey', 'monmey', 'mrnney', 'mkonney', 'monneu', 'monniy', 'molney', 'mvonney', 'monneys', 'monneyf', 'monnec', 'monnev', 'monneq', 'monzney', 'monnevy', 'nonney', 'monneye', 'monneyd', 'monneyk', 'omnney', 'jonney', 'donney', 'meonney', 'mofnney', 'qmonney', 'monneyn', 'monbney', 'monaey', 'tmonney', 'mopney', 'monxey', 'monnny', 'zmonney', 'monne', 'fmonney', 'wonney', 'mynney', 'monneyo', 'moanney', 'monnty', 'monntey', 'monneyr', 'mhnney', 'conney', 'cmonney', 'monnejy', 'monrey', 'gonney', 'mgnney', 'fonney', 'mouney', 'nmonney', 'monneg', 'monneay', 'mocnney', 'monfney', 'mojnney', 'monneyi', 'monnjy', 'monqey', 'ponney', 'lonney', 'mosnney', 'lmonney', 'vonney', 'mfonney', 'monnhy', 'monxney', 'monneyc', 'konney', 'monnxy', 'monyey', 'monnexy', 'monneya'}

# %%
print(known(edits_one("monney")))
# Out:
# {'money', 'monkey'}

# %%
# Let's look at words that are two edits away
print(len(set(edits_two("monney"))))
print(known(edits_one("monney")))
# Out:
# 51013
# {'money', 'monkey'}

# %%
# Let's look at possible corrections of a word
print(possible_corrections("monney"))
# Out:
# {'money', 'monkey'}

# %%
# Let's look at probability of a word
print(prob("money"))
print(prob("monkey"))
# Out:
# 0.0002922233626303688
# 5.378344097491451e-06

# %%
def spell_check(word):
    "Print the most probable spelling correction for `word` out of all the `possible_corrections`"
    correct_word = max(possible_corrections(word), key=prob)
    if correct_word != word:
        return "Did you mean " + correct_word + "?"
    else:
        return "Correct spelling."

# %%
# test spell check
print(spell_check("monney"))
# Out:
# Did you mean money?

# %%
possible_corrections("emfasize")
# Out:
# {'emphasize'}
