# %% [markdown]
# # Introduction
# In this demonstration, we will implement a generative adversarial network (GAN) to generate random new realistic images of clothing apparels by training it on the fashion-MNIST dataset from `keras`. The objective of this demonstration is to motivate the importance of latent spaces and how they can be used to generate new images.

# %% [markdown]
# ## Setup
# Let us import the necessary packages and methods for this demonstration:
# - Working with numeric structures: `numpy`
# - Working with images: `matplotlib.pyplot`
# - Working with artificial neural networks: `tensorflow`, `keras`

# %%
# Load necessary methods and packages
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data
# Let us load the fashion-MNIST dataset and study the images that we are working with.

# %%
# Import the 'fashion_mnist' data package from 'keras'
from keras.datasets import fashion_mnist

# Load the data
(X_train, _), (X_test, _) = fashion_mnist.load_data()

# Undo the train-test split
X = np.concatenate([X_train, X_test], axis = 0)

# Normalize the pixel gray levels
X = np.expand_dims(X, -1).astype('float32') / 255

# %% [markdown]
# GANs are used for random image generation and hence follow a different training regime. Because of this, we have the following considerations:
# - We do not need the $y$ values that are generally used for classification
# - We do not need a train-test split

# %%
# Sample a few fashion MNIST images from the data and view the images
indices = np.random.randint(0, X.shape[0], size = 25)

images = X[indices]

plt.figure(figsize = (5, 5))

for i in np.arange(0, len(indices), 1):
    plt.subplot(5, 5, i + 1)
    image = images[i]
    plt.imshow(image, cmap = 'gray')
    plt.axis('off')

# %% [markdown]
# You can see that the fashion-MNIST data are grayscale images of size 28x28 of various clothing apparels such as shoes, shirts, and so on.

# %%
# Study the shape of the data
print('Data shape: ', X.shape) # (70000, 28, 28, 1) --- 70000 images, each 28x28 pixels
# Out:
# Data shape:  (70000, 28, 28, 1)

# %% [markdown]
# # Part 1 - Building the GAN
# In this section, we will construct the components of the GAN but we will not combine them into a single model. This is because we need to discard the discriminator at the end anyway. Note that the GAN is primarily comprised of the generator and the discriminator during training and only the generator during inference.

# %% [markdown]
# ### Generator
# The generator (G) is designed to map the latent space vector $z$ to the image space.
#
# Let's define a function to build the generator. The generator is essentially a combination of a fully connected layer followed by transpose convolutional layers that produce images at the end.

# %%
# Define the generator
def build_generator(latent_dim = 1):
    G = keras.models.Sequential([layers.Dense(28 * 28 * 256, use_bias = False, input_shape = (latent_dim,)),
                                 layers.BatchNormalization(),
                                 layers.LeakyReLU(),
                                 layers.Reshape((28, 28, 256)),
                                 layers.Conv2DTranspose(filters = 128, kernel_size = 3, strides = 1, use_bias = False, padding = 'same'),
                                 layers.BatchNormalization(),
                                 layers.LeakyReLU(),
                                 layers.Conv2DTranspose(filters = 64, kernel_size = 3, strides = 1, use_bias = False, padding = 'same'),
                                 layers.BatchNormalization(),
                                 layers.LeakyReLU(),
                                 layers.Conv2DTranspose(filters = 32, kernel_size = 3, strides = 1, use_bias = False, padding = 'same'),
                                 layers.BatchNormalization(),
                                 layers.LeakyReLU(),
                                 layers.Conv2DTranspose(filters = 1, kernel_size = 3, strides = 1, use_bias = False, padding = 'same')])

    return G

# %% [markdown]
# ### Discriminator
# The discriminator (D) is designed to be able to tell the difference between a real image and an image that is generated by the generator.
#
# Let's define a function to build the discriminator. The discriminator is a combination of convolutioanl layers and a fully connected at the end to classify incoming images.

# %%
# Define the discriminator
def build_discriminator():
    D = keras.models.Sequential([layers.Conv2D(filters = 32, kernel_size = 3, strides = 1, use_bias = False, padding = 'same', input_shape = (28, 28, 1)),
                                 layers.LeakyReLU(),
                                 layers.Dropout(rate = 0.3),
                                 layers.Conv2D(filters = 64, kernel_size = 3, strides = 1, use_bias = False, padding = 'same'),
                                 layers.LeakyReLU(),
                                 layers.Dropout(rate = 0.3),
                                 layers.Conv2D(filters = 128, kernel_size = 3, strides = 1, use_bias = False, padding = 'same'),
                                 layers.LeakyReLU(),
                                 layers.Dropout(rate = 0.3),
                                 layers.Flatten(),
                                 layers.Dense(units = 1, use_bias = False)])

    return D

# %% [markdown]
# Now that the generator and the discriminator have been defined, we can instantiate them as components of the GAN.

# %%
# Set a latent vector size
latent_dim = 4

# %% [markdown]
# GANs also use random vectors from a latent space to generate new images.

# %%
# Create generator
generator = build_generator(latent_dim = latent_dim)

# Print the summary of the model
generator.summary()
# Out:
# Model: "sequential_38"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_38 (Dense)            (None, 200704)            802816
#
#  batch_normalization_52 (Ba  (None, 200704)            802816
#  tchNormalization)
#
#  leaky_re_lu_92 (LeakyReLU)  (None, 200704)            0
#
#  reshape_19 (Reshape)        (None, 28, 28, 256)       0
#
#  conv2d_transpose_52 (Conv2  (None, 28, 28, 128)       294912
#  DTranspose)
#
#  batch_normalization_53 (Ba  (None, 28, 28, 128)       512
#  tchNormalization)
#
#  leaky_re_lu_93 (LeakyReLU)  (None, 28, 28, 128)       0
#
#  conv2d_transpose_53 (Conv2  (None, 28, 28, 64)        73728
#  DTranspose)
#
#  batch_normalization_54 (Ba  (None, 28, 28, 64)        256
#  tchNormalization)
#
#  leaky_re_lu_94 (LeakyReLU)  (None, 28, 28, 64)        0
#
#  conv2d_transpose_54 (Conv2  (None, 28, 28, 32)        18432
#  DTranspose)
#
#  batch_normalization_55 (Ba  (None, 28, 28, 32)        128
#  tchNormalization)
#
#  leaky_re_lu_95 (LeakyReLU)  (None, 28, 28, 32)        0
#
#  conv2d_transpose_55 (Conv2  (None, 28, 28, 1)         288
#  DTranspose)
#
# =================================================================
# Total params: 1993888 (7.61 MB)
# Trainable params: 1592032 (6.07 MB)
# Non-trainable params: 401856 (1.53 MB)
# _________________________________________________________________

# %%
# Create discriminator
discriminator = build_discriminator()

# Print the summary of the model
discriminator.summary()
# Out:
# Model: "sequential_39"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_40 (Conv2D)          (None, 28, 28, 32)        288
#
#  leaky_re_lu_96 (LeakyReLU)  (None, 28, 28, 32)        0
#
#  dropout_40 (Dropout)        (None, 28, 28, 32)        0
#
#  conv2d_41 (Conv2D)          (None, 28, 28, 64)        18432
#
#  leaky_re_lu_97 (LeakyReLU)  (None, 28, 28, 64)        0
#
#  dropout_41 (Dropout)        (None, 28, 28, 64)        0
#
#  conv2d_42 (Conv2D)          (None, 28, 28, 128)       73728
#
#  leaky_re_lu_98 (LeakyReLU)  (None, 28, 28, 128)       0
#
#  dropout_42 (Dropout)        (None, 28, 28, 128)       0
#
#  flatten_19 (Flatten)        (None, 100352)            0
#
#  dense_39 (Dense)            (None, 1)                 100352
#
# =================================================================
# Total params: 192800 (753.12 KB)
# Trainable params: 192800 (753.12 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Part 2 - Training the Network
# In this section, we will define loss functions for the GAN and train it.

# %%
# Define loss functions
cross_entropy = keras.losses.BinaryCrossentropy(from_logits = True)

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss

    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
# Define the optimizers
generator_optimizer = tf.keras.optimizers.Adam(learning_rate = 0.0005)
discriminator_optimizer = tf.keras.optimizers.Adam(learning_rate = 0.0005)

# %%
# Set a batch size and a number of epochs
batch_size = 64
n_epochs = 5

# %%
# Define the training step
@tf.function
def train_step(images = None, batch_size = 1, latent_dim = 1):
    noise = tf.random.normal([batch_size, latent_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as dis_tape:
        generated_images = generator(noise, training = True)

        real_output = discriminator(images, training = True)
        fake_output = discriminator(generated_images, training = True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = dis_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

# %%
# Run the training loop
n_batches = X.shape[0] // batch_size
loss_comps = n_epochs * n_batches
i = 0
for epoch in range(n_epochs):
    for batch in range(n_batches):
        i = i + 1
        print('Parameter updates using loss computation number {} out of {} computations...'.format(i, loss_comps))
        batch_images = X[batch * batch_size : (batch + 1) * batch_size]
        train_step(images = batch_images, batch_size = batch_size, latent_dim = latent_dim)
# Out:
# Streaming output truncated to the last 5000 lines.
# Parameter updates using loss computation number 466 out of 5465 computations...
# Parameter updates using loss computation number 467 out of 5465 computations...
# Parameter updates using loss computation number 468 out of 5465 computations...
# Parameter updates using loss computation number 469 out of 5465 computations...
# Parameter updates using loss computation number 470 out of 5465 computations...
# Parameter updates using loss computation number 471 out of 5465 computations...
# Parameter updates using loss computation number 472 out of 5465 computations...
# Parameter updates using loss computation number 473 out of 5465 computations...
# Parameter updates using loss computation number 474 out of 5465 computations...
# Parameter updates using loss computation number 475 out of 5465 computations...
# Parameter updates using loss computation number 476 out of 5465 computations...
# Parameter updates using loss computation number 477 out of 5465 computations...
# Parameter updates using loss computation number 478 out of 5465 computations...
# Parameter updates using loss computation number 479 out of 5465 computations...
# Parameter updates using loss computation number 480 out of 5465 computations...
# Parameter updates using loss computation number 481 out of 5465 computations...
# Parameter updates using loss computation number 482 out of 5465 computations...
# Parameter updates using loss computation number 483 out of 5465 computations...
# Parameter updates using loss computation number 484 out of 5465 computations...
# Parameter updates using loss computation number 485 out of 5465 computations...
# Parameter updates using loss computation number 486 out of 5465 computations...
# Parameter updates using loss computation number 487 out of 5465 computations...
# Parameter updates using loss computation number 488 out of 5465 computations...
# Parameter updates using loss computation number 489 out of 5465 computations...
# Parameter updates using loss computation number 490 out of 5465 computations...
# Parameter updates using loss computation number 491 out of 5465 computations...
# Parameter updates using loss computation number 492 out of 5465 computations...
# Parameter updates using loss computation number 493 out of 5465 computations...
# Parameter updates using loss computation number 494 out of 5465 computations...
# Parameter updates using loss computation number 495 out of 5465 computations...
# Parameter updates using loss computation number 496 out of 5465 computations...
# Parameter updates using loss computation number 497 out of 5465 computations...
# Parameter updates using loss computation number 498 out of 5465 computations...
# Parameter updates using loss computation number 499 out of 5465 computations...
# Parameter updates using loss computation number 500 out of 5465 computations...
# Parameter updates using loss computation number 501 out of 5465 computations...
# Parameter updates using loss computation number 502 out of 5465 computations...
# Parameter updates using loss computation number 503 out of 5465 computations...
# Parameter updates using loss computation number 504 out of 5465 computations...
# Parameter updates using loss computation number 505 out of 5465 computations...
# Parameter updates using loss computation number 506 out of 5465 computations...
# Parameter updates using loss computation number 507 out of 5465 computations...
# Parameter updates using loss computation number 508 out of 5465 computations...
# Parameter updates using loss computation number 509 out of 5465 computations...
# Parameter updates using loss computation number 510 out of 5465 computations...
# Parameter updates using loss computation number 511 out of 5465 computations...
# Parameter updates using loss computation number 512 out of 5465 computations...
# Parameter updates using loss computation number 513 out of 5465 computations...
# Parameter updates using loss computation number 514 out of 5465 computations...
# Parameter updates using loss computation number 515 out of 5465 computations...
# Parameter updates using loss computation number 516 out of 5465 computations...
# Parameter updates using loss computation number 517 out of 5465 computations...
# Parameter updates using loss computation number 518 out of 5465 computations...
# Parameter updates using loss computation number 519 out of 5465 computations...
# Parameter updates using loss computation number 520 out of 5465 computations...
# Parameter updates using loss computation number 521 out of 5465 computations...
# Parameter updates using loss computation number 522 out of 5465 computations...
# Parameter updates using loss computation number 523 out of 5465 computations...
# Parameter updates using loss computation number 524 out of 5465 computations...
# Parameter updates using loss computation number 525 out of 5465 computations...
# Parameter updates using loss computation number 526 out of 5465 computations...
# Parameter updates using loss computation number 527 out of 5465 computations...
# Parameter updates using loss computation number 528 out of 5465 computations...
# Parameter updates using loss computation number 529 out of 5465 computations...
# Parameter updates using loss computation number 530 out of 5465 computations...
# Parameter updates using loss computation number 531 out of 5465 computations...
# Parameter updates using loss computation number 532 out of 5465 computations...
# Parameter updates using loss computation number 533 out of 5465 computations...
# Parameter updates using loss computation number 534 out of 5465 computations...
# Parameter updates using loss computation number 535 out of 5465 computations...
# Parameter updates using loss computation number 536 out of 5465 computations...
# Parameter updates using loss computation number 537 out of 5465 computations...
# Parameter updates using loss computation number 538 out of 5465 computations...
# Parameter updates using loss computation number 539 out of 5465 computations...
# Parameter updates using loss computation number 540 out of 5465 computations...
# Parameter updates using loss computation number 541 out of 5465 computations...
# Parameter updates using loss computation number 542 out of 5465 computations...
# Parameter updates using loss computation number 543 out of 5465 computations...
# Parameter updates using loss computation number 544 out of 5465 computations...
# Parameter updates using loss computation number 545 out of 5465 computations...
# Parameter updates using loss computation number 546 out of 5465 computations...
# Parameter updates using loss computation number 547 out of 5465 computations...
# Parameter updates using loss computation number 548 out of 5465 computations...
# Parameter updates using loss computation number 549 out of 5465 computations...
# Parameter updates using loss computation number 550 out of 5465 computations...
# Parameter updates using loss computation number 551 out of 5465 computations...
# Parameter updates using loss computation number 552 out of 5465 computations...
# Parameter updates using loss computation number 553 out of 5465 computations...
# Parameter updates using loss computation number 554 out of 5465 computations...
# Parameter updates using loss computation number 555 out of 5465 computations...
# Parameter updates using loss computation number 556 out of 5465 computations...
# Parameter updates using loss computation number 557 out of 5465 computations...
# Parameter updates using loss computation number 558 out of 5465 computations...
# Parameter updates using loss computation number 559 out of 5465 computations...
# Parameter updates using loss computation number 560 out of 5465 computations...
# Parameter updates using loss computation number 561 out of 5465 computations...
# Parameter updates using loss computation number 562 out of 5465 computations...
# Parameter updates using loss computation number 563 out of 5465 computations...
# Parameter updates using loss computation number 564 out of 5465 computations...
# Parameter updates using loss computation number 565 out of 5465 computations...
# Parameter updates using loss computation number 566 out of 5465 computations...
# Parameter updates using loss computation number 567 out of 5465 computations...
# Parameter updates using loss computation number 568 out of 5465 computations...
# Parameter updates using loss computation number 569 out of 5465 computations...
# Parameter updates using loss computation number 570 out of 5465 computations...
# Parameter updates using loss computation number 571 out of 5465 computations...
# Parameter updates using loss computation number 572 out of 5465 computations...
# Parameter updates using loss computation number 573 out of 5465 computations...
# Parameter updates using loss computation number 574 out of 5465 computations...
# Parameter updates using loss computation number 575 out of 5465 computations...
# Parameter updates using loss computation number 576 out of 5465 computations...
# Parameter updates using loss computation number 577 out of 5465 computations...
# Parameter updates using loss computation number 578 out of 5465 computations...
# Parameter updates using loss computation number 579 out of 5465 computations...
# Parameter updates using loss computation number 580 out of 5465 computations...
# Parameter updates using loss computation number 581 out of 5465 computations...
# Parameter updates using loss computation number 582 out of 5465 computations...
# Parameter updates using loss computation number 583 out of 5465 computations...
# Parameter updates using loss computation number 584 out of 5465 computations...
# Parameter updates using loss computation number 585 out of 5465 computations...
# Parameter updates using loss computation number 586 out of 5465 computations...
# Parameter updates using loss computation number 587 out of 5465 computations...
# Parameter updates using loss computation number 588 out of 5465 computations...
# Parameter updates using loss computation number 589 out of 5465 computations...
# Parameter updates using loss computation number 590 out of 5465 computations...
# Parameter updates using loss computation number 591 out of 5465 computations...
# Parameter updates using loss computation number 592 out of 5465 computations...
# Parameter updates using loss computation number 593 out of 5465 computations...
# Parameter updates using loss computation number 594 out of 5465 computations...
# Parameter updates using loss computation number 595 out of 5465 computations...
# Parameter updates using loss computation number 596 out of 5465 computations...
# Parameter updates using loss computation number 597 out of 5465 computations...
# Parameter updates using loss computation number 598 out of 5465 computations...
# Parameter updates using loss computation number 599 out of 5465 computations...
# Parameter updates using loss computation number 600 out of 5465 computations...
# Parameter updates using loss computation number 601 out of 5465 computations...
# Parameter updates using loss computation number 602 out of 5465 computations...
# Parameter updates using loss computation number 603 out of 5465 computations...
# Parameter updates using loss computation number 604 out of 5465 computations...
# Parameter updates using loss computation number 605 out of 5465 computations...
# Parameter updates using loss computation number 606 out of 5465 computations...
# Parameter updates using loss computation number 607 out of 5465 computations...
# Parameter updates using loss computation number 608 out of 5465 computations...
# Parameter updates using loss computation number 609 out of 5465 computations...
# Parameter updates using loss computation number 610 out of 5465 computations...
# Parameter updates using loss computation number 611 out of 5465 computations...
# Parameter updates using loss computation number 612 out of 5465 computations...
# Parameter updates using loss computation number 613 out of 5465 computations...
# Parameter updates using loss computation number 614 out of 5465 computations...
# Parameter updates using loss computation number 615 out of 5465 computations...
# Parameter updates using loss computation number 616 out of 5465 computations...
# Parameter updates using loss computation number 617 out of 5465 computations...
# Parameter updates using loss computation number 618 out of 5465 computations...
# Parameter updates using loss computation number 619 out of 5465 computations...
# Parameter updates using loss computation number 620 out of 5465 computations...
# Parameter updates using loss computation number 621 out of 5465 computations...
# Parameter updates using loss computation number 622 out of 5465 computations...
# Parameter updates using loss computation number 623 out of 5465 computations...
# Parameter updates using loss computation number 624 out of 5465 computations...
# Parameter updates using loss computation number 625 out of 5465 computations...
# Parameter updates using loss computation number 626 out of 5465 computations...
# Parameter updates using loss computation number 627 out of 5465 computations...
# Parameter updates using loss computation number 628 out of 5465 computations...
# Parameter updates using loss computation number 629 out of 5465 computations...
# Parameter updates using loss computation number 630 out of 5465 computations...
# Parameter updates using loss computation number 631 out of 5465 computations...
# Parameter updates using loss computation number 632 out of 5465 computations...
# Parameter updates using loss computation number 633 out of 5465 computations...
# Parameter updates using loss computation number 634 out of 5465 computations...
# Parameter updates using loss computation number 635 out of 5465 computations...
# Parameter updates using loss computation number 636 out of 5465 computations...
# Parameter updates using loss computation number 637 out of 5465 computations...
# Parameter updates using loss computation number 638 out of 5465 computations...
# Parameter updates using loss computation number 639 out of 5465 computations...
# Parameter updates using loss computation number 640 out of 5465 computations...
# Parameter updates using loss computation number 641 out of 5465 computations...
# Parameter updates using loss computation number 642 out of 5465 computations...
# Parameter updates using loss computation number 643 out of 5465 computations...
# Parameter updates using loss computation number 644 out of 5465 computations...
# Parameter updates using loss computation number 645 out of 5465 computations...
# Parameter updates using loss computation number 646 out of 5465 computations...
# Parameter updates using loss computation number 647 out of 5465 computations...
# Parameter updates using loss computation number 648 out of 5465 computations...
# Parameter updates using loss computation number 649 out of 5465 computations...
# Parameter updates using loss computation number 650 out of 5465 computations...
# Parameter updates using loss computation number 651 out of 5465 computations...
# Parameter updates using loss computation number 652 out of 5465 computations...
# Parameter updates using loss computation number 653 out of 5465 computations...
# Parameter updates using loss computation number 654 out of 5465 computations...
# Parameter updates using loss computation number 655 out of 5465 computations...
# Parameter updates using loss computation number 656 out of 5465 computations...
# Parameter updates using loss computation number 657 out of 5465 computations...
# Parameter updates using loss computation number 658 out of 5465 computations...
# Parameter updates using loss computation number 659 out of 5465 computations...
# Parameter updates using loss computation number 660 out of 5465 computations...
# Parameter updates using loss computation number 661 out of 5465 computations...
# Parameter updates using loss computation number 662 out of 5465 computations...
# Parameter updates using loss computation number 663 out of 5465 computations...
# Parameter updates using loss computation number 664 out of 5465 computations...
# Parameter updates using loss computation number 665 out of 5465 computations...
# Parameter updates using loss computation number 666 out of 5465 computations...
# Parameter updates using loss computation number 667 out of 5465 computations...
# Parameter updates using loss computation number 668 out of 5465 computations...
# Parameter updates using loss computation number 669 out of 5465 computations...
# Parameter updates using loss computation number 670 out of 5465 computations...
# Parameter updates using loss computation number 671 out of 5465 computations...
# Parameter updates using loss computation number 672 out of 5465 computations...
# Parameter updates using loss computation number 673 out of 5465 computations...
# Parameter updates using loss computation number 674 out of 5465 computations...
# Parameter updates using loss computation number 675 out of 5465 computations...
# Parameter updates using loss computation number 676 out of 5465 computations...
# Parameter updates using loss computation number 677 out of 5465 computations...
# Parameter updates using loss computation number 678 out of 5465 computations...
# Parameter updates using loss computation number 679 out of 5465 computations...
# Parameter updates using loss computation number 680 out of 5465 computations...
# Parameter updates using loss computation number 681 out of 5465 computations...
# Parameter updates using loss computation number 682 out of 5465 computations...
# Parameter updates using loss computation number 683 out of 5465 computations...
# Parameter updates using loss computation number 684 out of 5465 computations...
# Parameter updates using loss computation number 685 out of 5465 computations...
# Parameter updates using loss computation number 686 out of 5465 computations...
# Parameter updates using loss computation number 687 out of 5465 computations...
# Parameter updates using loss computation number 688 out of 5465 computations...
# Parameter updates using loss computation number 689 out of 5465 computations...
# Parameter updates using loss computation number 690 out of 5465 computations...
# Parameter updates using loss computation number 691 out of 5465 computations...
# Parameter updates using loss computation number 692 out of 5465 computations...
# Parameter updates using loss computation number 693 out of 5465 computations...
# Parameter updates using loss computation number 694 out of 5465 computations...
# Parameter updates using loss computation number 695 out of 5465 computations...
# Parameter updates using loss computation number 696 out of 5465 computations...
# Parameter updates using loss computation number 697 out of 5465 computations...
# Parameter updates using loss computation number 698 out of 5465 computations...
# Parameter updates using loss computation number 699 out of 5465 computations...
# Parameter updates using loss computation number 700 out of 5465 computations...
# Parameter updates using loss computation number 701 out of 5465 computations...
# Parameter updates using loss computation number 702 out of 5465 computations...
# Parameter updates using loss computation number 703 out of 5465 computations...
# Parameter updates using loss computation number 704 out of 5465 computations...
# Parameter updates using loss computation number 705 out of 5465 computations...
# Parameter updates using loss computation number 706 out of 5465 computations...
# Parameter updates using loss computation number 707 out of 5465 computations...
# Parameter updates using loss computation number 708 out of 5465 computations...
# Parameter updates using loss computation number 709 out of 5465 computations...
# Parameter updates using loss computation number 710 out of 5465 computations...
# Parameter updates using loss computation number 711 out of 5465 computations...
# Parameter updates using loss computation number 712 out of 5465 computations...
# Parameter updates using loss computation number 713 out of 5465 computations...
# Parameter updates using loss computation number 714 out of 5465 computations...
# Parameter updates using loss computation number 715 out of 5465 computations...
# Parameter updates using loss computation number 716 out of 5465 computations...
# Parameter updates using loss computation number 717 out of 5465 computations...
# Parameter updates using loss computation number 718 out of 5465 computations...
# Parameter updates using loss computation number 719 out of 5465 computations...
# Parameter updates using loss computation number 720 out of 5465 computations...
# Parameter updates using loss computation number 721 out of 5465 computations...
# Parameter updates using loss computation number 722 out of 5465 computations...
# Parameter updates using loss computation number 723 out of 5465 computations...
# Parameter updates using loss computation number 724 out of 5465 computations...
# Parameter updates using loss computation number 725 out of 5465 computations...
# Parameter updates using loss computation number 726 out of 5465 computations...
# Parameter updates using loss computation number 727 out of 5465 computations...
# Parameter updates using loss computation number 728 out of 5465 computations...
# Parameter updates using loss computation number 729 out of 5465 computations...
# Parameter updates using loss computation number 730 out of 5465 computations...
# Parameter updates using loss computation number 731 out of 5465 computations...
# Parameter updates using loss computation number 732 out of 5465 computations...
# Parameter updates using loss computation number 733 out of 5465 computations...
# Parameter updates using loss computation number 734 out of 5465 computations...
# Parameter updates using loss computation number 735 out of 5465 computations...
# Parameter updates using loss computation number 736 out of 5465 computations...
# Parameter updates using loss computation number 737 out of 5465 computations...
# Parameter updates using loss computation number 738 out of 5465 computations...
# Parameter updates using loss computation number 739 out of 5465 computations...
# Parameter updates using loss computation number 740 out of 5465 computations...
# Parameter updates using loss computation number 741 out of 5465 computations...
# Parameter updates using loss computation number 742 out of 5465 computations...
# Parameter updates using loss computation number 743 out of 5465 computations...
# Parameter updates using loss computation number 744 out of 5465 computations...
# Parameter updates using loss computation number 745 out of 5465 computations...
# Parameter updates using loss computation number 746 out of 5465 computations...
# Parameter updates using loss computation number 747 out of 5465 computations...
# Parameter updates using loss computation number 748 out of 5465 computations...
# Parameter updates using loss computation number 749 out of 5465 computations...
# Parameter updates using loss computation number 750 out of 5465 computations...
# Parameter updates using loss computation number 751 out of 5465 computations...
# Parameter updates using loss computation number 752 out of 5465 computations...
# Parameter updates using loss computation number 753 out of 5465 computations...
# Parameter updates using loss computation number 754 out of 5465 computations...
# Parameter updates using loss computation number 755 out of 5465 computations...
# Parameter updates using loss computation number 756 out of 5465 computations...
# Parameter updates using loss computation number 757 out of 5465 computations...
# Parameter updates using loss computation number 758 out of 5465 computations...
# Parameter updates using loss computation number 759 out of 5465 computations...
# Parameter updates using loss computation number 760 out of 5465 computations...
# Parameter updates using loss computation number 761 out of 5465 computations...
# Parameter updates using loss computation number 762 out of 5465 computations...
# Parameter updates using loss computation number 763 out of 5465 computations...
# Parameter updates using loss computation number 764 out of 5465 computations...
# Parameter updates using loss computation number 765 out of 5465 computations...
# Parameter updates using loss computation number 766 out of 5465 computations...
# Parameter updates using loss computation number 767 out of 5465 computations...
# Parameter updates using loss computation number 768 out of 5465 computations...
# Parameter updates using loss computation number 769 out of 5465 computations...
# Parameter updates using loss computation number 770 out of 5465 computations...
# Parameter updates using loss computation number 771 out of 5465 computations...
# Parameter updates using loss computation number 772 out of 5465 computations...
# Parameter updates using loss computation number 773 out of 5465 computations...
# Parameter updates using loss computation number 774 out of 5465 computations...
# Parameter updates using loss computation number 775 out of 5465 computations...
# Parameter updates using loss computation number 776 out of 5465 computations...
# Parameter updates using loss computation number 777 out of 5465 computations...
# Parameter updates using loss computation number 778 out of 5465 computations...
# Parameter updates using loss computation number 779 out of 5465 computations...
# Parameter updates using loss computation number 780 out of 5465 computations...
# Parameter updates using loss computation number 781 out of 5465 computations...
# Parameter updates using loss computation number 782 out of 5465 computations...
# Parameter updates using loss computation number 783 out of 5465 computations...
# Parameter updates using loss computation number 784 out of 5465 computations...
# Parameter updates using loss computation number 785 out of 5465 computations...
# Parameter updates using loss computation number 786 out of 5465 computations...
# Parameter updates using loss computation number 787 out of 5465 computations...
# Parameter updates using loss computation number 788 out of 5465 computations...
# Parameter updates using loss computation number 789 out of 5465 computations...
# Parameter updates using loss computation number 790 out of 5465 computations...
# Parameter updates using loss computation number 791 out of 5465 computations...
# Parameter updates using loss computation number 792 out of 5465 computations...
# Parameter updates using loss computation number 793 out of 5465 computations...
# Parameter updates using loss computation number 794 out of 5465 computations...
# Parameter updates using loss computation number 795 out of 5465 computations...
# Parameter updates using loss computation number 796 out of 5465 computations...
# Parameter updates using loss computation number 797 out of 5465 computations...
# Parameter updates using loss computation number 798 out of 5465 computations...
# Parameter updates using loss computation number 799 out of 5465 computations...
# Parameter updates using loss computation number 800 out of 5465 computations...
# Parameter updates using loss computation number 801 out of 5465 computations...
# Parameter updates using loss computation number 802 out of 5465 computations...
# Parameter updates using loss computation number 803 out of 5465 computations...
# Parameter updates using loss computation number 804 out of 5465 computations...
# Parameter updates using loss computation number 805 out of 5465 computations...
# Parameter updates using loss computation number 806 out of 5465 computations...
# Parameter updates using loss computation number 807 out of 5465 computations...
# Parameter updates using loss computation number 808 out of 5465 computations...
# Parameter updates using loss computation number 809 out of 5465 computations...
# Parameter updates using loss computation number 810 out of 5465 computations...
# Parameter updates using loss computation number 811 out of 5465 computations...
# Parameter updates using loss computation number 812 out of 5465 computations...
# Parameter updates using loss computation number 813 out of 5465 computations...
# Parameter updates using loss computation number 814 out of 5465 computations...
# Parameter updates using loss computation number 815 out of 5465 computations...
# Parameter updates using loss computation number 816 out of 5465 computations...
# Parameter updates using loss computation number 817 out of 5465 computations...
# Parameter updates using loss computation number 818 out of 5465 computations...
# Parameter updates using loss computation number 819 out of 5465 computations...
# Parameter updates using loss computation number 820 out of 5465 computations...
# Parameter updates using loss computation number 821 out of 5465 computations...
# Parameter updates using loss computation number 822 out of 5465 computations...
# Parameter updates using loss computation number 823 out of 5465 computations...
# Parameter updates using loss computation number 824 out of 5465 computations...
# Parameter updates using loss computation number 825 out of 5465 computations...
# Parameter updates using loss computation number 826 out of 5465 computations...
# Parameter updates using loss computation number 827 out of 5465 computations...
# Parameter updates using loss computation number 828 out of 5465 computations...
# Parameter updates using loss computation number 829 out of 5465 computations...
# Parameter updates using loss computation number 830 out of 5465 computations...
# Parameter updates using loss computation number 831 out of 5465 computations...
# Parameter updates using loss computation number 832 out of 5465 computations...
# Parameter updates using loss computation number 833 out of 5465 computations...
# Parameter updates using loss computation number 834 out of 5465 computations...
# Parameter updates using loss computation number 835 out of 5465 computations...
# Parameter updates using loss computation number 836 out of 5465 computations...
# Parameter updates using loss computation number 837 out of 5465 computations...
# Parameter updates using loss computation number 838 out of 5465 computations...
# Parameter updates using loss computation number 839 out of 5465 computations...
# Parameter updates using loss computation number 840 out of 5465 computations...
# Parameter updates using loss computation number 841 out of 5465 computations...
# Parameter updates using loss computation number 842 out of 5465 computations...
# Parameter updates using loss computation number 843 out of 5465 computations...
# Parameter updates using loss computation number 844 out of 5465 computations...
# Parameter updates using loss computation number 845 out of 5465 computations...
# Parameter updates using loss computation number 846 out of 5465 computations...
# Parameter updates using loss computation number 847 out of 5465 computations...
# Parameter updates using loss computation number 848 out of 5465 computations...
# Parameter updates using loss computation number 849 out of 5465 computations...
# Parameter updates using loss computation number 850 out of 5465 computations...
# Parameter updates using loss computation number 851 out of 5465 computations...
# Parameter updates using loss computation number 852 out of 5465 computations...
# Parameter updates using loss computation number 853 out of 5465 computations...
# Parameter updates using loss computation number 854 out of 5465 computations...
# Parameter updates using loss computation number 855 out of 5465 computations...
# Parameter updates using loss computation number 856 out of 5465 computations...
# Parameter updates using loss computation number 857 out of 5465 computations...
# Parameter updates using loss computation number 858 out of 5465 computations...
# Parameter updates using loss computation number 859 out of 5465 computations...
# Parameter updates using loss computation number 860 out of 5465 computations...
# Parameter updates using loss computation number 861 out of 5465 computations...
# Parameter updates using loss computation number 862 out of 5465 computations...
# Parameter updates using loss computation number 863 out of 5465 computations...
# Parameter updates using loss computation number 864 out of 5465 computations...
# Parameter updates using loss computation number 865 out of 5465 computations...
# Parameter updates using loss computation number 866 out of 5465 computations...
# Parameter updates using loss computation number 867 out of 5465 computations...
# Parameter updates using loss computation number 868 out of 5465 computations...
# Parameter updates using loss computation number 869 out of 5465 computations...
# Parameter updates using loss computation number 870 out of 5465 computations...
# Parameter updates using loss computation number 871 out of 5465 computations...
# Parameter updates using loss computation number 872 out of 5465 computations...
# Parameter updates using loss computation number 873 out of 5465 computations...
# Parameter updates using loss computation number 874 out of 5465 computations...
# Parameter updates using loss computation number 875 out of 5465 computations...
# Parameter updates using loss computation number 876 out of 5465 computations...
# Parameter updates using loss computation number 877 out of 5465 computations...
# Parameter updates using loss computation number 878 out of 5465 computations...
# Parameter updates using loss computation number 879 out of 5465 computations...
# Parameter updates using loss computation number 880 out of 5465 computations...
# Parameter updates using loss computation number 881 out of 5465 computations...
# Parameter updates using loss computation number 882 out of 5465 computations...
# Parameter updates using loss computation number 883 out of 5465 computations...
# Parameter updates using loss computation number 884 out of 5465 computations...
# Parameter updates using loss computation number 885 out of 5465 computations...
# Parameter updates using loss computation number 886 out of 5465 computations...
# Parameter updates using loss computation number 887 out of 5465 computations...
# Parameter updates using loss computation number 888 out of 5465 computations...
# Parameter updates using loss computation number 889 out of 5465 computations...
# Parameter updates using loss computation number 890 out of 5465 computations...
# Parameter updates using loss computation number 891 out of 5465 computations...
# Parameter updates using loss computation number 892 out of 5465 computations...
# Parameter updates using loss computation number 893 out of 5465 computations...
# Parameter updates using loss computation number 894 out of 5465 computations...
# Parameter updates using loss computation number 895 out of 5465 computations...
# Parameter updates using loss computation number 896 out of 5465 computations...
# Parameter updates using loss computation number 897 out of 5465 computations...
# Parameter updates using loss computation number 898 out of 5465 computations...
# Parameter updates using loss computation number 899 out of 5465 computations...
# Parameter updates using loss computation number 900 out of 5465 computations...
# Parameter updates using loss computation number 901 out of 5465 computations...
# Parameter updates using loss computation number 902 out of 5465 computations...
# Parameter updates using loss computation number 903 out of 5465 computations...
# Parameter updates using loss computation number 904 out of 5465 computations...
# Parameter updates using loss computation number 905 out of 5465 computations...
# Parameter updates using loss computation number 906 out of 5465 computations...
# Parameter updates using loss computation number 907 out of 5465 computations...
# Parameter updates using loss computation number 908 out of 5465 computations...
# Parameter updates using loss computation number 909 out of 5465 computations...
# Parameter updates using loss computation number 910 out of 5465 computations...
# Parameter updates using loss computation number 911 out of 5465 computations...
# Parameter updates using loss computation number 912 out of 5465 computations...
# Parameter updates using loss computation number 913 out of 5465 computations...
# Parameter updates using loss computation number 914 out of 5465 computations...
# Parameter updates using loss computation number 915 out of 5465 computations...
# Parameter updates using loss computation number 916 out of 5465 computations...
# Parameter updates using loss computation number 917 out of 5465 computations...
# Parameter updates using loss computation number 918 out of 5465 computations...
# Parameter updates using loss computation number 919 out of 5465 computations...
# Parameter updates using loss computation number 920 out of 5465 computations...
# Parameter updates using loss computation number 921 out of 5465 computations...
# Parameter updates using loss computation number 922 out of 5465 computations...
# Parameter updates using loss computation number 923 out of 5465 computations...
# Parameter updates using loss computation number 924 out of 5465 computations...
# Parameter updates using loss computation number 925 out of 5465 computations...
# Parameter updates using loss computation number 926 out of 5465 computations...
# Parameter updates using loss computation number 927 out of 5465 computations...
# Parameter updates using loss computation number 928 out of 5465 computations...
# Parameter updates using loss computation number 929 out of 5465 computations...
# Parameter updates using loss computation number 930 out of 5465 computations...
# Parameter updates using loss computation number 931 out of 5465 computations...
# Parameter updates using loss computation number 932 out of 5465 computations...
# Parameter updates using loss computation number 933 out of 5465 computations...
# Parameter updates using loss computation number 934 out of 5465 computations...
# Parameter updates using loss computation number 935 out of 5465 computations...
# Parameter updates using loss computation number 936 out of 5465 computations...
# Parameter updates using loss computation number 937 out of 5465 computations...
# Parameter updates using loss computation number 938 out of 5465 computations...
# Parameter updates using loss computation number 939 out of 5465 computations...
# Parameter updates using loss computation number 940 out of 5465 computations...
# Parameter updates using loss computation number 941 out of 5465 computations...
# Parameter updates using loss computation number 942 out of 5465 computations...
# Parameter updates using loss computation number 943 out of 5465 computations...
# Parameter updates using loss computation number 944 out of 5465 computations...
# Parameter updates using loss computation number 945 out of 5465 computations...
# Parameter updates using loss computation number 946 out of 5465 computations...
# Parameter updates using loss computation number 947 out of 5465 computations...
# Parameter updates using loss computation number 948 out of 5465 computations...
# Parameter updates using loss computation number 949 out of 5465 computations...
# Parameter updates using loss computation number 950 out of 5465 computations...
# Parameter updates using loss computation number 951 out of 5465 computations...
# Parameter updates using loss computation number 952 out of 5465 computations...
# Parameter updates using loss computation number 953 out of 5465 computations...
# Parameter updates using loss computation number 954 out of 5465 computations...
# Parameter updates using loss computation number 955 out of 5465 computations...
# Parameter updates using loss computation number 956 out of 5465 computations...
# Parameter updates using loss computation number 957 out of 5465 computations...
# Parameter updates using loss computation number 958 out of 5465 computations...
# Parameter updates using loss computation number 959 out of 5465 computations...
# Parameter updates using loss computation number 960 out of 5465 computations...
# Parameter updates using loss computation number 961 out of 5465 computations...
# Parameter updates using loss computation number 962 out of 5465 computations...
# Parameter updates using loss computation number 963 out of 5465 computations...
# Parameter updates using loss computation number 964 out of 5465 computations...
# Parameter updates using loss computation number 965 out of 5465 computations...
# Parameter updates using loss computation number 966 out of 5465 computations...
# Parameter updates using loss computation number 967 out of 5465 computations...
# Parameter updates using loss computation number 968 out of 5465 computations...
# Parameter updates using loss computation number 969 out of 5465 computations...
# Parameter updates using loss computation number 970 out of 5465 computations...
# Parameter updates using loss computation number 971 out of 5465 computations...
# Parameter updates using loss computation number 972 out of 5465 computations...
# Parameter updates using loss computation number 973 out of 5465 computations...
# Parameter updates using loss computation number 974 out of 5465 computations...
# Parameter updates using loss computation number 975 out of 5465 computations...
# Parameter updates using loss computation number 976 out of 5465 computations...
# Parameter updates using loss computation number 977 out of 5465 computations...
# Parameter updates using loss computation number 978 out of 5465 computations...
# Parameter updates using loss computation number 979 out of 5465 computations...
# Parameter updates using loss computation number 980 out of 5465 computations...
# Parameter updates using loss computation number 981 out of 5465 computations...
# Parameter updates using loss computation number 982 out of 5465 computations...
# Parameter updates using loss computation number 983 out of 5465 computations...
# Parameter updates using loss computation number 984 out of 5465 computations...
# Parameter updates using loss computation number 985 out of 5465 computations...
# Parameter updates using loss computation number 986 out of 5465 computations...
# Parameter updates using loss computation number 987 out of 5465 computations...
# Parameter updates using loss computation number 988 out of 5465 computations...
# Parameter updates using loss computation number 989 out of 5465 computations...
# Parameter updates using loss computation number 990 out of 5465 computations...
# Parameter updates using loss computation number 991 out of 5465 computations...
# Parameter updates using loss computation number 992 out of 5465 computations...
# Parameter updates using loss computation number 993 out of 5465 computations...
# Parameter updates using loss computation number 994 out of 5465 computations...
# Parameter updates using loss computation number 995 out of 5465 computations...
# Parameter updates using loss computation number 996 out of 5465 computations...
# Parameter updates using loss computation number 997 out of 5465 computations...
# Parameter updates using loss computation number 998 out of 5465 computations...
# Parameter updates using loss computation number 999 out of 5465 computations...
# Parameter updates using loss computation number 1000 out of 5465 computations...
# Parameter updates using loss computation number 1001 out of 5465 computations...
# Parameter updates using loss computation number 1002 out of 5465 computations...
# Parameter updates using loss computation number 1003 out of 5465 computations...
# Parameter updates using loss computation number 1004 out of 5465 computations...
# Parameter updates using loss computation number 1005 out of 5465 computations...
# Parameter updates using loss computation number 1006 out of 5465 computations...
# Parameter updates using loss computation number 1007 out of 5465 computations...
# Parameter updates using loss computation number 1008 out of 5465 computations...
# Parameter updates using loss computation number 1009 out of 5465 computations...
# Parameter updates using loss computation number 1010 out of 5465 computations...
# Parameter updates using loss computation number 1011 out of 5465 computations...
# Parameter updates using loss computation number 1012 out of 5465 computations...
# Parameter updates using loss computation number 1013 out of 5465 computations...
# Parameter updates using loss computation number 1014 out of 5465 computations...
# Parameter updates using loss computation number 1015 out of 5465 computations...
# Parameter updates using loss computation number 1016 out of 5465 computations...
# Parameter updates using loss computation number 1017 out of 5465 computations...
# Parameter updates using loss computation number 1018 out of 5465 computations...
# Parameter updates using loss computation number 1019 out of 5465 computations...
# Parameter updates using loss computation number 1020 out of 5465 computations...
# Parameter updates using loss computation number 1021 out of 5465 computations...
# Parameter updates using loss computation number 1022 out of 5465 computations...
# Parameter updates using loss computation number 1023 out of 5465 computations...
# Parameter updates using loss computation number 1024 out of 5465 computations...
# Parameter updates using loss computation number 1025 out of 5465 computations...
# Parameter updates using loss computation number 1026 out of 5465 computations...
# Parameter updates using loss computation number 1027 out of 5465 computations...
# Parameter updates using loss computation number 1028 out of 5465 computations...
# Parameter updates using loss computation number 1029 out of 5465 computations...
# Parameter updates using loss computation number 1030 out of 5465 computations...
# Parameter updates using loss computation number 1031 out of 5465 computations...
# Parameter updates using loss computation number 1032 out of 5465 computations...
# Parameter updates using loss computation number 1033 out of 5465 computations...
# Parameter updates using loss computation number 1034 out of 5465 computations...
# Parameter updates using loss computation number 1035 out of 5465 computations...
# Parameter updates using loss computation number 1036 out of 5465 computations...
# Parameter updates using loss computation number 1037 out of 5465 computations...
# Parameter updates using loss computation number 1038 out of 5465 computations...
# Parameter updates using loss computation number 1039 out of 5465 computations...
# Parameter updates using loss computation number 1040 out of 5465 computations...
# Parameter updates using loss computation number 1041 out of 5465 computations...
# Parameter updates using loss computation number 1042 out of 5465 computations...
# Parameter updates using loss computation number 1043 out of 5465 computations...
# Parameter updates using loss computation number 1044 out of 5465 computations...
# Parameter updates using loss computation number 1045 out of 5465 computations...
# Parameter updates using loss computation number 1046 out of 5465 computations...
# Parameter updates using loss computation number 1047 out of 5465 computations...
# Parameter updates using loss computation number 1048 out of 5465 computations...
# Parameter updates using loss computation number 1049 out of 5465 computations...
# Parameter updates using loss computation number 1050 out of 5465 computations...
# Parameter updates using loss computation number 1051 out of 5465 computations...
# Parameter updates using loss computation number 1052 out of 5465 computations...
# Parameter updates using loss computation number 1053 out of 5465 computations...
# Parameter updates using loss computation number 1054 out of 5465 computations...
# Parameter updates using loss computation number 1055 out of 5465 computations...
# Parameter updates using loss computation number 1056 out of 5465 computations...
# Parameter updates using loss computation number 1057 out of 5465 computations...
# Parameter updates using loss computation number 1058 out of 5465 computations...
# Parameter updates using loss computation number 1059 out of 5465 computations...
# Parameter updates using loss computation number 1060 out of 5465 computations...
# Parameter updates using loss computation number 1061 out of 5465 computations...
# Parameter updates using loss computation number 1062 out of 5465 computations...
# Parameter updates using loss computation number 1063 out of 5465 computations...
# ...
# Parameter updates using loss computation number 5269 out of 5465 computations...
# Parameter updates using loss computation number 5270 out of 5465 computations...
# Parameter updates using loss computation number 5271 out of 5465 computations...
# Parameter updates using loss computation number 5272 out of 5465 computations...
# Parameter updates using loss computation number 5273 out of 5465 computations...
# Parameter updates using loss computation number 5274 out of 5465 computations...
# Parameter updates using loss computation number 5275 out of 5465 computations...
# Parameter updates using loss computation number 5276 out of 5465 computations...
# Parameter updates using loss computation number 5277 out of 5465 computations...
# Parameter updates using loss computation number 5278 out of 5465 computations...
# Parameter updates using loss computation number 5279 out of 5465 computations...
# Parameter updates using loss computation number 5280 out of 5465 computations...
# Parameter updates using loss computation number 5281 out of 5465 computations...
# Parameter updates using loss computation number 5282 out of 5465 computations...
# Parameter updates using loss computation number 5283 out of 5465 computations...
# Parameter updates using loss computation number 5284 out of 5465 computations...
# Parameter updates using loss computation number 5285 out of 5465 computations...
# Parameter updates using loss computation number 5286 out of 5465 computations...
# Parameter updates using loss computation number 5287 out of 5465 computations...
# Parameter updates using loss computation number 5288 out of 5465 computations...
# Parameter updates using loss computation number 5289 out of 5465 computations...
# Parameter updates using loss computation number 5290 out of 5465 computations...
# Parameter updates using loss computation number 5291 out of 5465 computations...
# Parameter updates using loss computation number 5292 out of 5465 computations...
# Parameter updates using loss computation number 5293 out of 5465 computations...
# Parameter updates using loss computation number 5294 out of 5465 computations...
# Parameter updates using loss computation number 5295 out of 5465 computations...
# Parameter updates using loss computation number 5296 out of 5465 computations...
# Parameter updates using loss computation number 5297 out of 5465 computations...
# Parameter updates using loss computation number 5298 out of 5465 computations...
# Parameter updates using loss computation number 5299 out of 5465 computations...
# Parameter updates using loss computation number 5300 out of 5465 computations...
# Parameter updates using loss computation number 5301 out of 5465 computations...
# Parameter updates using loss computation number 5302 out of 5465 computations...
# Parameter updates using loss computation number 5303 out of 5465 computations...
# Parameter updates using loss computation number 5304 out of 5465 computations...
# Parameter updates using loss computation number 5305 out of 5465 computations...
# Parameter updates using loss computation number 5306 out of 5465 computations...
# Parameter updates using loss computation number 5307 out of 5465 computations...
# Parameter updates using loss computation number 5308 out of 5465 computations...
# Parameter updates using loss computation number 5309 out of 5465 computations...
# Parameter updates using loss computation number 5310 out of 5465 computations...
# Parameter updates using loss computation number 5311 out of 5465 computations...
# Parameter updates using loss computation number 5312 out of 5465 computations...
# Parameter updates using loss computation number 5313 out of 5465 computations...
# Parameter updates using loss computation number 5314 out of 5465 computations...
# Parameter updates using loss computation number 5315 out of 5465 computations...
# Parameter updates using loss computation number 5316 out of 5465 computations...
# Parameter updates using loss computation number 5317 out of 5465 computations...
# Parameter updates using loss computation number 5318 out of 5465 computations...
# Parameter updates using loss computation number 5319 out of 5465 computations...
# Parameter updates using loss computation number 5320 out of 5465 computations...
# Parameter updates using loss computation number 5321 out of 5465 computations...
# Parameter updates using loss computation number 5322 out of 5465 computations...
# Parameter updates using loss computation number 5323 out of 5465 computations...
# Parameter updates using loss computation number 5324 out of 5465 computations...
# Parameter updates using loss computation number 5325 out of 5465 computations...
# Parameter updates using loss computation number 5326 out of 5465 computations...
# Parameter updates using loss computation number 5327 out of 5465 computations...
# Parameter updates using loss computation number 5328 out of 5465 computations...
# Parameter updates using loss computation number 5329 out of 5465 computations...
# Parameter updates using loss computation number 5330 out of 5465 computations...
# Parameter updates using loss computation number 5331 out of 5465 computations...
# Parameter updates using loss computation number 5332 out of 5465 computations...
# Parameter updates using loss computation number 5333 out of 5465 computations...
# Parameter updates using loss computation number 5334 out of 5465 computations...
# Parameter updates using loss computation number 5335 out of 5465 computations...
# Parameter updates using loss computation number 5336 out of 5465 computations...
# Parameter updates using loss computation number 5337 out of 5465 computations...
# Parameter updates using loss computation number 5338 out of 5465 computations...
# Parameter updates using loss computation number 5339 out of 5465 computations...
# Parameter updates using loss computation number 5340 out of 5465 computations...
# Parameter updates using loss computation number 5341 out of 5465 computations...
# Parameter updates using loss computation number 5342 out of 5465 computations...
# Parameter updates using loss computation number 5343 out of 5465 computations...
# Parameter updates using loss computation number 5344 out of 5465 computations...
# Parameter updates using loss computation number 5345 out of 5465 computations...
# Parameter updates using loss computation number 5346 out of 5465 computations...
# Parameter updates using loss computation number 5347 out of 5465 computations...
# Parameter updates using loss computation number 5348 out of 5465 computations...
# Parameter updates using loss computation number 5349 out of 5465 computations...
# Parameter updates using loss computation number 5350 out of 5465 computations...
# Parameter updates using loss computation number 5351 out of 5465 computations...
# Parameter updates using loss computation number 5352 out of 5465 computations...
# Parameter updates using loss computation number 5353 out of 5465 computations...
# Parameter updates using loss computation number 5354 out of 5465 computations...
# Parameter updates using loss computation number 5355 out of 5465 computations...
# Parameter updates using loss computation number 5356 out of 5465 computations...
# Parameter updates using loss computation number 5357 out of 5465 computations...
# Parameter updates using loss computation number 5358 out of 5465 computations...
# Parameter updates using loss computation number 5359 out of 5465 computations...
# Parameter updates using loss computation number 5360 out of 5465 computations...
# Parameter updates using loss computation number 5361 out of 5465 computations...
# Parameter updates using loss computation number 5362 out of 5465 computations...
# Parameter updates using loss computation number 5363 out of 5465 computations...
# Parameter updates using loss computation number 5364 out of 5465 computations...
# Parameter updates using loss computation number 5365 out of 5465 computations...
# Parameter updates using loss computation number 5366 out of 5465 computations...
# Parameter updates using loss computation number 5367 out of 5465 computations...
# Parameter updates using loss computation number 5368 out of 5465 computations...
# Parameter updates using loss computation number 5369 out of 5465 computations...
# Parameter updates using loss computation number 5370 out of 5465 computations...
# Parameter updates using loss computation number 5371 out of 5465 computations...
# Parameter updates using loss computation number 5372 out of 5465 computations...
# Parameter updates using loss computation number 5373 out of 5465 computations...
# Parameter updates using loss computation number 5374 out of 5465 computations...
# Parameter updates using loss computation number 5375 out of 5465 computations...
# Parameter updates using loss computation number 5376 out of 5465 computations...
# Parameter updates using loss computation number 5377 out of 5465 computations...
# Parameter updates using loss computation number 5378 out of 5465 computations...
# Parameter updates using loss computation number 5379 out of 5465 computations...
# Parameter updates using loss computation number 5380 out of 5465 computations...
# Parameter updates using loss computation number 5381 out of 5465 computations...
# Parameter updates using loss computation number 5382 out of 5465 computations...
# Parameter updates using loss computation number 5383 out of 5465 computations...
# Parameter updates using loss computation number 5384 out of 5465 computations...
# Parameter updates using loss computation number 5385 out of 5465 computations...
# Parameter updates using loss computation number 5386 out of 5465 computations...
# Parameter updates using loss computation number 5387 out of 5465 computations...
# Parameter updates using loss computation number 5388 out of 5465 computations...
# Parameter updates using loss computation number 5389 out of 5465 computations...
# Parameter updates using loss computation number 5390 out of 5465 computations...
# Parameter updates using loss computation number 5391 out of 5465 computations...
# Parameter updates using loss computation number 5392 out of 5465 computations...
# Parameter updates using loss computation number 5393 out of 5465 computations...
# Parameter updates using loss computation number 5394 out of 5465 computations...
# Parameter updates using loss computation number 5395 out of 5465 computations...
# Parameter updates using loss computation number 5396 out of 5465 computations...
# Parameter updates using loss computation number 5397 out of 5465 computations...
# Parameter updates using loss computation number 5398 out of 5465 computations...
# Parameter updates using loss computation number 5399 out of 5465 computations...
# Parameter updates using loss computation number 5400 out of 5465 computations...
# Parameter updates using loss computation number 5401 out of 5465 computations...
# Parameter updates using loss computation number 5402 out of 5465 computations...
# Parameter updates using loss computation number 5403 out of 5465 computations...
# Parameter updates using loss computation number 5404 out of 5465 computations...
# Parameter updates using loss computation number 5405 out of 5465 computations...
# Parameter updates using loss computation number 5406 out of 5465 computations...
# Parameter updates using loss computation number 5407 out of 5465 computations...
# Parameter updates using loss computation number 5408 out of 5465 computations...
# Parameter updates using loss computation number 5409 out of 5465 computations...
# Parameter updates using loss computation number 5410 out of 5465 computations...
# Parameter updates using loss computation number 5411 out of 5465 computations...
# Parameter updates using loss computation number 5412 out of 5465 computations...
# Parameter updates using loss computation number 5413 out of 5465 computations...
# Parameter updates using loss computation number 5414 out of 5465 computations...
# Parameter updates using loss computation number 5415 out of 5465 computations...
# Parameter updates using loss computation number 5416 out of 5465 computations...
# Parameter updates using loss computation number 5417 out of 5465 computations...
# Parameter updates using loss computation number 5418 out of 5465 computations...
# Parameter updates using loss computation number 5419 out of 5465 computations...
# Parameter updates using loss computation number 5420 out of 5465 computations...
# Parameter updates using loss computation number 5421 out of 5465 computations...
# Parameter updates using loss computation number 5422 out of 5465 computations...
# Parameter updates using loss computation number 5423 out of 5465 computations...
# Parameter updates using loss computation number 5424 out of 5465 computations...
# Parameter updates using loss computation number 5425 out of 5465 computations...
# Parameter updates using loss computation number 5426 out of 5465 computations...
# Parameter updates using loss computation number 5427 out of 5465 computations...
# Parameter updates using loss computation number 5428 out of 5465 computations...
# Parameter updates using loss computation number 5429 out of 5465 computations...
# Parameter updates using loss computation number 5430 out of 5465 computations...
# Parameter updates using loss computation number 5431 out of 5465 computations...
# Parameter updates using loss computation number 5432 out of 5465 computations...
# Parameter updates using loss computation number 5433 out of 5465 computations...
# Parameter updates using loss computation number 5434 out of 5465 computations...
# Parameter updates using loss computation number 5435 out of 5465 computations...
# Parameter updates using loss computation number 5436 out of 5465 computations...
# Parameter updates using loss computation number 5437 out of 5465 computations...
# Parameter updates using loss computation number 5438 out of 5465 computations...
# Parameter updates using loss computation number 5439 out of 5465 computations...
# Parameter updates using loss computation number 5440 out of 5465 computations...
# Parameter updates using loss computation number 5441 out of 5465 computations...
# Parameter updates using loss computation number 5442 out of 5465 computations...
# Parameter updates using loss computation number 5443 out of 5465 computations...
# Parameter updates using loss computation number 5444 out of 5465 computations...
# Parameter updates using loss computation number 5445 out of 5465 computations...
# Parameter updates using loss computation number 5446 out of 5465 computations...
# Parameter updates using loss computation number 5447 out of 5465 computations...
# Parameter updates using loss computation number 5448 out of 5465 computations...
# Parameter updates using loss computation number 5449 out of 5465 computations...
# Parameter updates using loss computation number 5450 out of 5465 computations...
# Parameter updates using loss computation number 5451 out of 5465 computations...
# Parameter updates using loss computation number 5452 out of 5465 computations...
# Parameter updates using loss computation number 5453 out of 5465 computations...
# Parameter updates using loss computation number 5454 out of 5465 computations...
# Parameter updates using loss computation number 5455 out of 5465 computations...
# Parameter updates using loss computation number 5456 out of 5465 computations...
# Parameter updates using loss computation number 5457 out of 5465 computations...
# Parameter updates using loss computation number 5458 out of 5465 computations...
# Parameter updates using loss computation number 5459 out of 5465 computations...
# Parameter updates using loss computation number 5460 out of 5465 computations...
# Parameter updates using loss computation number 5461 out of 5465 computations...
# Parameter updates using loss computation number 5462 out of 5465 computations...
# Parameter updates using loss computation number 5463 out of 5465 computations...
# Parameter updates using loss computation number 5464 out of 5465 computations...
# Parameter updates using loss computation number 5465 out of 5465 computations...

# %% [markdown]
# # Part 3 - Generating Images
# In this section, we will generate some new images using the generator component of the GAN.

# %%
# Choose a number of new images to generate
n_new = 25

# %%
# Generate some new images using the generator
noise = tf.random.normal([n_new, latent_dim])
generated_images = generator(noise, training = False)

# Rescale the image gray levels to [0, 1]
generated_images = 0.5 * generated_images + 0.5

plt.figure(figsize = (5, 5))

for i in range(n_new):
    plt.subplot(int(np.sqrt(n_new)), int(np.sqrt(n_new)), i + 1)
    plt.imshow(generated_images[i, :, :, 0], cmap = 'gray')

plt.axis('off')
plt.show()
