# %%
# !pip install sentence-transformers

# %%
import pandas as pd
import sentence_transformers
from sentence_transformers import SentenceTransformer, util

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
input_path = '/content/drive/My Drive/HelpMate AI Codes/HelpMate Practice Question/'. # Update as per your path

# %%
job_postings = pd.read_csv(input_path + 'job_postings.csv')

# %%
job_postings
# Out:
#                                    title  \
# 0               Licensed Insurance Agent
# 1                          Sales Manager
# 2                     Model Risk Auditor
# 3                       Business Manager
# 4                    NY Studio Assistant
# ..                                   ...
# 495     Electrical Engineer - P&C Design
# 496                               Editor
# 497           Spiritual Care Coordinator
# 498                  Supply Chain Intern
# 499  Automotive Lead Quality Coordinator
#
#                                            description           location  \
# 0    While many industries were hurt by the last fe...          Chico, CA
# 1    Are you a dynamic and creative marketing profe...  Santa Clarita, CA
# 2    Join Us as a Model Risk Auditor – Showcase You...       New York, NY
# 3    Business ManagerFirst Baptist Church ForneyFor...         Forney, TX
# 4    YOU COULD BE ONE OF THE MAGIC MAKERS\nKen Fulk...       New York, NY
# ..                                                 ...                ...
# 495  Job Description:Role: Electrical Engineer - P&...      United States
# 496  Role : Editor Remote Description: The Spotify ...       New York, NY
# 497  Coordinates spiritual, emotional and psycholog...        Fremont, OH
# 498  Learn and assist with all activities associate...     Fort Wayne, IN
# 499  Job DetailsDivision: Nucor Steel BerkeleyLocat...          Huger, SC
#
#       work_type
# 0     FULL_TIME
# 1     FULL_TIME
# 2      CONTRACT
# 3     FULL_TIME
# 4     FULL_TIME
# ..          ...
# 495   FULL_TIME
# 496    CONTRACT
# 497   FULL_TIME
# 498  INTERNSHIP
# 499   FULL_TIME
#
# [500 rows x 4 columns]

# %%
# Load the embedding model

MiniLM_model_name = "all-MiniLM-L6-v2"
MiniLM_model = SentenceTransformer(MiniLM_model_name)

# %%
# Load the embedding model

QA_model_name = "multi-qa-MiniLM-L6-cos-v1"
QA_model = SentenceTransformer(QA_model_name)

# %%
# Function to generate embeddings for text.

def generate_embeddings(model, texts):
    embeddings = model.encode(texts, convert_to_tensor=True)
    return embeddings

# %%
# Call the function to generate embeddings. It will take upto 5 minutes to embed all 500 entries in the dataset.

job_postings['Embeddings_MiniLM'] = job_postings['description'].apply(lambda x: generate_embeddings(MiniLM_model, [x])[0])
job_postings['Embeddings_QA'] = job_postings['description'].apply(lambda x: generate_embeddings(QA_model, [x])[0])

# %%
job_postings
# Out:
#                                    title  \
# 0               Licensed Insurance Agent
# 1                          Sales Manager
# 2                     Model Risk Auditor
# 3                       Business Manager
# 4                    NY Studio Assistant
# ..                                   ...
# 495     Electrical Engineer - P&C Design
# 496                               Editor
# 497           Spiritual Care Coordinator
# 498                  Supply Chain Intern
# 499  Automotive Lead Quality Coordinator
#
#                                            description           location  \
# 0    While many industries were hurt by the last fe...          Chico, CA
# 1    Are you a dynamic and creative marketing profe...  Santa Clarita, CA
# 2    Join Us as a Model Risk Auditor – Showcase You...       New York, NY
# 3    Business ManagerFirst Baptist Church ForneyFor...         Forney, TX
# 4    YOU COULD BE ONE OF THE MAGIC MAKERS\nKen Fulk...       New York, NY
# ..                                                 ...                ...
# 495  Job Description:Role: Electrical Engineer - P&...      United States
# 496  Role : Editor Remote Description: The Spotify ...       New York, NY
# 497  Coordinates spiritual, emotional and psycholog...        Fremont, OH
# 498  Learn and assist with all activities associate...     Fort Wayne, IN
# 499  Job DetailsDivision: Nucor Steel BerkeleyLocat...          Huger, SC
#
#       work_type                                  Embeddings_MiniLM  \
# 0     FULL_TIME  [tensor(-0.0357), tensor(0.0185), tensor(-0.08...
# 1     FULL_TIME  [tensor(0.0146), tensor(-0.0772), tensor(0.003...
# 2      CONTRACT  [tensor(0.0594), tensor(-0.0626), tensor(-0.05...
# 3     FULL_TIME  [tensor(0.0161), tensor(0.0097), tensor(0.0055...
# 4     FULL_TIME  [tensor(0.0196), tensor(-0.1300), tensor(0.058...
# ..          ...                                                ...
# 495   FULL_TIME  [tensor(0.0284), tensor(0.0051), tensor(0.0042...
# 496    CONTRACT  [tensor(0.0469), tensor(-0.1052), tensor(-0.02...
# 497   FULL_TIME  [tensor(0.0375), tensor(-0.0017), tensor(-0.03...
# 498  INTERNSHIP  [tensor(-0.0180), tensor(0.0153), tensor(0.005...
# 499   FULL_TIME  [tensor(-0.0713), tensor(-0.0609), tensor(-0.0...
#
#                                          Embeddings_QA
# 0    [tensor(0.0241), tensor(0.0494), tensor(-0.033...
# 1    [tensor(0.0172), tensor(-0.0164), tensor(0.008...
# 2    [tensor(0.0255), tensor(-0.0302), tensor(-0.08...
# 3    [tensor(0.0107), tensor(0.0243), tensor(-0.029...
# 4    [tensor(0.0156), tensor(-0.0645), tensor(0.006...
# ..                                                 ...
# 495  [tensor(-0.0445), tensor(0.0474), tensor(0.048...
# 496  [tensor(0.0431), tensor(-0.0604), tensor(0.051...
# 497  [tensor(0.0759), tensor(0.0399), tensor(-0.082...
# 498  [tensor(0.0025), tensor(0.0193), tensor(-0.033...
# 499  [tensor(0.0031), tensor(-0.0021), tensor(-0.02...
#
# [500 rows x 6 columns]

# %%
# query_1 = I am looking for a data engineer job that offers competitive pay
# query_2 = I want to work in UI design in the gaming industry

# %%
query1 = input()
# Out:
# I am looking for a data engineer job that offers competitive pay

# %%
query2 = input()
# Out:
# I want to work in UI design in the gaming industry

# %%
# Define the function for calculating cosine similarity

def calculate_similarity(embedding1, embedding2):
    cosine_score = util.pytorch_cos_sim(embedding1, embedding2)
    # Convert the result to a Python float
    similarity = cosine_score.item()

    return similarity

# %%
# Calculate the query embedding for query1
query_embedding_miniLM_1 = MiniLM_model.encode(query1, convert_to_tensor=True)
query_embedding_QA_1 = QA_model.encode(query1, convert_to_tensor=True)


# Calculate the query embedding for query2
query_embedding_miniLM_2 = MiniLM_model.encode(query2, convert_to_tensor=True)
query_embedding_QA_2 = QA_model.encode(query2, convert_to_tensor=True)

# %%
# Calculate similarity scores between the query embedding and all chunk embeddings for query1
job_postings['Similarity_1_miniLM'] = job_postings['Embeddings_MiniLM'].apply(lambda x: calculate_similarity(query_embedding_miniLM_1, x))
job_postings['Similarity_1_QA'] = job_postings['Embeddings_QA'].apply(lambda x: calculate_similarity(query_embedding_QA_1, x))


# Calculate similarity scores between the query embedding and all chunk embeddings for query2
job_postings['Similarity_2_miniLM'] = job_postings['Embeddings_MiniLM'].apply(lambda x: calculate_similarity(query_embedding_miniLM_2, x))
job_postings['Similarity_2_QA'] = job_postings['Embeddings_QA'].apply(lambda x: calculate_similarity(query_embedding_QA_2, x))

# %%
# Extract top 3 results for query1 for both models

top_3_MiniLM_query1 = job_postings.sort_values(by='Similarity_1_miniLM', ascending=False)[:3]
top_3_QA_query1 = job_postings.sort_values(by='Similarity_1_QA', ascending=False)[:3]

# %%
# Extract top 3 results for query2 for both models

top_3_MiniLM_query2 = job_postings.sort_values(by='Similarity_2_miniLM', ascending=False)[:3]
top_3_QA_query2 = job_postings.sort_values(by='Similarity_2_QA', ascending=False)[:3]

# %%
top_3_MiniLM_query1
# Out:
#                     title                                        description  \
# 266         Data Engineer  Job Description:\n• Design, develop, and launc...
# 396   Azure Data Engineer  Need Genuine candidates who has solid experien...
# 440  Senior Data Engineer  Combine your technical expertise and problem-s...
#
#                     location  work_type  \
# 266            United States   CONTRACT
# 396            United States   CONTRACT
# 440  Virginia, United States  FULL_TIME
#
#                                      Embeddings_MiniLM  \
# 266  [tensor(-0.0304), tensor(0.0321), tensor(0.022...
# 396  [tensor(-0.0148), tensor(-0.0782), tensor(0.02...
# 440  [tensor(-0.0201), tensor(0.0069), tensor(-0.01...
#
#                                          Embeddings_QA  Similarity_1_miniLM  \
# 266  [tensor(-0.0350), tensor(0.0405), tensor(0.041...             0.529741
# 396  [tensor(0.0092), tensor(-0.0536), tensor(-0.00...             0.478422
# 440  [tensor(-0.0178), tensor(0.0046), tensor(0.000...             0.449332
#
#      Similarity_1_QA  Similarity_2_miniLM  Similarity_2_QA
# 266         0.543093             0.175004         0.205815
# 396         0.387438             0.299140         0.203843
# 440         0.342863             0.210983         0.186412

# %%
top_3_QA_query1
# Out:
#                                title  \
# 266                    Data Engineer
# 292  Data Scientist/ Product Analyst
# 287      Assistant to Sales Director
#
#                                            description           location  \
# 266  Job Description:\n• Design, develop, and launc...      United States
# 292  Looking for candidates with 4+ years’ experien...  San Francisco, CA
# 287  Please send resume with salary requirements an...        Chicago, IL
#
#      work_type                                  Embeddings_MiniLM  \
# 266   CONTRACT  [tensor(-0.0304), tensor(0.0321), tensor(0.022...
# 292   CONTRACT  [tensor(0.0009), tensor(-0.0532), tensor(0.044...
# 287  FULL_TIME  [tensor(-0.1007), tensor(-0.0512), tensor(-0.0...
#
#                                          Embeddings_QA  Similarity_1_miniLM  \
# 266  [tensor(-0.0350), tensor(0.0405), tensor(0.041...             0.529741
# 292  [tensor(0.0243), tensor(0.0120), tensor(0.0096...             0.309458
# 287  [tensor(-0.0475), tensor(-0.0001), tensor(0.00...             0.215967
#
#      Similarity_1_QA  Similarity_2_miniLM  Similarity_2_QA
# 266         0.543093             0.175004         0.205815
# 292         0.462681             0.116504         0.295949
# 287         0.416805             0.243621         0.256875

# %%
top_3_MiniLM_query2
# Out:
#                                                  title  \
# 126  UX Designer/Architect-Plano TX and Columbus OH...
# 307               Software Engineer- Graphics Designer
# 4                                  NY Studio Assistant
#
#                                            description       location  \
# 126  Our client is looking for UX Designer.\nLocati...      Plano, TX
# 307  Job Description\nExperience with C/C++ program...  United States
# 4    YOU COULD BE ONE OF THE MAGIC MAKERS\nKen Fulk...   New York, NY
#
#      work_type                                  Embeddings_MiniLM  \
# 126   CONTRACT  [tensor(0.0440), tensor(0.0145), tensor(0.0494...
# 307  FULL_TIME  [tensor(-0.1053), tensor(0.0162), tensor(0.020...
# 4    FULL_TIME  [tensor(0.0196), tensor(-0.1300), tensor(0.058...
#
#                                          Embeddings_QA  Similarity_1_miniLM  \
# 126  [tensor(0.0026), tensor(0.0201), tensor(0.0548...             0.317580
# 307  [tensor(-0.0668), tensor(-0.0321), tensor(-0.0...             0.373739
# 4    [tensor(0.0156), tensor(-0.0645), tensor(0.006...             0.253242
#
#      Similarity_1_QA  Similarity_2_miniLM  Similarity_2_QA
# 126         0.327876             0.472885         0.422205
# 307         0.296570             0.412720         0.389942
# 4           0.296694             0.398065         0.369122

# %%
top_3_QA_query2
# Out:
#                                        title  \
# 438                       Lead Game Designer
# 327  Head of Visual Design Operating Systems
# 267                          Sr. AV Designer
#
#                                            description              location  \
# 438  Position: Lead Game DesignerLocation: Remote W...         United States
# 327  STEALTH GAMING OPERATING SYSTEM. \nWe are a ve...         United States
# 267  ABOUT THE POSITION\nAs a Senior AV Designer, y...  West Valley City, UT
#
#      work_type                                  Embeddings_MiniLM  \
# 438  FULL_TIME  [tensor(0.0055), tensor(-0.0065), tensor(-0.02...
# 327  FULL_TIME  [tensor(-0.0058), tensor(-0.0010), tensor(-0.0...
# 267  FULL_TIME  [tensor(-0.0371), tensor(0.0614), tensor(-0.02...
#
#                                          Embeddings_QA  Similarity_1_miniLM  \
# 438  [tensor(-0.0034), tensor(0.0232), tensor(-0.03...             0.134383
# 327  [tensor(-0.0337), tensor(-0.0295), tensor(0.03...             0.198510
# 267  [tensor(0.0251), tensor(0.0615), tensor(-0.028...             0.243018
#
#      Similarity_1_QA  Similarity_2_miniLM  Similarity_2_QA
# 438         0.265356             0.395483         0.532436
# 327         0.224083             0.366534         0.519794
# 267         0.256798             0.396645         0.432892
