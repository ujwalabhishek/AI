# %% [markdown]
# <div class="MuiBox-root css-lrle2m-container" data-testid="online-editor-player"><div class="text_component" data-testid="online-editor-content"><p>Welcome to the project!</p><p>First and foremost, congratulations on completing the foundational stages of ShopAssist AI! We hope this course was a rich learning experience for you. It is time to elevate your skills and take ShopAssist AI to the next level.</p><p>Before we dive into the next milestone, let's take a moment to reflect on the primary learning objectives you've mastered during the previous modules. These objectives include:</p><ul><li><strong>Understanding System Design:</strong> You have gained a strong foundation in comprehending conversational AI systems' architecture and design principles. This knowledge includes breaking down the system into distinct stages, effectively organising the workflow, and recognising the significance of a structured approach.</li><li><strong>Manage Conversational Flow:</strong> You have learnt to proficiently initiate, steer, and manage conversations with users, regardless of the context or domain. You have also acquired the skills to utilise essential different functions to drive the behaviour of Large Language Models (LLMs) for seamless interactions.</li><li><strong>Ensure Output Consistency:</strong> You have explored techniques for maintaining consistency &amp; standardised formats in chatbot responses, ensuring uniformity and clarity.</li><li><strong>Implement Safety Measures:</strong> You have learnt how to effectively implement moderation layers to identify and handle conversations containing potentially unsafe or sensitive content.&nbsp;</li><li><strong>Leverage Few-Shot and Chain-of-Thought Prompting:</strong> You have applied few-shot examples and chain-of-thought reasoning to provide LLM context and direction, leading to improved chatbot performance.</li></ul><h2><br>What's next?</h2><p><br>While ShopAssist AI is a robust system, there's always room for improvement. A notable challenge we've encountered is the complexity of managing multiple layers and components to achieve seamless and efficient interactions between the chatbot and users.</p><p>With this in mind, we introduce you to this project, offering you the opportunity to enhance the customer experience by crafting a more sophisticated and intelligent chatbot.</p><p>In ShopAssist AI, your chatbot demonstrated the capability to:</p><ul><li>Seamlessly interact with users to discern their intent and requirements.</li><li>Extract relevant information from the database based on user intent.</li><li>Present tailored recommendations to users.</li></ul><p>However, it's important to note that LLMs inherently struggle to generate standardised output consistently. You may have noticed this while constructing the intent clarity layer, which required multiple layers to ensure that the output adhered to standard formats before invoking functions for database information extraction.</p><p>This resembles a 'hacky' approach, making a robust system cumbersome. Fortunately, OpenAI, the creator behind ChatGPT, has introduced an exciting innovation called 'function calling' within their GPT models. This enhancement simplifies the development of chatbots capable of interfacing with external tools and APIs, opening up a realm of innovative AI applications.</p><p>Hence, we present this project, where you have multiple opportunities to enhance the customer experience by crafting a superior and more intelligent chatbot. In the next segment, you will understand the details of this project in detail.</p></div></div>

# %% [markdown]
# <div class="MuiBox-root css-lrle2m-container" data-testid="online-editor-player"><div class="text_component" data-testid="online-editor-content"><p>In this segment, we present you with two exciting project options to choose from. These options provide diverse opportunities to apply your newfound skills and creativity, ensuring a rewarding learning experience. Whether you wish to craft your custom AI project or enhance ShopAssist AI to the next level, both avenues promise valuable insights and contributions to conversational AI. Let's explore these options in detail:</p><h2><br>Option 1: Build Your Own Project (BYOP)</h2><p>In the "Build Your Own Project" option, you can conceive, design, and implement your own AI-driven project. This is an exciting opportunity to explore your passion for AI and create a chatbot that can impact any domain you choose. Here are some project ideas to spark your imagination:</p><ul><li><strong>Travel Planner AI:&nbsp;</strong>Develop a chatbot that assists travellers in planning their trips. It can recommend top hotels and suggest itineraries based on user-specified destinations.</li><li><strong>Restaurant Recommender AI:</strong> Create a chatbot that helps users find the perfect restaurant for any occasion. It can consider factors like cuisine preferences, dietary restrictions, location, and user reviews to make tailored recommendations.</li></ul><p>As you work on your custom project, remember to document your progress meticulously. Create comprehensive documentation that outlines your project's goals, the AI model used, data sources, key design decisions, and any challenges you encountered.</p><p><br><em>NOTE: Remember, you can source data for your project from publicly available datasets from platforms like Kaggle or even collect data yourself. The key is choosing a project that aligns with your interests and objectives and has a meaningful application in the real world.</em></p><h2>Option 2: Enhance ShopAssist AI (ShopAssist 2.0)</h2><p>If you prefer a structured project with a clear starting point, you can enhance ShopAssist AI, taking it to the next level as ShopAssist 2.0. In this option, you will leverage the newly introduced 'function calling' feature to create a more streamlined and efficient chatbot. Here are the tasks involved:</p><ul><li><strong>Integrate Function Calling API:</strong> Modify the existing architecture to leverage the Function Calling API's capabilities for improved performance. Scope out which layers can be removed and how the existing layers can be updated to handle the new approach.</li><li><strong>Refine Conversation Flow:&nbsp;</strong>Enhance the chatbot's conversation flow by leveraging function calling. Make the interaction between the user and the chatbot more natural and dynamic.</li><li><strong>Document and Present:</strong> Create comprehensive documentation that outlines the changes made, the integration process, and the benefits of using the Function Calling API. Prepare a presentation to showcase the enhancements.</li></ul><p>Both options offer exciting opportunities to apply your AI skills and creativity. Whether you build your own project or enhance ShopAssist AI, you'll gain valuable experience in conversational AI and contribute to the development of innovative AI solutions.</p><p>In the next segment, you will learn about the Function Calling API and understand how it can transform your chatbot into more efficient, adaptable and user-centric.</p></div></div>

# %% [markdown]
# <div class="MuiBox-root css-lrle2m-container" data-testid="online-editor-player"><div class="text_component" data-testid="online-editor-content"><p>Imagine creating an AI assistant capable of understanding commands like <strong><em>'Find me the nearest Thai restaurant and add the reservation to my calendar.'</em></strong> As language models are evolving, they are breaking new ground. OpenAI, the creator of ChatGPT, has introduced an exciting innovation called 'function calling' within their GPT models. This enhancement streamlines the development of chatbots that can interact with external tools and APIs, opening doors to innovative AI applications.</p><p><br></p><h2>What is Function Calling?</h2><p>Function calling is a new capability in OpenAI's GPT-4-0613 and GPT-3.5 Turbo-0613 models. Instead of just generating plain text responses, these AI models are now equipped to recognise situations where they must interact with external systems. Function calling allows the AI to trigger specific functions based on the input of the user.&nbsp;</p><p>For instance, if a user instructs, <strong><em>'Find me the best hotel deals for a weekend trip'</em></strong>, the AI can initiate a function that interacts with hotel booking APIs to fetch relevant information. Similarly, the AI can activate a currency conversion function if a user requests, <em><strong>'Convert 100 USD to INR'.</strong></em> This capability to seamlessly interface with external tools represents a significant advancement beyond conventional use cases.</p><p><br></p><p style="text-align: center;"><br></p><p style="text-align: center;"><img src="https://d35ev2v1xsdze0.cloudfront.net/127763c3-68d4-40db-8e93-d553f837b87b-pr1.png" style="width: 636px;" class="fr-fic fr-dib" size="257092"></p><p><br></p><p><br></p><p>For example, the large language model (LLM) above uses two functions to get the required information the user asks. This involves the use of a web search plugin to locate pertinent documents. Once the relevant URLs are pinpointed, the LLM employs an HTML scraping plugin to extract the needed information from those web pages.</p><p><br></p><h2>How to Use Function Calling</h2><p><br>This feature allows developers to seamlessly integrate functions into their interactions with the model. Developers can describe processes within prompts, prompting the model to output a JSON object containing arguments. This JSON can then be used to call those functions in the code. It is important to note that the Chat Completions API does not directly execute functions but instead generates the required JSON for facilitating function calls.</p><p><br>Function calling unleashes a range of practical scenarios, including:</p><ul><li><strong>Empowering chatbots with external APIs:</strong> Developers can create chatbots that tap into external APIs. By defining functions, chatbots can provide answers and insights sourced from various services. For instance, functions like send_email(to string, body: string) or get_current_weather(location: string, unit: 'Celsius' | 'Fahrenheit') can be set up to send emails or fetch weather data, respectively.</li><li><strong>Translating natural language to API commands:</strong> ChatGPT can convert user-friendly questions into API commands. By establishing suitable functions and using context, developers can transform queries like 'Who are my top customers?' into API requests such as get_customers(min_revenue: int, created_before: string, limit: int). This way, the AI fetches customer data from an internal API effortlessly.</li><li><strong>Extracting structured information from text:</strong> Developers can define functions that extract structured insights from unstructured text. For instance, functions like extract_data(name: string, birthday: string) or SQL_query (query: string) can dissect and extract specific details from text inputs. This is incredibly useful for transforming raw data into organised and usable information.</li></ul><h2><br>The Functions Parameter</h2><p><br>The Functions Parameter is a key component of this new feature. It adds a layer of sophistication to the API.<br>Each function in the list comes with a name, description and parameters.&nbsp;</p><p>The name and description provide insights into the purpose of the function, while the parameters field defines the required input. To ensure accurate function calls, these parameters must be described using the JSON schema specification.</p><p>The Function Call API Parameter adds another layer of flexibility. It can take one of the following three values:</p><ul><li><strong>none:</strong> If you do not want the model to generate a function call, set function_call to 'none'. This is the default if you do not provide any functions.</li><li><strong>auto:&nbsp;</strong>This allows the model to decide whether to generate a function call. If multiple functions are provided, it selects the most suitable one. This is the default when functions are provided.</li><li><strong>function name:&nbsp;</strong>You can also specify the name of a specific function, like {"name": "square"} if you want the model to generate a call to that function.</li></ul><p>In essence, the introduction of function calling transforms AI interactions from mere text exchanges to dynamic interactions with the outside world, paving the way for more sophisticated and versatile AI applications.</p><p>In essence, the introduction of function calling transforms AI interactions from mere text exchanges to dynamic interactions with the outside world, paving the way for more sophisticated and versatile AI applications.</p><p><br><strong>Use Case: Virtual Travel Planner</strong><br>Imagine you are crafting a virtual travel planner – an AI-powered assistant that helps users plan their dream vacations. To bring this concept to life, you are utilising the cutting-edge technology of OpenAI, including a fascinating new feature known as function calling.</p><p>In your virtual travel planner project, you want users to interact with the assistant to create detailed travel itineraries. Let's delve into how function calling works in this context.</p><p>You implement a function named 'findBestHotels' that helps users discover the best five hotels for their vacation destinations. Here is what a function call could look like for this purpose:</p><p><br></p><div data-lang="python"><div contenteditable="false"><pre style="margin: 0; line-height: 125%;">{
#     <span style="background-color: #fff0f0;">"name"</span>: <span style="background-color: #fff0f0;">"findBestHotels"</span>,
#     <span style="background-color: #fff0f0;">"description"</span>: <span style="background-color: #fff0f0;">"Find the best 5 hotels for a given destination"</span>,
#     <span style="background-color: #fff0f0;">"parameters"</span>: {
#         <span style="background-color: #fff0f0;">"type"</span>: <span style="background-color: #fff0f0;">"object"</span>,
#         <span style="background-color: #fff0f0;">"properties"</span>: {
#             <span style="background-color: #fff0f0;">"destination"</span>: {
#                 <span style="background-color: #fff0f0;">"type"</span>: <span style="background-color: #fff0f0;">"string"</span>,
#                 <span style="background-color: #fff0f0;">"description"</span>: <span style="background-color: #fff0f0;">"The desired travel destination"</span>
#             }
#         }
#     }
# }</pre></div></div><p><br></p><p>Imagine a user sends a prompt like 'Help me find the perfect hotel in Paris'. In response, the AI might provide a structured function call request:</p><p><br></p><div data-lang="python"><div contenteditable="false"><pre style="margin: 0; line-height: 125%;">{
# &nbsp;&nbsp;&nbsp;&nbsp;<span style="background-color: #fff0f0;">'index'</span>: <span style="color: #0000DD; font-weight: bold;">0</span>,
# &nbsp;&nbsp;&nbsp;&nbsp;<span style="background-color: #fff0f0;">'message'</span>: {
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<span style="background-color: #fff0f0;">'role'</span>: <span style="background-color: #fff0f0;">'assistant'</span>,
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<span style="background-color: #fff0f0;">'content'</span>: <span style="color: #008800; font-weight: bold;">None</span>,
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<span style="background-color: #fff0f0;">'function_call'</span>: {
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<span style="background-color: #fff0f0;">'name'</span>: <span style="background-color: #fff0f0;">'findBestHotels'</span>,
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<span style="background-color: #fff0f0;">'arguments'</span>: <span style="background-color: #fff0f0;">'{</span><span style="color: #666666; font-weight: bold; background-color: #fff0f0;">\n</span><span style="background-color: #fff0f0;">  "destination": "Paris"}'</span>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;}
# &nbsp;&nbsp;&nbsp;&nbsp;},
# &nbsp;&nbsp;&nbsp;&nbsp;<span style="background-color: #fff0f0;">'finish_reason'</span>: <span style="background-color: #fff0f0;">'function_call'</span>
# }</pre></div></div><p><br></p><p>When the AI generates a function call response, it includes a 'function_call' field containing the name of the function and the arguments required for the call. By checking this field in the response, you can identify when the AI is making a function call.</p><p>Should the AI decide not to make a function call, the 'function_call' field will be absent in the response. Instead, the AI's response will be found in the 'content' field, as seen in the previous modules.</p><p>In your virtual travel planner, this function calling mechanism opens up a world of possibilities. Users can seamlessly interact with your AI assistant to explore destinations, find accommodations, plan activities and more. This feature empowers the AI to tap into external tools and APIs, providing users with a comprehensive and personalised travel planning experience.</p><h2><br>Conclusion</h2><p><br>The Function Calling API opens up a world of possibilities for AI applications. It enables chatbots and AI models to seamlessly interact with external tools and systems, expanding their capabilities substantially. As you embark on this journey to explore and utilise the Function Calling API, you will discover new ways to create intelligent and versatile AI applications.</p><p><br></p><h2>Additional Resources</h2><ul><li><a data-cke-saved-href="https://www.youtube.com/watch?v=FhKoj4opgeY" href="https://www.youtube.com/watch?v=FhKoj4opgeY" target="_blank">Link 1</a></li><li><a data-cke-saved-href="https://platform.openai.com/docs/guides/gpt/function-calling" href="https://platform.openai.com/docs/guides/gpt/function-calling" target="_blank">OpenAI Documentation</a>&nbsp;</li></ul></div></div>

# %% [markdown]
# # Evaluation Criteria
#
# <div class="MuiBox-root css-lrle2m-container" data-testid="online-editor-player"><div class="text_component" data-testid="online-editor-content"><p>Now that you are familiar with different project options and function calling API, in the next session, you will understand the evaluation criteria and submission for this project.</p><p><br>As we delve into the next phase of your AI journey, it's crucial to outline the evaluation criteria that will guide the assessment of your projects. Whether you build your own project (BYOP) or enhance ShopAssist AI (ShopAssist 2.0), these criteria provide a fair and comprehensive assessment framework for your endeavours.<br><br></p><ul><li>Option 1</li></ul><table align="center" border="1" cellpadding="1" cellspacing="1" style="width: 708px;"><tbody><tr><td style="text-align: center; width: 144px;"><strong>Criteria</strong></td><td style="text-align: center; width: 80px;"><strong>Weight</strong></td><td style="text-align: center; width: 482px;"><strong>Build Your Own Project (BYOP)</strong></td></tr><tr><td style="width: 144px;"><p style="text-align: center;">System Design</p></td><td style="text-align: center; width: 80px;">30%</td><td style="text-align: center; width: 482px;">- Innovation and creativity in system design.<br>- Evaluation of the chatbot's architecture, workflow, and uniqueness in addressing real-world problems.<br><br></td></tr><tr><td style="width: 144px;"><p style="text-align: center;">Technical Implementation</p></td><td style="text-align: center; width: 80px;">40%</td><td style="text-align: center; width: 482px;">- Quality of AI model.<br>- Efficiency of code.<br>- Effective interaction with external tools or APIs.<br><br></td></tr><tr><td style="width: 144px;"><p style="text-align: center;">User Experience</p></td><td style="text-align: center; width: 80px;">15%</td><td style="text-align: center; width: 482px;">- Evaluation of user-friendliness.<br>- Examination of how seamlessly users can interact with your chatbot and the clarity of responses.<br><br></td></tr><tr><td style="width: 144px;"><p style="text-align: center;">Documentation</p></td><td style="text-align: center; width: 80px;">15%</td><td style="text-align: center; width: 482px;">Comprehensive documentation detailing project goals, data sources, design choices, and challenges faced.</td></tr></tbody></table><p><br></p><ul><li>Option 2</li></ul><table align="center" border="1" cellpadding="1" cellspacing="1" style="width: 711px;"><tbody><tr><td style="text-align: center; width: 140px;"><strong>Criteria</strong></td><td style="text-align: center; width: 86px;"><strong>Weight</strong></td><td style="text-align: center; width: 482px;"><strong>ShopAssist AI 2.0</strong></td></tr><tr><td style="width: 140px;"><p style="text-align: center;">System Design</p></td><td style="text-align: center; width: 86px;">30%</td><td style="width: 482px;"><p style="text-align: center;">- Demonstrate creativity in integrating the Function Calling API<br>- Effective modification of the existing architecture to accommodate new features and enhance interaction flow.</p></td></tr><tr><td style="width: 140px;"><p style="text-align: center;">Technical Implementation</p></td><td style="text-align: center; width: 86px;">40%</td><td style="text-align: center; width: 482px;">- Focus on integrating the Function Calling API.<br>- Evaluation of how well you adapt the existing architecture, handle function calls, and maintain overall technical integrity.<br><br></td></tr><tr><td style="width: 140px;"><p style="text-align: center;">User Experience</p></td><td style="text-align: center; width: 86px;">15%</td><td style="text-align: center; width: 482px;">- Enhancements made through the Function Calling API should enhance user experience.<br>- Consider how well the chatbot adapts to user input and provides relevant responses.<br><br></td></tr><tr><td style="width: 140px;"><p style="text-align: center;">Documentation</p></td><td style="text-align: center; width: 86px;">15%</td><td style="text-align: center; width: 482px;">- Effective documentation outlining changes, Function Calling API integration, and the benefits derived from the enhancements.</td></tr></tbody></table></div></div>
