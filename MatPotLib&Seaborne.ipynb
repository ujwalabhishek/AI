# %% [markdown]
# # Statistics

# %% [markdown]
# https://chatgpt.com/c/6832ceec-9d78-8002-8222-2475aff1f687
#
# **Mean** - Average
#
# **Median** - Middle
#
# **Mode** - Most Frequent
#
# ![image.png](attachment:699dd0cc-8214-428d-994e-4f4fc857d060.png)
#
# ![image.png](attachment:7b45f912-ba5c-461d-aa5b-3cc2041ae492.png)
#
# ![image.png](attachment:35d0eba3-9805-4873-8236-5e0dfa0f97fe.png)
#
# ![image.png](attachment:c451853b-32e8-4ade-909d-ec060854afd4.png)
#
#
# 📌 What is Standard Deviation?
# Standard Deviation is a measure of spread — it tells you how much the values in a dataset vary from the mean (average).
#
# A low standard deviation means the data points are close to the mean.
#
# A high standard deviation means the data points are spread out over a wide range.
#
# ![image.png](attachment:1841fc10-c08e-43f6-9d06-99eb08a82702.png)
#
#
# ![image.png](attachment:202ee070-1e65-4a1d-8597-868b4588d01e.png)

# %% [markdown]
# ### Percentile
#
# A percentile tells you how a particular value compares to the rest of the data.
#
# If you are at the 90th percentile, it means you scored better than 90% of the data.
#
# Simple Example:
#
# Let’s say we have a list of exam scores:
#  > scores = [40, 50, 60, 70, 80, 90, 100]
# >
# If you're told that your score is at the 70th percentile, it means:
#
# 👉 Your score is higher than 70% of the students.
#
# 📊 Visual Example:
#
# Imagine the scores are sorted like this:
#
# | Rank | Score |
# | ---- | ----- |
# | 1st  | 40    |
# | 2nd  | 50    |
# | 3rd  | 60    |
# | 4th  | 70    |
# | 5th  | 80    |
# | 6th  | 90    |
# | 7th  | 100   |
#
# Now suppose you want to find the 50th percentile (also known as the median).
#
# There are 7 numbers, so the middle value (4th) is 70 → that’s the 50th percentile.
#
# key percentiles
#
# | Percentile | Meaning                               |
# | ---------- | ------------------------------------- |
# | 25th       | 25% of values are below this (Q1)     |
# | 50th       | 50% of values are below this (Median) |
# | 75th       | 75% of values are below this (Q3)     |
# | 90th       | 90% of values are below this          |
# | 100th      | The highest value                     |

# %%
import numpy as np

scores = [40, 50, 60, 70, 80, 90, 100]

# Find the 75th percentile
percentile_75 = np.percentile(scores, 75)
print(f"75th percentile: {percentile_75}")
# Out:
# 75th percentile: 85.0

# %% [markdown]
# ### Quartiles
#
# Quartiles are values that divide a sorted dataset into four equal parts.
#
# Each part contains 25% of the data.
#
# There are three main quartiles:
#
# | Quartile | Meaning                          |
# | -------- | -------------------------------- |
# | **Q1**   | 25th percentile (lower quartile) |
# | **Q2**   | 50th percentile (median)         |
# | **Q3**   | 75th percentile (upper quartile) |
#
# #### Why Are Quartiles Useful?
# Quartiles help us understand the spread and distribution of data — especially when identifying outliers or measuring data dispersion.
#
# Let’s say we have test scores for 9 students:
#
#
# >scores = [35, 40, 45, 50, 55, 60, 65, 70, 75]
#
# These are already sorted.
#
# Step-by-step:
#
# 👉 **Q2 (Median):**
#
# Middle value of the dataset.
#
# Q2 = 55
#
# 👉 **Q1 (25th percentile):**
#
# Median of the lower half (excluding Q2):
#
# Lower half = [35, 40, 45, 50]
#
# Q1 = (40 + 45)/2 = 42.5
#
# 👉 **Q3 (75th percentile):**
#
# Median of the upper half (excluding Q2):
#
# Upper half = [60, 65, 70, 75]
#
# Q3 = (65 + 70)/2 = 67.5
#
#
# ✅ Final Quartiles:
#
#
# Q1 = 42.5
#
# Q2 = 55
#
# Q3 = 67.5

# %% [markdown]
# ### What is Interquartile Range (IQR)?
#
# The Interquartile Range (IQR) measures the spread of the middle 50% of your data.
#
# 🧮 Formula:
#
# IQR = Q3 - Q1
#
# Q1 = 25th percentile (lower quartile)
#
# Q3 = 75th percentile (upper quartile)
#
# #### 🎯 Why is IQR important?
# It helps you:
#
# 1. Measure data spread without being affected by outliers.
# 2. Detect outliers.
# 3. Understand how concentrated your data is around the median.
#
# 🧠 Simple Example:
#
# >data = [10, 20, 30, 40, 50, 60, 70, 80, 90]
#
# Step 1:Sort the data (already sorted here)
#
# Step 2:Find Q1 and Q3
#
# Q1 = 25th percentile = 30
#
# Q3 = 75th percentile = 70
#
# Step 3:Compute IQR
#
# IQR = Q3 - Q1 = 70 - 30 = 40
#
# This tells us that the middle 50% of the data spans a range of 40 units.
#
# ### Detecting Outliers with IQR:
#
# Outliers are values that fall:
#
# * Below Q1 - 1.5 × IQR
#
# * Above Q3 + 1.5 × IQR
#
# Outlier boundaries:
#
# Lower bound: 30 - 1.5×40 = -30
#
# Upper bound: 70 + 1.5×40 = 130
#
# ✅ So any value outside -30 to 130 is considered an outlier.
#
#
#
# ### Probability Density
#
# ### Probability Density Curve
#
# https://www.khanacademy.org/math/statistics-probability/random-variables-stats-library/random-variables-continuous/v/probability-density-functions

# %% [markdown]
# # Matplotlib and Seaborn

# %% [markdown]
# * **Univariate analysis** is when you are observing the behaviour of a single variable. You can use histograms, count plots and pie charts to understand the distribution of a single feature.
# * **Bivariate analysis** is when you are observing the relationship between two variables. You can use scatter plots, line plots and bar charts to visualise how one variable affects another.
# * **Multivariate analysis** is when you are observing the relationships and interdependence between more than two variables. In such cases, tools like heat maps and pair plots are useful.
# * While dealing with categorical data, you could use count plots, bar charts and box plots to compare different categories or groups.
# * While dealing with time series data, visuals such as line plots and area plots can help you visualise changes over time.

# %% [markdown]
# ## scatter plot
#
# A scatter plot is simple: it is a technique for bivariate analysis where the relationship between two variables is marked out by a bunch of dots with each dot representing a single data point. If the dots are found to form a pattern such as a line or curve, it would suggest that there is a clear relationship between the two variables.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/heart.csv')
df.head()
# Out:
#    age  sex     BP  cholestrol  heart disease
# 0   70    1  130.0       322.0            1.0
# 1   67    0  115.0       564.0            0.0
# 2   57    1  124.0       261.0            1.0
# 3   64    1  128.0       263.0            0.0
# 4   74    0  120.0       269.0            0.0

# %% [markdown]
# Lets make a scattar plot using Matplot

# %%
plt.scatter(data=df,x='age',y='cholestrol')

# %% [markdown]
# ### .show()

# %%
plt.scatter(data=df,x='age',y='cholestrol')
plt.show() # hides the object and its memory location being shown in the chart above

# %% [markdown]
# Let's change the size of the image, and also annotate the plot by adding a title and giving names to the axes

# %%
plt.figure(figsize =(10,5))
plt.scatter(data=df, x ='age', y='cholestrol')
plt.title('Age vs Cld Level')
plt.xlabel('Age')
plt.ylabel('Cld')
plt.show()

# %% [markdown]
# Using Seaborn

# %%
sns.scatterplot(data=df, x ='age', y='cholestrol')
# Out:
# <Axes: xlabel='age', ylabel='cholestrol'>

# %%
sns.scatterplot(data=df, x ='age', y='cholestrol')
plt.show()

# %% [markdown]
# ## seaborn

# %%
# Seaborn is built atop matplotlib; many matplotlib methods are compatible with it
plt.figure(figsize=(5, 3))
sns.scatterplot(data=df, x = 'age', y = 'cholestrol' )
plt.title('Plot of age versus cholestrol levels')
plt.xlabel('Age')
plt.ylabel('Cholestrol')
plt.show()

# %% [markdown]
# ### Customize seaborn graph

# %%
plt.figure(figsize=(5, 3))
sns.scatterplot(data=df, x = 'age', y = 'cholestrol', s=10 ) #change marker size
plt.title('Plot of age versus cholestrol levels')
plt.xlabel('Age')
plt.ylabel('Cholestrol')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.scatterplot(data=df, x = 'age', y = 'cholestrol', marker='^' ) #change marker style
plt.title('Plot of age versus cholestrol levels')
plt.xlabel('Age')
plt.ylabel('Cholestrol')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.scatterplot(data=df, x = 'age', y = 'cholestrol', marker='^', c='r' ) #change marker color
plt.title('Plot of age versus cholestrol levels')
plt.xlabel('Age')
plt.ylabel('Cholestrol')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.scatterplot(data=df, x = 'age', y = 'cholestrol',   alpha=0.5 ) #change marker color
plt.title('Plot of age versus cholestrol levels')
plt.xlabel('Age')
plt.ylabel('Cholestrol')
plt.show()

# %%
plt.style.use('ggplot')
plt.figure(figsize=(5, 3))
sns.scatterplot(data=df, x = 'age', y = 'cholestrol',   alpha=0.5 ) #change marker color
plt.title('Age vs CLD')
plt.xlabel('Age')
plt.ylabel('Cholestrol')
plt.show()

# %% [markdown]
# Style changes are universal and will affect all plots. You need to manually revert the style if they were intended for just one plot.

# %%
plt.style.use('default')
plt.figure(figsize=(5, 3))
sns.scatterplot(data=df, x = 'age', y = 'cholestrol') #change marker color
plt.title('Plot of age versus cholestrol levels')
plt.xlabel('Age')
plt.ylabel('Cholestrol')
plt.show()

# %% [markdown]
# There are various other parameters; check out the **documentation** for seaborn ['https://seaborn.pydata.org/generated/seaborn.scatterplot.html']

# %% [markdown]
# ##  Line Plot
